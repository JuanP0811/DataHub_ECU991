# %%
import pandas as pd 
import numpy as np 

df = pd.read_csv( "emergencias_julio_2021.csv",
    sep=";",              # muy importante para este archivo
    encoding="utf-8"      # casi siempre funciona bien en español
)
#encoding sirve para los acentos y caracteres especiales
#"utf-8" es un estandar muy usado

# %%
#diagnostico
print(df.shape)
df.info()
# Out:
# (314507, 7)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 314507 entries, 0 to 314506
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Fecha          314507 non-null  object
#  1   provincia      314507 non-null  object
#  2   Canton         314507 non-null  object
#  3   Cod_Parroquia  314507 non-null  int64
#  4   Parroquia      314507 non-null  object
#  5   Servicio       314507 non-null  object
#  6   Subtipo        314507 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 16.8+ MB

# %%
import sys
# !{sys.executable} -m pip install unidecode
# Out:
# Requirement already satisfied: unidecode in c:\users\jpbau\appdata\local\programs\python\python312\lib\site-packages (1.4.0)
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from unidecode import unidecode
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df['Fecha'] = pd.to_datetime(df['Fecha'], dayfirst=True, errors='coerce')
def norm_txt(s):
    if pd.isna(s):
        return None   # si ya es nulo, retorna None
    
    s = str(s).strip()
    s = " ".join(s.split())   # colapsa espacios múltiples
    s = unidecode(s).lower()  # sin acentos y minúsculas
    
    # Si la provincia es inválida → retorna None
    if s in ['0', 'zona no delimitada']:
        return None
    
    return s   # valor normalizado

# %%
df0 = df.copy()
df0

Text_columns = ['provincia' , 'Canton' , 'Parroquia', 'Servicio', 'Subtipo']
for col in Text_columns:
    if col in df0.columns :
        df0[col] = df0[col].apply(norm_txt)
        

if 'Cod_Parroquia' in df0.columns:
    df0['Cod_Parroquia'] = (
        df0['Cod_Parroquia']
        .astype(str)
        .str.replace(r'\.0$', '', regex=True)  # elimina .0 si vino de Excel
        .str.strip()
    )

print(df0['Cod_Parroquia'].dtypes)
print(df0['Cod_Parroquia'].head())
# Out:
# object
# 0    90150
# 1    90650
# 2    90950
# 3    92050
# 4    90150
# Name: Cod_Parroquia, dtype: object

# %%
df0
# Out:
#             Fecha   provincia                   Canton Cod_Parroquia  \
# 0      2021-07-01      guayas                guayaquil         90150
# 1      2021-07-01      guayas                    daule         90650
# 2      2021-07-01      guayas               el triunfo         90950
# 3      2021-07-01      guayas  san jacinto de yaguachi         92050
# 4      2021-07-01      guayas                guayaquil         90150
# ...           ...         ...                      ...           ...
# 314502 2021-07-31  tungurahua      santiago de pillaro        180852
# 314503 2021-07-31  tungurahua                   ambato        180150
# 314504 2021-07-31     pastaza                  pastaza        160150
# 314505 2021-07-31  tungurahua                   ambato        180150
# 314506 2021-07-31  tungurahua                   ambato        180150
#
#                                                 Parroquia  \
# 0       guayaquil, cabecera cantonal y capital provincial
# 1                                daule, cabecera cantonal
# 2                           el triunfo, cabecera cantonal
# 3              san jacinto de yaguachi, cabecera cantonal
# 4       guayaquil, cabecera cantonal y capital provincial
# ...                                                   ...
# 314502                     emilio maria teran (rumipamba)
# 314503     ambato, cabecera cantonal y capital provincial
# 314504       puyo, cabecera cantonal y capital provincial
# 314505     ambato, cabecera cantonal y capital provincial
# 314506     ambato, cabecera cantonal y capital provincial
#
#                    Servicio                                      Subtipo
# 0       seguridad ciudadana                                    libadores
# 1       seguridad ciudadana                 escandalo en espacio privado
# 2       seguridad ciudadana                 escandalo en espacio privado
# 3       seguridad ciudadana  patrullaje policial en el sector solicitado
# 4       seguridad ciudadana                           presencia policial
# ...                     ...                                          ...
# 314502  seguridad ciudadana                 escandalo en espacio privado
# 314503  seguridad ciudadana                                    libadores
# 314504  seguridad ciudadana                                    libadores
# 314505  seguridad ciudadana                   ficha de datos informacion
# 314506  seguridad ciudadana  patrullaje policial en el sector solicitado
#
# [314507 rows x 7 columns]

# %%
df0['provincia'].isna().sum()
eventos_none = df0[df0['provincia'].isna()]

print("===== EVENTOS CON provincia = None =====")
print(eventos_none)
print(f"\nTotal de eventos con None: {len(eventos_none)}")
print(df0.shape)
# Out:
# ===== EVENTOS CON provincia = None =====
#             Fecha provincia       Canton Cod_Parroquia    Parroquia  \
# 16675  2021-07-17      None  el piedrero        900451  el piedrero
# 19167  2021-07-18      None  el piedrero        900451  el piedrero
# 25202  2021-07-24      None  el piedrero        900451  el piedrero
# 27721  2021-07-26      None  el piedrero        900451  el piedrero
# 64891  2021-07-02      None         None             0         None
# ...           ...       ...          ...           ...          ...
# 248922 2021-07-24      None         None             0         None
# 262456 2021-07-14      None         None             0         None
# 262502 2021-07-16      None         None             0         None
# 262697 2021-07-23      None         None             0         None
# 262932 2021-07-31      None         None             0         None
#
#                      Servicio                       Subtipo
# 16675       gestion sanitaria                         caida
# 19167     seguridad ciudadana       violencia intrafamiliar
# 25202     seguridad ciudadana  escandalo en espacio publico
# 27721       gestion sanitaria         inmersion en liquidos
# 64891       gestion sanitaria         transporte secundario
# ...                       ...                           ...
# 248922  gestion de siniestros                     incendios
# 262456   transito y movilidad                procedimientos
# 262502      gestion sanitaria         transporte secundario
# 262697       servicio militar            espacios acuaticos
# 262932       servicio militar            espacios acuaticos
#
# [90 rows x 7 columns]
#
# Total de eventos con None: 90
# (314507, 7)

# %%
# Contar antes de eliminar
antes = df0.shape[0]

# Eliminar filas donde provincia es None/NaN/pd.NA
df0 = df0[df0['provincia'].notna()].copy()

# Contar después
despues = df0.shape[0]

print(f"Filas antes: {antes}")
print(f"Filas después: {despues}")
print(f"Filas eliminadas: {antes - despues}")
# Out:
# Filas antes: 314507
# Filas después: 314417
# Filas eliminadas: 90

# %%
df0.shape
# Out:
# (314417, 7)

# %%
# ----- 1) Define la llave del evento único -----
keys = [
    'Fecha',
    'provincia_limpia',
    'Canton',
    'Parroquia',
    'Cod_Parroquia',
    'Servicio',
    'Subtipo'
]

# Filtrar solo las que existan en tu DataFrame
keys = [c for c in keys if c in df0.columns]


# ----- 2) Identificar duplicados según esa llave -----
# df0.duplicated(subset=keys, keep=False) marca TODOS los duplicados (incluye el primero)
mask_dups = df0.duplicated(subset=keys, keep=False)

# Extraer los eventos duplicados
duplicados = df0.loc[mask_dups].sort_values(keys)

# Mostrar resumen
print(f"Total de filas duplicadas usando la llave: {len(duplicados)}")

# Mostrar los duplicados
print("\n===== EVENTOS DUPLICADOS =====")
print(duplicados)
# Out:
# Total de filas duplicadas usando la llave: 244790
#
# ===== EVENTOS DUPLICADOS =====
#            Fecha   provincia     Canton Cod_Parroquia  \
# 33179 2021-07-01  chimborazo     alausi         60250
# 33188 2021-07-01  chimborazo     alausi         60250
# 33206 2021-07-01  chimborazo     alausi         60250
# 33223 2021-07-01  chimborazo     alausi         60250
# 33311 2021-07-01  chimborazo     alausi         60250
# ...          ...         ...        ...           ...
# 75977 2021-07-31        loja  zapotillo        111350
# 42078 2021-07-31      el oro     zaruma         71350
# 43820 2021-07-31      el oro     zaruma         71350
# 43940 2021-07-31      el oro     zaruma         71350
# 43941 2021-07-31      el oro     zaruma         71350
#
#                           Parroquia             Servicio  \
# 33179     alausi, cabecera cantonal  seguridad ciudadana
# 33188     alausi, cabecera cantonal  seguridad ciudadana
# 33206     alausi, cabecera cantonal  seguridad ciudadana
# 33223     alausi, cabecera cantonal  seguridad ciudadana
# 33311     alausi, cabecera cantonal  seguridad ciudadana
# ...                             ...                  ...
# 75977  zapotillo, cabecera cantonal  seguridad ciudadana
# 42078     zaruma, cabecera cantonal    gestion sanitaria
# 43820     zaruma, cabecera cantonal    gestion sanitaria
# 43940     zaruma, cabecera cantonal    gestion sanitaria
# 43941     zaruma, cabecera cantonal    gestion sanitaria
#
#                                            Subtipo
# 33179  patrullaje policial en el sector solicitado
# 33188  patrullaje policial en el sector solicitado
# 33206  patrullaje policial en el sector solicitado
# 33223  patrullaje policial en el sector solicitado
# 33311  patrullaje policial en el sector solicitado
# ...                                            ...
# 75977                                    libadores
# 42078                           mal estado general
# 43820                           mal estado general
# 43940                        transporte secundario
# 43941                        transporte secundario
#
# [244790 rows x 7 columns]

# %%
PROVINCIAS_VALIDAS = {
    '01':'AZUAY','02':'BOLIVAR','03':'CANAR','04':'CARCHI','05':'COTOPAXI','06':'CHIMBORAZO',
    '07':'EL ORO','08':'ESMERALDAS','09':'GUAYAS','10':'IMBABURA','11':'LOJA','12':'LOS RIOS',
    '13':'MANABI','14':'MORONA SANTIAGO','15':'NAPO','16':'PASTAZA','17':'PICHINCHA',
    '18':'TUNGURAHUA','19':'ZAMORA CHINCHIPE','20':'GALAPAGOS','21':'SUCUMBIOS',
    '22':'ORELLANA','23':'SANTO DOMINGO DE LOS TSACHILAS','24':'SANTA ELENA'
}
VALIDAS_SET = set(PROVINCIAS_VALIDAS.values())

# %%
df0.columns
# Out:
# Index(['Fecha', 'provincia', 'Canton', 'Cod_Parroquia', 'Parroquia',
#        'Servicio', 'Subtipo'],
#       dtype='object')

# %%
#validaciones de contenido:
# Provincias inválidas remanentes
restantes = df0.loc[df0['provincia'].isin(VALIDAS_SET) & df0['provincia'].notna()]
print(len(restantes))  # debería ser 0 si no usas 'SIN PROVINCIA'

# Nulos por columna clave
print(df0[['Fecha', 'provincia', 'Canton', 'Cod_Parroquia', 'Parroquia',
       'Servicio', 'Subtipo']].isna().sum())
# Out:
# 0
# Fecha            0
# provincia        0
# Canton           0
# Cod_Parroquia    0
# Parroquia        0
# Servicio         0
# Subtipo          0
# dtype: int64

# %%
df0
# Out:
#             Fecha   provincia                   Canton Cod_Parroquia  \
# 0      2021-07-01      guayas                guayaquil         90150
# 1      2021-07-01      guayas                    daule         90650
# 2      2021-07-01      guayas               el triunfo         90950
# 3      2021-07-01      guayas  san jacinto de yaguachi         92050
# 4      2021-07-01      guayas                guayaquil         90150
# ...           ...         ...                      ...           ...
# 314502 2021-07-31  tungurahua      santiago de pillaro        180852
# 314503 2021-07-31  tungurahua                   ambato        180150
# 314504 2021-07-31     pastaza                  pastaza        160150
# 314505 2021-07-31  tungurahua                   ambato        180150
# 314506 2021-07-31  tungurahua                   ambato        180150
#
#                                                 Parroquia  \
# 0       guayaquil, cabecera cantonal y capital provincial
# 1                                daule, cabecera cantonal
# 2                           el triunfo, cabecera cantonal
# 3              san jacinto de yaguachi, cabecera cantonal
# 4       guayaquil, cabecera cantonal y capital provincial
# ...                                                   ...
# 314502                     emilio maria teran (rumipamba)
# 314503     ambato, cabecera cantonal y capital provincial
# 314504       puyo, cabecera cantonal y capital provincial
# 314505     ambato, cabecera cantonal y capital provincial
# 314506     ambato, cabecera cantonal y capital provincial
#
#                    Servicio                                      Subtipo
# 0       seguridad ciudadana                                    libadores
# 1       seguridad ciudadana                 escandalo en espacio privado
# 2       seguridad ciudadana                 escandalo en espacio privado
# 3       seguridad ciudadana  patrullaje policial en el sector solicitado
# 4       seguridad ciudadana                           presencia policial
# ...                     ...                                          ...
# 314502  seguridad ciudadana                 escandalo en espacio privado
# 314503  seguridad ciudadana                                    libadores
# 314504  seguridad ciudadana                                    libadores
# 314505  seguridad ciudadana                   ficha de datos informacion
# 314506  seguridad ciudadana  patrullaje policial en el sector solicitado
#
# [314417 rows x 7 columns]

# %% [markdown]
# # Parroquias INEC

# %%
dataI = pd.read_excel("CODIFICACIÓN_2021.xlsx", header=0 , skiprows=1)
dataI
# Out:
#       Unnamed: 0  DPA_PROVIN   DPA_DESPRO  DPA_CANTON   DPA_DESCAN  \
# 0            NaN           1        AZUAY         101       CUENCA
# 1            NaN           1        AZUAY         101       CUENCA
# 2            NaN           1        AZUAY         101       CUENCA
# 3            NaN           1        AZUAY         101       CUENCA
# 4            NaN           1        AZUAY         101       CUENCA
# ...          ...         ...          ...         ...          ...
# 1037         NaN          24  SANTA ELENA        2401  SANTA ELENA
# 1038         NaN          24  SANTA ELENA        2402  LA LIBERTAD
# 1039         NaN          24  SANTA ELENA        2403      SALINAS
# 1040         NaN          24  SANTA ELENA        2403      SALINAS
# 1041         NaN          24  SANTA ELENA        2403      SALINAS
#
#       DPA_PARROQ         DPA_DESPAR  Unnamed: 7  DPA_PARROQ.1  \
# 0          10150             CUENCA         NaN         10150
# 1          10151              BAÑOS         NaN         10151
# 2          10152              CUMBE         NaN         10152
# 3          10153            CHAUCHA         NaN         10153
# 4          10154              CHECA         NaN         10154
# ...          ...                ...         ...           ...
# 1037      240156  SAN JOSÉ DE ANCÓN         NaN        240156
# 1038      240250        LA LIBERTAD         NaN        240250
# 1039      240350            SALINAS         NaN        240350
# 1040      240351          ANCONCITO         NaN        240351
# 1041      240352   JOSÉ LUIS TAMAYO         NaN        240352
#
#            DPA_DESPAR.1  Revisión   Revisión .1
# 0                CUENCA       True         True
# 1                 BAÑOS       True         True
# 2                 CUMBE       True         True
# 3               CHAUCHA       True         True
# 4                 CHECA       True         True
# ...                 ...        ...          ...
# 1037  SAN JOSÉ DE ANCÓN       True         True
# 1038        LA LIBERTAD       True         True
# 1039            SALINAS       True         True
# 1040          ANCONCITO       True         True
# 1041   JOSÉ LUIS TAMAYO       True         True
#
# [1042 rows x 12 columns]

# %%
dataI = dataI.dropna(axis=1,how="any")
dataI
# Out:
#       DPA_PROVIN   DPA_DESPRO  DPA_CANTON   DPA_DESCAN  DPA_PARROQ  \
# 0              1        AZUAY         101       CUENCA       10150
# 1              1        AZUAY         101       CUENCA       10151
# 2              1        AZUAY         101       CUENCA       10152
# 3              1        AZUAY         101       CUENCA       10153
# 4              1        AZUAY         101       CUENCA       10154
# ...          ...          ...         ...          ...         ...
# 1037          24  SANTA ELENA        2401  SANTA ELENA      240156
# 1038          24  SANTA ELENA        2402  LA LIBERTAD      240250
# 1039          24  SANTA ELENA        2403      SALINAS      240350
# 1040          24  SANTA ELENA        2403      SALINAS      240351
# 1041          24  SANTA ELENA        2403      SALINAS      240352
#
#              DPA_DESPAR  DPA_PARROQ.1       DPA_DESPAR.1  Revisión   \
# 0                CUENCA         10150             CUENCA       True
# 1                 BAÑOS         10151              BAÑOS       True
# 2                 CUMBE         10152              CUMBE       True
# 3               CHAUCHA         10153            CHAUCHA       True
# 4                 CHECA         10154              CHECA       True
# ...                 ...           ...                ...        ...
# 1037  SAN JOSÉ DE ANCÓN        240156  SAN JOSÉ DE ANCÓN       True
# 1038        LA LIBERTAD        240250        LA LIBERTAD       True
# 1039            SALINAS        240350            SALINAS       True
# 1040          ANCONCITO        240351          ANCONCITO       True
# 1041   JOSÉ LUIS TAMAYO        240352   JOSÉ LUIS TAMAYO       True
#
#       Revisión .1
# 0            True
# 1            True
# 2            True
# 3            True
# 4            True
# ...           ...
# 1037         True
# 1038         True
# 1039         True
# 1040         True
# 1041         True
#
# [1042 rows x 10 columns]

# %%
dataI.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1042 entries, 0 to 1041
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   DPA_PROVIN    1042 non-null   int64
#  1   DPA_DESPRO    1042 non-null   object
#  2   DPA_CANTON    1042 non-null   int64
#  3   DPA_DESCAN    1042 non-null   object
#  4   DPA_PARROQ    1042 non-null   int64
#  5   DPA_DESPAR    1042 non-null   object
#  6   DPA_PARROQ.1  1042 non-null   int64
#  7   DPA_DESPAR.1  1042 non-null   object
#  8   Revisión      1042 non-null   bool
#  9   Revisión .1   1042 non-null   bool
# dtypes: bool(2), int64(4), object(4)
# memory usage: 67.3+ KB

# %%
cod_parroquia_inec = dataI['DPA_PARROQ']
cod_parroquia_inec
# Out:
# 0        10150
# 1        10151
# 2        10152
# 3        10153
# 4        10154
#          ...
# 1037    240156
# 1038    240250
# 1039    240350
# 1040    240351
# 1041    240352
# Name: DPA_PARROQ, Length: 1042, dtype: int64

# %%
# Convertir a numéricos y limpiar
cod_p = pd.to_numeric(df0['Cod_Parroquia'], errors='coerce').dropna().astype(int)
cod_inec = pd.to_numeric(cod_parroquia_inec, errors='coerce').dropna().astype(int)

# Encontrar cuáles códigos de tu data NO están en INEC
faltantes = cod_p[~cod_p.isin(cod_inec)]

print(f"Total de códigos en tu data: {len(cod_p)}")
print(f"Total de códigos en INEC: {len(cod_inec)}")
print(f"\n{'='*50}")

if len(faltantes) > 0:
    print(f"✗ Códigos que NO existen en INEC: {len(faltantes.unique())}")
    print(f"\nDetalle:")
    for codigo in sorted(faltantes.unique()):
        count = (cod_p == codigo).sum()
        print(f"  Código {codigo}: aparece {count} veces")
else:
    print(f"✓ TODOS los códigos existen en INEC")

faltantes
# Out:
# Total de códigos en tu data: 314417
# Total de códigos en INEC: 1042
#
# ==================================================
# ✗ Códigos que NO existen en INEC: 1
#
# Detalle:
#   Código 11551: aparece 11 veces
# 43403     11551
# 86150     11551
# 87671     11551
# 90126     11551
# 91119     11551
# 91805     11551
# 92287     11551
# 100100    11551
# 100176    11551
# 100194    11551
# 102755    11551
# Name: Cod_Parroquia, dtype: int64

# %%
faltantes_set = set(cod_p) - set(cod_inec)
faltantes = sorted(faltantes_set)
print(f"Códigos faltantes: {faltantes}")
# Out:
# Códigos faltantes: [11551]

# %% [markdown]
# # Código más modular

# %%
df1 = df.copy()

# %%
df1
# Out:
#             Fecha   provincia                   Canton  Cod_Parroquia  \
# 0      2021-07-01      GUAYAS                GUAYAQUIL          90150
# 1      2021-07-01      GUAYAS                    DAULE          90650
# 2      2021-07-01      GUAYAS               EL TRIUNFO          90950
# 3      2021-07-01      GUAYAS  SAN JACINTO DE YAGUACHI          92050
# 4      2021-07-01      GUAYAS                GUAYAQUIL          90150
# ...           ...         ...                      ...            ...
# 314502 2021-07-31  TUNGURAHUA      SANTIAGO DE PILLARO         180852
# 314503 2021-07-31  TUNGURAHUA                   AMBATO         180150
# 314504 2021-07-31     PASTAZA                  PASTAZA         160150
# 314505 2021-07-31  TUNGURAHUA                   AMBATO         180150
# 314506 2021-07-31  TUNGURAHUA                   AMBATO         180150
#
#                                                 Parroquia  \
# 0       GUAYAQUIL, CABECERA CANTONAL Y CAPITAL PROVINCIAL
# 1                                DAULE, CABECERA CANTONAL
# 2                           EL TRIUNFO, CABECERA CANTONAL
# 3              SAN JACINTO DE YAGUACHI, CABECERA CANTONAL
# 4       GUAYAQUIL, CABECERA CANTONAL Y CAPITAL PROVINCIAL
# ...                                                   ...
# 314502                     EMILIO MARÍA TERÁN (RUMIPAMBA)
# 314503     AMBATO, CABECERA CANTONAL Y CAPITAL PROVINCIAL
# 314504       PUYO, CABECERA CANTONAL Y CAPITAL PROVINCIAL
# 314505     AMBATO, CABECERA CANTONAL Y CAPITAL PROVINCIAL
# 314506     AMBATO, CABECERA CANTONAL Y CAPITAL PROVINCIAL
#
#                    Servicio                                      Subtipo
# 0       Seguridad Ciudadana                                    Libadores
# 1       Seguridad Ciudadana                 Escándalo en espacio privado
# 2       Seguridad Ciudadana                 Escándalo en espacio privado
# 3       Seguridad Ciudadana  Patrullaje policial en el sector solicitado
# 4       Seguridad Ciudadana                           Presencia policial
# ...                     ...                                          ...
# 314502  Seguridad Ciudadana                 Escándalo en espacio privado
# 314503  Seguridad Ciudadana                                    Libadores
# 314504  Seguridad Ciudadana                                    Libadores
# 314505  Seguridad Ciudadana                   Ficha de datos información
# 314506  Seguridad Ciudadana  Patrullaje policial en el sector solicitado
#
# [314507 rows x 7 columns]

# %%
import pandas as pd
from unidecode import unidecode


# ============================================================
# 1. NORMALIZACIÓN DE TEXTO
# ============================================================

def norm_nombre(s):
    """
    Normaliza nombres de provincia/cantón/parroquia:
    - strip espacios
    - colapsa espacios múltiples
    - quita acentos
    - pasa a minúsculas
    """
    if pd.isna(s):
        return None
    s = str(s).strip()
    s = " ".join(s.split())
    s = unidecode(s).lower()
    return s


def norm_provincia(s):
    """
    Normaliza provincia y convierte a None si es '0' o 'zona no delimitada'.
    """
    s_norm = norm_nombre(s)
    if s_norm in ['0', 'zona no delimitada']:
        return None
    return s_norm


# ============================================================
# 2. CARGAR DATASET DE EMERGENCIAS
# ============================================================

def load_emergencias(path_csv: str) -> pd.DataFrame:
    """
    Lee el CSV de emergencias (julio) con los parámetros correctos.
    """
    df = pd.read_csv(path_csv, sep=";", encoding="utf-8")
    df['Fecha'] = pd.to_datetime(df['Fecha'], dayfirst=True, errors='coerce')
    return df


# ============================================================
# 3. LIMPIEZA DE EMERGENCIAS
# ============================================================

def clean_emergencias(df: pd.DataFrame) -> pd.DataFrame:
    """
    Limpia el dataset de emergencias:
    - Normaliza texto en provincia, cantón, parroquia, servicio, subtipo
    - Marca provincias inválidas ('0', 'zona no delimitada') como None
    - Limpia Cod_Parroquia y la deja como string (6 dígitos cuando aplique)
    - Crea columnas prov_norm, canton_norm, parr_norm
    - Elimina filas sin provincia (None)
    """
    df0 = df.copy()

    # Normalizar columnas de texto
    text_cols = ['provincia', 'Canton', 'Parroquia', 'Servicio', 'Subtipo']
    for col in text_cols:
        if col not in df0.columns:
            continue
        if col == 'provincia':
            df0[col] = df0[col].apply(norm_provincia)
        else:
            df0[col] = df0[col].apply(norm_nombre)
            
    if 'Cod_Parroquia' in df0.columns:
        df0['Cod_Parroquia'] = (
            df0['Cod_Parroquia']
            .astype(str)
            .str.replace(r'\.0$', '', regex=True)
            .str.strip()
        )

    df0['Cod_Parroquia'] = df0['Cod_Parroquia'].apply(
        lambda x: x.zfill(6) if x.isdigit() and len(x) <= 6 else x
    )

    

    # Columnas normalizadas explícitas (para el match con INEC)
    df0['prov_norm']   = df0['provincia'].apply(norm_nombre)
    df0['canton_norm'] = df0['Canton'].apply(norm_nombre)
    df0['parr_norm']   = df0['Parroquia'].apply(norm_nombre)

    # Eliminar filas sin provincia (None/NaN) porque no se pueden georreferenciar
    antes = len(df0)
    df0 = df0[df0['provincia'].notna()].copy()
    despues = len(df0)
    print(f"[clean_emergencias] Filas eliminadas por provincia None: {antes - despues}")

    return df0


# ============================================================
# 4. CARGAR Y PREPARAR CODIFICACIÓN INEC 2021
# ============================================================

def load_inec_codificacion(dataI: pd.DataFrame) -> pd.DataFrame:
    """
    Lee el archivo CODIFICACIÓN_2021 del INEC y prepara un DataFrame de referencia
    con:
    - DPA_PARROQ (código parroquial de 6 dígitos)
    - Nombres oficiales de provincia, cantón, parroquia
    - Versiones normalizadas para el match (prov_norm, canton_norm, parr_norm)
    """
    cols = ['DPA_PROVIN', 'DPA_DESPRO',
            'DPA_CANTON', 'DPA_DESCAN',
            'DPA_PARROQ', 'DPA_DESPAR']
    inec_ref = dataI[cols].copy()
    
    # Normalizar nombres
    inec_ref['prov_norm']   = inec_ref['DPA_DESPRO'].apply(norm_nombre)
    inec_ref['canton_norm'] = inec_ref['DPA_DESCAN'].apply(norm_nombre)
    inec_ref['parr_norm']   = inec_ref['DPA_DESPAR'].apply(norm_nombre)

    return inec_ref


# ============================================================
# 5. MAPEAR PARROQUIAS A CÓDIGO INEC
# ============================================================

def mapear_parroquias_inec(df_emerg: pd.DataFrame, inec_ref: pd.DataFrame) -> pd.DataFrame:
    """
    Mapea el código de parroquia de df_emerg contra el catálogo INEC.
    
    Si Cod_Parroquia coincide con DPA_PARROQ -> asigna el código.
    Si NO coincide -> coloca NaN.
    """
    # Nos aseguramos que los códigos estén limpios y comparables
    df = df_emerg.copy()
    df['Cod_Parroquia'] = (
        df['Cod_Parroquia']
        .astype(str)
        .str.replace(r'\.0$', '', regex=True)
        .str.strip()
        .str.zfill(6)
    )
    
    inec = inec_ref.copy()
    inec['DPA_PARROQ'] = (
        inec['DPA_PARROQ']
        .astype(str)
        .str.replace(r'\.0$', '', regex=True)
        .str.strip()
        .str.zfill(6)
    )

    # Merge SOLO por código parroquial
    df_geo = df.merge(
        inec[['DPA_PARROQ']],   # solo necesitamos el código oficial
        left_on='Cod_Parroquia',
        right_on='DPA_PARROQ',
        how='left'
    )

    return df_geo



# ============================================================
# 6. REPORTE DE GEOREFERENCIACIÓN
# ============================================================

def reporte_geocodificacion(df_geo: pd.DataFrame) -> None:
    """
    Imprime un resumen de qué tan bien se mapeó a INEC:
    - % de filas con código parroquial asignado
    - ejemplos de parroquias sin match
    """
    total = len(df_geo)
    con_codigo = df_geo['DPA_PARROQ'].notna().sum()
    sin_codigo = total - con_codigo

    print("=== REPORTE GEOREFERENCIACIÓN ===")
    print(f"Filas totales: {total}")
    print(f"Con código INEC (DPA_PARROQ): {con_codigo} ({con_codigo/total*100:.2f}%)")
    print(f"Sin código INEC: {sin_codigo} ({sin_codigo/total*100:.2f}%)")

    if sin_codigo > 0:
        print("\nEjemplos de parroquias SIN match (provincia / cantón / parroquia):")
        ejemplos = (
            df_geo[df_geo['DPA_PARROQ'].isna()]
            [['provincia', 'Canton', 'Parroquia']]
            .drop_duplicates()
            .head(300)
        )
        print(ejemplos)


# ============================================================
# 7. PIPELINE COMPLETO
# ============================================================

def pipeline_georreferenciacion(path_emerg: str, dataI: pd.DataFrame) -> pd.DataFrame:
    """
    Ejecuta todo el flujo:
    1) Carga emergencias
    2) Limpia texto, provincias y Cod_Parroquia
    3) Carga catálogo INEC
    4) Mapea parroquias y agrega DPA_PARROQ
    5) Imprime reporte
    Devuelve df_geo (listo para unir con shapefile).
    """
    print("1) Cargando emergencias...")
    df = load_emergencias(path_emerg)

    print("2) Limpiando emergencias...")
    df_clean = clean_emergencias(df)

    print("3) Cargando codificación INEC...")
    inec_ref = load_inec_codificacion(dataI)

    print("4) Mapeando parroquias a INEC...")
    df_geo = mapear_parroquias_inec(df_clean, inec_ref)

    print("5) Reporte de georreferenciación:")
    reporte_geocodificacion(df_geo)

    return df_geo


# ============================================================
# 8. EJEMPLO DE USO
# ============================================================

# Descomenta esto y ajusta las rutas en tu notebook/script:
df_geo = pipeline_georreferenciacion(
     path_emerg="emergencias_julio_2021.csv",
     dataI=dataI
)
#df_geo.to_csv("emergencias_julio_2021_georreferenciado.csv", index=False)
df_geo
# Out:
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 90
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 314417
# Con código INEC (DPA_PARROQ): 314406 (100.00%)
# Sin código INEC: 11 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#       provincia                 Canton            Parroquia
# 43399     azuay  camilo ponce enriquez  el carmen de pijili
#             Fecha   provincia                   Canton Cod_Parroquia  \
# 0      2021-07-01      guayas                guayaquil        090150
# 1      2021-07-01      guayas                    daule        090650
# 2      2021-07-01      guayas               el triunfo        090950
# 3      2021-07-01      guayas  san jacinto de yaguachi        092050
# 4      2021-07-01      guayas                guayaquil        090150
# ...           ...         ...                      ...           ...
# 314412 2021-07-31  tungurahua      santiago de pillaro        180852
# 314413 2021-07-31  tungurahua                   ambato        180150
# 314414 2021-07-31     pastaza                  pastaza        160150
# 314415 2021-07-31  tungurahua                   ambato        180150
# 314416 2021-07-31  tungurahua                   ambato        180150
#
#                                                 Parroquia  \
# 0       guayaquil, cabecera cantonal y capital provincial
# 1                                daule, cabecera cantonal
# 2                           el triunfo, cabecera cantonal
# 3              san jacinto de yaguachi, cabecera cantonal
# 4       guayaquil, cabecera cantonal y capital provincial
# ...                                                   ...
# 314412                     emilio maria teran (rumipamba)
# 314413     ambato, cabecera cantonal y capital provincial
# 314414       puyo, cabecera cantonal y capital provincial
# 314415     ambato, cabecera cantonal y capital provincial
# 314416     ambato, cabecera cantonal y capital provincial
#
#                    Servicio                                      Subtipo  \
# 0       seguridad ciudadana                                    libadores
# 1       seguridad ciudadana                 escandalo en espacio privado
# 2       seguridad ciudadana                 escandalo en espacio privado
# 3       seguridad ciudadana  patrullaje policial en el sector solicitado
# 4       seguridad ciudadana                           presencia policial
# ...                     ...                                          ...
# 314412  seguridad ciudadana                 escandalo en espacio privado
# 314413  seguridad ciudadana                                    libadores
# 314414  seguridad ciudadana                                    libadores
# 314415  seguridad ciudadana                   ficha de datos informacion
# 314416  seguridad ciudadana  patrullaje policial en el sector solicitado
#
#          prov_norm              canton_norm  \
# 0           guayas                guayaquil
# 1           guayas                    daule
# 2           guayas               el triunfo
# 3           guayas  san jacinto de yaguachi
# 4           guayas                guayaquil
# ...            ...                      ...
# 314412  tungurahua      santiago de pillaro
# 314413  tungurahua                   ambato
# 314414     pastaza                  pastaza
# 314415  tungurahua                   ambato
# 314416  tungurahua                   ambato
#
#                                                 parr_norm DPA_PARROQ
# 0       guayaquil, cabecera cantonal y capital provincial     090150
# 1                                daule, cabecera cantonal     090650
# 2                           el triunfo, cabecera cantonal     090950
# 3              san jacinto de yaguachi, cabecera cantonal     092050
# 4       guayaquil, cabecera cantonal y capital provincial     090150
# ...                                                   ...        ...
# 314412                     emilio maria teran (rumipamba)     180852
# 314413     ambato, cabecera cantonal y capital provincial     180150
# 314414       puyo, cabecera cantonal y capital provincial     160150
# 314415     ambato, cabecera cantonal y capital provincial     180150
# 314416     ambato, cabecera cantonal y capital provincial     180150
#
# [314417 rows x 11 columns]

# %%
def reporte_geocodificacion(df_geo: pd.DataFrame) -> pd.DataFrame:
    """
    Imprime un resumen de georreferenciación y retorna
    TODOS los eventos que NO tienen código INEC (DPA_PARROQ = NaN).
    """
    total = len(df_geo)
    con_codigo = df_geo['DPA_PARROQ'].notna().sum()
    sin_codigo = total - con_codigo

    print("=== REPORTE GEOREFERENCIACIÓN ===")
    print(f"Filas totales: {total}")
    print(f"Con código INEC (DPA_PARROQ): {con_codigo} ({con_codigo/total*100:.2f}%)")
    print(f"Sin código INEC: {sin_codigo} ({sin_codigo/total*100:.2f}%)")

    # Filtrar TODOS los eventos sin código INEC
    eventos_sin_codigo = df_geo[df_geo['DPA_PARROQ'].isna()].copy()

    print("\n===== EVENTOS SIN CÓDIGO INEC (DPA_PARROQ NaN) =====")
    print(eventos_sin_codigo)  # ojo: puede ser grande

    return eventos_sin_codigo

# %%
eventos_sin_codigo = reporte_geocodificacion(df_geo)
# Out:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 314417
# Con código INEC (DPA_PARROQ): 314406 (100.00%)
# Sin código INEC: 11 (0.00%)
#
# ===== EVENTOS SIN CÓDIGO INEC (DPA_PARROQ NaN) =====
#             Fecha provincia                 Canton Cod_Parroquia  \
# 43399  2021-07-23     azuay  camilo ponce enriquez        011551
# 86139  2021-07-13     azuay  camilo ponce enriquez        011551
# 87659  2021-07-01     azuay  camilo ponce enriquez        011551
# 90111  2021-07-07     azuay  camilo ponce enriquez        011551
# 91103  2021-07-09     azuay  camilo ponce enriquez        011551
# 91788  2021-07-10     azuay  camilo ponce enriquez        011551
# 92270  2021-07-11     azuay  camilo ponce enriquez        011551
# 100071 2021-07-27     azuay  camilo ponce enriquez        011551
# 100147 2021-07-27     azuay  camilo ponce enriquez        011551
# 100165 2021-07-27     azuay  camilo ponce enriquez        011551
# 102722 2021-07-03     azuay  camilo ponce enriquez        011551
#
#                   Parroquia               Servicio  \
# 43399   el carmen de pijili      gestion sanitaria
# 86139   el carmen de pijili    seguridad ciudadana
# 87659   el carmen de pijili   transito y movilidad
# 90111   el carmen de pijili     gestion de riesgos
# 91103   el carmen de pijili  servicios municipales
# 91788   el carmen de pijili    seguridad ciudadana
# 92270   el carmen de pijili   transito y movilidad
# 100071  el carmen de pijili    seguridad ciudadana
# 100147  el carmen de pijili      gestion sanitaria
# 100165  el carmen de pijili      gestion sanitaria
# 102722  el carmen de pijili  servicios municipales
#
#                                             Subtipo prov_norm  \
# 43399                          problemas digestivos     azuay
# 86139              persona herida con arma de fuego     azuay
# 87659                 perdida de carril con heridos     azuay
# 90111                              accidente minero     azuay
# 91103                           apoyo institucional     azuay
# 91788   patrullaje policial en el sector solicitado     azuay
# 92270                                     servicios     azuay
# 100071  patrullaje policial en el sector solicitado     azuay
# 100147                        alza termica - fiebre     azuay
# 100165                           mal estado general     azuay
# 102722                                  cable aereo     azuay
#
#                   canton_norm            parr_norm DPA_PARROQ
# 43399   camilo ponce enriquez  el carmen de pijili        NaN
# 86139   camilo ponce enriquez  el carmen de pijili        NaN
# 87659   camilo ponce enriquez  el carmen de pijili        NaN
# 90111   camilo ponce enriquez  el carmen de pijili        NaN
# 91103   camilo ponce enriquez  el carmen de pijili        NaN
# 91788   camilo ponce enriquez  el carmen de pijili        NaN
# 92270   camilo ponce enriquez  el carmen de pijili        NaN
# 100071  camilo ponce enriquez  el carmen de pijili        NaN
# 100147  camilo ponce enriquez  el carmen de pijili        NaN
# 100165  camilo ponce enriquez  el carmen de pijili        NaN
# 102722  camilo ponce enriquez  el carmen de pijili        NaN

# %%
# Exporta a Excel sin índice
output_path = "df_geo_export.xlsx"
df_geo.to_excel(output_path, index=False)
print(f"Archivo guardado en: {output_path}")
# Out:
# Archivo guardado en: df_geo_export.xlsx

# %%
import pandas as pd
from unidecode import unidecode
import glob
import os


# ============================================================
# 1. NORMALIZACIÓN DE TEXTO
# ============================================================

def norm_nombre(s):
    """
    Normaliza nombres de provincia/cantón/parroquia:
    - strip espacios
    - colapsa espacios múltiples
    - quita acentos
    - pasa a minúsculas
    """
    if pd.isna(s):
        return None
    s = str(s).strip()
    s = " ".join(s.split())
    s = unidecode(s).lower()
    return s


def norm_provincia(s):
    """
    Normaliza provincia y convierte a None si es '0' o 'zona no delimitada'.
    """
    s_norm = norm_nombre(s)
    if s_norm in ['0', 'zona no delimitada']:
        return None
    return s_norm


# ============================================================
# 2. CARGAR DATASET DE EMERGENCIAS
# ============================================================

def load_emergencias(path_csv: str) -> pd.DataFrame:
    """
    Lee el CSV de emergencias con los parámetros correctos.
    """
    df = pd.read_csv(path_csv, sep=";", encoding="utf-8")
    df['Fecha'] = pd.to_datetime(df['Fecha'], dayfirst=True, errors='coerce')
    return df


# ============================================================
# 3. LIMPIEZA DE EMERGENCIAS
# ============================================================

def clean_emergencias(df: pd.DataFrame) -> pd.DataFrame:
    """
    Limpia el dataset de emergencias:
    - Normaliza texto en provincia, cantón, parroquia, servicio, subtipo
    - Marca provincias inválidas ('0', 'zona no delimitada') como None
    - Limpia Cod_Parroquia y la deja como string (6 dígitos cuando aplique)
    - Crea columnas prov_norm, canton_norm, parr_norm
    - Elimina filas sin provincia (None)
    """
    df0 = df.copy()

    # Normalizar columnas de texto
    text_cols = ['provincia', 'Canton', 'Parroquia', 'Servicio', 'Subtipo']
    for col in text_cols:
        if col not in df0.columns:
            continue
        if col == 'provincia':
            df0[col] = df0[col].apply(norm_provincia)
        else:
            df0[col] = df0[col].apply(norm_nombre)
            
    if 'Cod_Parroquia' in df0.columns:
        df0['Cod_Parroquia'] = (
            df0['Cod_Parroquia']
            .astype(str)
            .str.replace(r'\.0$', '', regex=True)
            .str.strip()
        )

    df0['Cod_Parroquia'] = df0['Cod_Parroquia'].apply(
        lambda x: x.zfill(6) if x.isdigit() and len(x) <= 6 else x
    )

    

    # Columnas normalizadas explícitas (para el match con INEC)
    df0['prov_norm']   = df0['provincia'].apply(norm_nombre)
    df0['canton_norm'] = df0['Canton'].apply(norm_nombre)
    df0['parr_norm']   = df0['Parroquia'].apply(norm_nombre)

    # Eliminar filas sin provincia (None/NaN) porque no se pueden georreferenciar
    antes = len(df0)
    df0 = df0[df0['provincia'].notna()].copy()
    despues = len(df0)
    print(f"[clean_emergencias] Filas eliminadas por provincia None: {antes - despues}")

    return df0


# ============================================================
# 4. CARGAR Y PREPARAR CODIFICACIÓN INEC 2021
# ============================================================

def load_inec_codificacion(dataI: pd.DataFrame) -> pd.DataFrame:
    """
    Lee el archivo CODIFICACIÓN_2021 del INEC y prepara un DataFrame de referencia
    con:
    - DPA_PARROQ (código parroquial de 6 dígitos)
    - Nombres oficiales de provincia, cantón, parroquia
    - Versiones normalizadas para el match (prov_norm, canton_norm, parr_norm)
    """
    cols = ['DPA_PROVIN', 'DPA_DESPRO',
            'DPA_CANTON', 'DPA_DESCAN',
            'DPA_PARROQ', 'DPA_DESPAR']
    inec_ref = dataI[cols].copy()
    
    # Normalizar nombres
    inec_ref['prov_norm']   = inec_ref['DPA_DESPRO'].apply(norm_nombre)
    inec_ref['canton_norm'] = inec_ref['DPA_DESCAN'].apply(norm_nombre)
    inec_ref['parr_norm']   = inec_ref['DPA_DESPAR'].apply(norm_nombre)

    return inec_ref


# ============================================================
# 5. MAPEAR PARROQUIAS A CÓDIGO INEC
# ============================================================

def mapear_parroquias_inec(df_emerg: pd.DataFrame, inec_ref: pd.DataFrame) -> pd.DataFrame:
    """
    Mapea el código de parroquia de df_emerg contra el catálogo INEC.
    
    Si Cod_Parroquia coincide con DPA_PARROQ -> asigna el código.
    Si NO coincide -> coloca NaN.
    """
    # Nos aseguramos que los códigos estén limpios y comparables
    df = df_emerg.copy()
    df['Cod_Parroquia'] = (
        df['Cod_Parroquia']
        .astype(str)
        .str.replace(r'\.0$', '', regex=True)
        .str.strip()
        .str.zfill(6)
    )
    
    inec = inec_ref.copy()
    inec['DPA_PARROQ'] = (
        inec['DPA_PARROQ']
        .astype(str)
        .str.replace(r'\.0$', '', regex=True)
        .str.strip()
        .str.zfill(6)
    )

    # Merge SOLO por código parroquial
    df_geo = df.merge(
        inec[['DPA_PARROQ']],   # solo necesitamos el código oficial
        left_on='Cod_Parroquia',
        right_on='DPA_PARROQ',
        how='left'
    )

    return df_geo



# ============================================================
# 6. REPORTE DE GEOREFERENCIACIÓN
# ============================================================

def reporte_geocodificacion(df_geo: pd.DataFrame) -> None:
    """
    Imprime un resumen de qué tan bien se mapeó a INEC:
    - % de filas con código parroquial asignado
    - ejemplos de parroquias sin match
    """
    total = len(df_geo)
    con_codigo = df_geo['DPA_PARROQ'].notna().sum()
    sin_codigo = total - con_codigo

    print("=== REPORTE GEOREFERENCIACIÓN ===")
    print(f"Filas totales: {total}")
    print(f"Con código INEC (DPA_PARROQ): {con_codigo} ({con_codigo/total*100:.2f}%)")
    print(f"Sin código INEC: {sin_codigo} ({sin_codigo/total*100:.2f}%)")

    if sin_codigo > 0:
        print("\nEjemplos de parroquias SIN match (provincia / cantón / parroquia):")
        ejemplos = (
            df_geo[df_geo['DPA_PARROQ'].isna()]
            [['provincia', 'Canton', 'Parroquia']]
            .drop_duplicates()
            .head(300)
        )
        print(ejemplos)


# ============================================================
# 7. PIPELINE COMPLETO
# ============================================================

def pipeline_georreferenciacion(path_emerg: str, dataI: pd.DataFrame) -> pd.DataFrame:
    """
    Ejecuta todo el flujo:
    1) Carga emergencias
    2) Limpia texto, provincias y Cod_Parroquia
    3) Carga catálogo INEC
    4) Mapea parroquias y agrega DPA_PARROQ
    5) Imprime reporte
    Devuelve df_geo (listo para unir con shapefile).
    """
    print(f"\n{'='*60}")
    print(f"Procesando: {os.path.basename(path_emerg)}")
    print(f"{'='*60}")
    
    print("1) Cargando emergencias...")
    df = load_emergencias(path_emerg)

    print("2) Limpiando emergencias...")
    df_clean = clean_emergencias(df)

    print("3) Cargando codificación INEC...")
    inec_ref = load_inec_codificacion(dataI)

    print("4) Mapeando parroquias a INEC...")
    df_geo = mapear_parroquias_inec(df_clean, inec_ref)

    print("5) Reporte de georreferenciación:")
    reporte_geocodificacion(df_geo)

    return df_geo


# ============================================================
# 8. PROCESAR TODOS LOS ARCHIVOS
# ============================================================

def procesar_todos_emergencias():
    """
    Encuentra todos los archivos emergencias_*.csv y los procesa.
    Guarda cada uno con el nombre: emergencias_X_georreferenciado.csv
    """
    # Cargar el archivo de codificación INEC
    print("Cargando CODIFICACIÓN_2021.xlsx...")
    dataI = pd.read_excel("CODIFICACIÓN_2021.xlsx", header=0, skiprows=1)
    dataI = dataI.dropna(axis=1, how="any")
    print(f"Codificación INEC cargada: {dataI.shape[0]} parroquias")
    
    # Encontrar todos los archivos emergencias_*.csv
    archivos_emergencias = glob.glob("emergencias_*.csv")
    
    if not archivos_emergencias:
        print("\n¡No se encontraron archivos emergencias_*.csv!")
        return
    
    print(f"\n[OK] Se encontraron {len(archivos_emergencias)} archivos para procesar")
    print("Archivos:")
    for archivo in archivos_emergencias:
        print(f"  - {archivo}")
    
    # Procesar cada archivo
    for path_emerg in archivos_emergencias:
        try:
            # Ejecutar el pipeline
            df_geo = pipeline_georreferenciacion(path_emerg, dataI)
            
            # Crear nombre del archivo de salida
            nombre_base = os.path.splitext(os.path.basename(path_emerg))[0]
            output_path = f"{nombre_base}_georreferenciado.csv"
            
            # Guardar resultado
            df_geo.to_csv(output_path, index=False, encoding='utf-8')
            print(f"[OK] Archivo guardado: {output_path}")
            
        except Exception as e:
            print(f"[ERROR] al procesar {path_emerg}: {str(e)}")
            continue
    
    print(f"\n{'='*60}")
    print("[OK] PROCESAMIENTO COMPLETADO")
    print(f"{'='*60}")


# ============================================================
# 9. EJECUCIÓN
# ============================================================

if __name__ == "__main__":
    procesar_todos_emergencias()
# Out:
# Cargando CODIFICACIÓN_2021.xlsx...
# Codificación INEC cargada: 1042 parroquias
#
# [OK] Se encontraron 6 archivos para procesar
# Archivos:
#   - emergencias_agosto_2021.csv
#   - emergencias_diciembre_2021.csv
#   - emergencias_julio_2021.csv
#   - emergencias_noviembre_2021.csv
#   - emergencias_octubre_2021.csv
#   - emergencias_septiembre_2021.csv
#
# ============================================================
# Procesando: emergencias_agosto_2021.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 93
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 319896
# Con código INEC (DPA_PARROQ): 319883 (100.00%)
# Sin código INEC: 13 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 85324      azuay  camilo ponce enriquez  el carmen de pijili
# 119225  orellana               aguarico             tiputini
# [OK] Archivo guardado: emergencias_agosto_2021_georreferenciado.csv
#
# ============================================================
# Procesando: emergencias_diciembre_2021.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 77
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 333978
# Con código INEC (DPA_PARROQ): 333967 (100.00%)
# Sin código INEC: 11 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 78865      azuay  camilo ponce enriquez  el carmen de pijili
# 160973  orellana               aguarico             tiputini
# [OK] Archivo guardado: emergencias_diciembre_2021_georreferenciado.csv
#
# ============================================================
# Procesando: emergencias_julio_2021.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 90
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 314417
# Con código INEC (DPA_PARROQ): 314406 (100.00%)
# Sin código INEC: 11 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#       provincia                 Canton            Parroquia
# 43399     azuay  camilo ponce enriquez  el carmen de pijili
# [OK] Archivo guardado: emergencias_julio_2021_georreferenciado.csv
#
# ============================================================
# Procesando: emergencias_noviembre_2021.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 76
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 298937
# Con código INEC (DPA_PARROQ): 298925 (100.00%)
# Sin código INEC: 12 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 35325   orellana               aguarico             tiputini
# 124738     azuay  camilo ponce enriquez  el carmen de pijili
# [OK] Archivo guardado: emergencias_noviembre_2021_georreferenciado.csv
#
# ============================================================
# Procesando: emergencias_octubre_2021.csv
# ============================================================
# 1) Cargando emergencias...
# C:\Users\JPbau\AppData\Local\Temp\ipykernel_11788\3374631713.py:45: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path_csv, sep=";", encoding="utf-8")
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 91
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 327729
# Con código INEC (DPA_PARROQ): 327722 (100.00%)
# Sin código INEC: 7 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#       provincia                 Canton            Parroquia
# 5390      azuay  camilo ponce enriquez  el carmen de pijili
# 84151  orellana               aguarico             tiputini
# [OK] Archivo guardado: emergencias_octubre_2021_georreferenciado.csv
#
# ============================================================
# Procesando: emergencias_septiembre_2021.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 68
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 307597
# Con código INEC (DPA_PARROQ): 307589 (100.00%)
# Sin código INEC: 8 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 96406      azuay  camilo ponce enriquez  el carmen de pijili
# 263807  orellana               aguarico             tiputini
# [OK] Archivo guardado: emergencias_septiembre_2021_georreferenciado.csv
#
# ============================================================
# [OK] PROCESAMIENTO COMPLETADO
# ============================================================

# %% [markdown]
# Unir provincias

# %%
import pandas as pd
import glob
import os

def unir_archivos_georreferenciados():
    """
    Une todos los archivos *_georreferenciado.csv en un solo archivo.
    """
    print("="*60)
    print("UNIENDO ARCHIVOS GEORREFERENCIADOS")
    print("="*60)
    
    # Buscar todos los archivos georreferenciados
    archivos = glob.glob("emergencias_*_georreferenciado.csv")
    
    if not archivos:
        print("\n❌ No se encontraron archivos *_georreferenciado.csv")
        return
    
    print(f"\n[OK] Se encontraron {len(archivos)} archivos:")
    for archivo in sorted(archivos):
        tamano_mb = os.path.getsize(archivo) / (1024 * 1024)
        print(f"  - {archivo} ({tamano_mb:.2f} MB)")
    
    # Leer y concatenar todos los archivos
    print(f"\n[PROCESO] Leyendo archivos...")
    dataframes = []
    
    for i, archivo in enumerate(sorted(archivos), 1):
        print(f"  [{i}/{len(archivos)}] Cargando {archivo}...")
        df = pd.read_csv(archivo, encoding='utf-8')
        
        # Agregar columna con el nombre del archivo de origen (opcional)
        df['archivo_origen'] = os.path.basename(archivo)
        
        dataframes.append(df)
        print(f"      [OK] {len(df):,} filas cargadas")
    
    # Concatenar todos los dataframes
    print(f"\n[PROCESO] Concatenando {len(dataframes)} archivos...")
    df_completo = pd.concat(dataframes, ignore_index=True)
    
    print(f"  [OK] Total de filas: {len(df_completo):,}")
    print(f"  [OK] Total de columnas: {len(df_completo.columns)}")
    
    # Mostrar estadísticas
    print(f"\n[ESTADISTICAS]")
    print(f"  - Con codigo INEC: {df_completo['DPA_PARROQ'].notna().sum():,} ({df_completo['DPA_PARROQ'].notna().sum()/len(df_completo)*100:.2f}%)")
    print(f"  - Sin codigo INEC: {df_completo['DPA_PARROQ'].isna().sum():,} ({df_completo['DPA_PARROQ'].isna().sum()/len(df_completo)*100:.2f}%)")
    
    if 'Fecha' in df_completo.columns:
        df_completo['Fecha'] = pd.to_datetime(df_completo['Fecha'], errors='coerce')
        print(f"  - Rango de fechas: {df_completo['Fecha'].min()} a {df_completo['Fecha'].max()}")
    
    # Guardar archivo unificado
    output_file = "emergencias_2021_completo_georreferenciado.csv"
    print(f"\n[GUARDANDO] Archivo unificado: {output_file}")
    df_completo.to_csv(output_file, index=False, encoding='utf-8')
    
    tamano_final_mb = os.path.getsize(output_file) / (1024 * 1024)
    print(f"  [OK] Archivo guardado exitosamente ({tamano_final_mb:.2f} MB)")
    
    # Reporte por archivo de origen
    print(f"\n[DISTRIBUCION] Por archivo:")
    conteo_origen = df_completo['archivo_origen'].value_counts().sort_index()
    for archivo, cantidad in conteo_origen.items():
        print(f"  - {archivo}: {cantidad:,} filas")
    
    print(f"\n{'='*60}")
    print("[OK] PROCESO COMPLETADO")
    print(f"{'='*60}")
    print(f"\nArchivo final: {output_file}")
    print(f"Total de registros: {len(df_completo):,}")
    
    return df_completo

if __name__ == "__main__":
    df_unificado = unir_archivos_georreferenciados()

# %%
df_emergencias_total = pd.read_csv("emergencias_2021_completo_georreferenciado.csv")

print(df_emergencias_total.head(10))

# para verlo en forma de tabla 
df_emergencias_total.style.set_properties(**{'text-align': 'left'})
# Out:
# C:\Users\JPbau\AppData\Local\Temp\ipykernel_11788\2669691389.py:1: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_emergencias_total = pd.read_csv("emergencias_2021_completo_georreferenciado.csv")
#         Fecha provincia     Canton  Cod_Parroquia  \
# 0  2021-08-07    guayas  guayaquil          90150
# 1  2021-08-07    guayas  guayaquil          90150
# 2  2021-08-07    guayas  guayaquil          90150
# 3  2021-08-07    guayas  guayaquil          90150
# 4  2021-08-07    guayas  guayaquil          90150
# 5  2021-08-07    guayas  guayaquil          90150
# 6  2021-08-07    guayas  guayaquil          90150
# 7  2021-08-07    guayas  guayaquil          90150
# 8  2021-08-07    guayas  guayaquil          90150
# 9  2021-08-07    guayas  guayaquil          90150
#
#                                            Parroquia               Servicio  \
# 0  guayaquil, cabecera cantonal y capital provincial    seguridad ciudadana
# 1  guayaquil, cabecera cantonal y capital provincial    seguridad ciudadana
# 2  guayaquil, cabecera cantonal y capital provincial    seguridad ciudadana
# 3  guayaquil, cabecera cantonal y capital provincial    seguridad ciudadana
# 4  guayaquil, cabecera cantonal y capital provincial    seguridad ciudadana
# 5  guayaquil, cabecera cantonal y capital provincial    seguridad ciudadana
# 6  guayaquil, cabecera cantonal y capital provincial   transito y movilidad
# 7  guayaquil, cabecera cantonal y capital provincial  gestion de siniestros
# 8  guayaquil, cabecera cantonal y capital provincial    seguridad ciudadana
# 9  guayaquil, cabecera cantonal y capital provincial    seguridad ciudadana
#
#                                          Subtipo prov_norm canton_norm  \
# 0                                      libadores    guayas   guayaquil
# 1                 diversas formas de explotacion    guayas   guayaquil
# 2  consumo de sustancias sujetas a fiscalizacion    guayas   guayaquil
# 3    patrullaje policial en el sector solicitado    guayas   guayaquil
# 4                 diversas formas de explotacion    guayas   guayaquil
# 5                                      libadores    guayas   guayaquil
# 6                                 procedimientos    guayas   guayaquil
# 7                            colision y/o choque    guayas   guayaquil
# 8    patrullaje policial en el sector solicitado    guayas   guayaquil
# 9                                  robo personas    guayas   guayaquil
#
#                                            parr_norm  DPA_PARROQ  \
# 0  guayaquil, cabecera cantonal y capital provincial     90150.0
# 1  guayaquil, cabecera cantonal y capital provincial     90150.0
# 2  guayaquil, cabecera cantonal y capital provincial     90150.0
# 3  guayaquil, cabecera cantonal y capital provincial     90150.0
# 4  guayaquil, cabecera cantonal y capital provincial     90150.0
# 5  guayaquil, cabecera cantonal y capital provincial     90150.0
# 6  guayaquil, cabecera cantonal y capital provincial     90150.0
# 7  guayaquil, cabecera cantonal y capital provincial     90150.0
# 8  guayaquil, cabecera cantonal y capital provincial     90150.0
# 9  guayaquil, cabecera cantonal y capital provincial     90150.0
#
#                                    archivo_origen Unnamed: 7
# 0  emergencias_2021_completo_georreferenciado.csv        NaN
# 1  emergencias_2021_completo_georreferenciado.csv        NaN
# 2  emergencias_2021_completo_georreferenciado.csv        NaN
# 3  emergencias_2021_completo_georreferenciado.csv        NaN
# 4  emergencias_2021_completo_georreferenciado.csv        NaN
# 5  emergencias_2021_completo_georreferenciado.csv        NaN
# 6  emergencias_2021_completo_georreferenciado.csv        NaN
# 7  emergencias_2021_completo_georreferenciado.csv        NaN
# 8  emergencias_2021_completo_georreferenciado.csv        NaN
# 9  emergencias_2021_completo_georreferenciado.csv        NaN
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 6
#       3 print(df_emergencias_total.head(10))
#       5 # para verlo en forma de tabla
# ----> 6 df_emergencias_total.style.set_properties(**{'text-align': 'left'})
#
# File c:\Users\JPbau\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\displayhook.py:279, in DisplayHook.__call__(self, result)
#     277 self.start_displayhook()
#     278 self.write_output_prompt()
# --> 279 format_dict, md_dict = self.compute_format_data(result)
#     280 self.update_user_ns(result)
#     281 self.fill_exec_result(result)
#
# File c:\Users\JPbau\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\displayhook.py:164, in DisplayHook.compute_format_data(self, result)
#     134 def compute_format_data(self, result):
#     135     """Compute format data of the object to be displayed.
#     136
#     137     The format data is a generalization of the :func:`repr` of an object.
#    (...)    162
#     163     """
# --> 164     return self.shell.display_formatter.format(result)
#
# File c:\Users\JPbau\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\formatters.py:238, in DisplayFormatter.format(self, obj, include, exclude)
#     236 md = None
#     237 try:
# --> 238     data = formatter(obj)
#     239 except:
#     240     # FIXME: log the exception
#     241     raise
#
# File c:\Users\JPbau\AppData\Local\Programs\Python\Python312\Lib\site-packages\decorator.py:235, in decorate.<locals>.fun(*args, **kw)
#     233 if not kwsyntax:
#     234     args, kw = fix(args, kw, sig)
# --> 235 return caller(func, *(extras + args), **kw)
#
# File c:\Users\JPbau\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\formatters.py:282, in catch_format_error(method, self, *args, **kwargs)
#     280 """show traceback on failed format call"""
#     281 try:
# --> 282     r = method(self, *args, **kwargs)
#     283 except NotImplementedError:
#     284     # don't warn on NotImplementedErrors
#     285     return self._check_return(None, args[0])
#
# File c:\Users\JPbau\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\formatters.py:406, in BaseFormatter.__call__(self, obj)
#     404     method = get_real_method(obj, self.print_method)
#     405     if method is not None:
# --> 406         return method()
#     407     return None
#     408 else:
#
# File c:\Users\JPbau\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\formats\style.py:405, in Styler._repr_html_(self)
#     400 """
#     401 Hooks into Jupyter notebook rich display system, which calls _repr_html_ by
#     402 default if an object is returned at the end of a cell.
#     403 """
#     404 if get_option("styler.render.repr") == "html":
# --> 405     return self.to_html()
#     406 return None
#
# File c:\Users\JPbau\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\formats\style.py:1345, in Styler.to_html(self, buf, table_uuid, table_attributes, sparse_index, sparse_columns, bold_headers, caption, max_rows, max_columns, encoding, doctype_html, exclude_styles, **kwargs)
#    1342     obj.set_caption(caption)
#    1344 # Build HTML string..
# -> 1345 html = obj._render_html(
#    1346     sparse_index=sparse_index,
#    1347     sparse_columns=sparse_columns,
#    1348     max_rows=max_rows,
#    1349     max_cols=max_columns,
#    1350     exclude_styles=exclude_styles,
#    1351     encoding=encoding or get_option("styler.render.encoding"),
#    1352     doctype_html=doctype_html,
#    1353     **kwargs,
#    1354 )
#    1356 return save_to_buffer(
#    1357     html, buf=buf, encoding=(encoding if buf is not None else None)
#    1358 )
#
# File c:\Users\JPbau\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\formats\style_render.py:204, in StylerRenderer._render_html(self, sparse_index, sparse_columns, max_rows, max_cols, **kwargs)
#     192 def _render_html(
#     193     self,
#     194     sparse_index: bool,
#    (...)    198     **kwargs,
#     199 ) -> str:
#     200     """
#     201     Renders the ``Styler`` including all applied styles to HTML.
#     202     Generates a dict with necessary kwargs passed to jinja2 template.
#     203     """
# --> 204     d = self._render(sparse_index, sparse_columns, max_rows, max_cols, "&nbsp;")
#     205     d.update(kwargs)
#     206     return self.template_html.render(
#     207         **d,
#     208         html_table_tpl=self.template_html_table,
#     209         html_style_tpl=self.template_html_style,
#     210     )
#
# File c:\Users\JPbau\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\formats\style_render.py:161, in StylerRenderer._render(self, sparse_index, sparse_columns, max_rows, max_cols, blank)
#     147 def _render(
#     148     self,
#     149     sparse_index: bool,
#    (...)    153     blank: str = "",
#     154 ):
#     155     """
#     156     Computes and applies styles and then generates the general render dicts.
#     157
#     158     Also extends the `ctx` and `ctx_index` attributes with those of concatenated
#     159     stylers for use within `_translate_latex`
#     160     """
# --> 161     self._compute()
#     162     dxs = []
#     163     ctx_len = len(self.index)
#
# File c:\Users\JPbau\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\formats\style_render.py:256, in StylerRenderer._compute(self)
#     254 r = self
#     255 for func, args, kwargs in self._todo:
# --> 256     r = func(self)(*args, **kwargs)
#     257 return r
#
# File c:\Users\JPbau\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\formats\style.py:2028, in Styler._map(self, func, subset, **kwargs)
#    2026 subset = non_reducing_slice(subset)
#    2027 result = self.data.loc[subset].map(func)
# -> 2028 self._update_ctx(result)
#    2029 return self
#
# File c:\Users\JPbau\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\formats\style.py:1560, in Styler._update_ctx(self, attrs)
#    1558 if not c or pd.isna(c):
#    1559     continue
# -> 1560 css_list = maybe_convert_css_to_tuples(c)
#    1561 i = self.index.get_loc(rn)
#    1562 self.ctx[(i, j)].extend(css_list)
#
# File c:\Users\JPbau\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\formats\style_render.py:1920, in maybe_convert_css_to_tuples(style)
#    1917 s = style.split(";")
#    1918 try:
#    1919     return [
# -> 1920         (x.split(":")[0].strip(), x.split(":")[1].strip())
#    1921         for x in s
#    1922         if x.strip() != ""
#    1923     ]
#    1924 except IndexError:
#    1925     raise ValueError(
#    1926         "Styles supplied as string must follow CSS rule formats, "
#    1927         f"for example 'attr: val;'. '{style}' was given."
#    1928     )
#
# KeyboardInterrupt:

# %%
import pandas as pd

# %%
df_agosto = pd.read_csv("emergencias_agosto_2021_georreferenciado.csv")
df_agosto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319896 entries, 0 to 319895
# Data columns (total 11 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Fecha          319896 non-null  object
#  1   provincia      319896 non-null  object
#  2   Canton         319896 non-null  object
#  3   Cod_Parroquia  319896 non-null  int64
#  4   Parroquia      319896 non-null  object
#  5   Servicio       319896 non-null  object
#  6   Subtipo        319896 non-null  object
#  7   prov_norm      319896 non-null  object
#  8   canton_norm    319896 non-null  object
#  9   parr_norm      319896 non-null  object
#  10  DPA_PARROQ     319883 non-null  float64
# dtypes: float64(1), int64(1), object(9)
# memory usage: 26.8+ MB

# %%
# Ver las filas donde DPA_PARROQ es NaN (vacío)
filas_sin_codigo = df_agosto[df_agosto['DPA_PARROQ'].isna()]
print(filas_sin_codigo)

# O si quieres verlas una por una
for index, row in filas_sin_codigo.iterrows():
    print(row)
# Out:
#              Fecha provincia                 Canton  Cod_Parroquia  \
# 85324   2021-08-05     azuay  camilo ponce enriquez          11551
# 87044   2021-08-04     azuay  camilo ponce enriquez          11551
# 100177  2021-08-11     azuay  camilo ponce enriquez          11551
# 119225  2021-08-13  orellana               aguarico         220254
# 125696  2021-08-13     azuay  camilo ponce enriquez          11551
# 144637  2021-08-06     azuay  camilo ponce enriquez          11551
# 175709  2021-08-20     azuay  camilo ponce enriquez          11551
# 222088  2021-08-17     azuay  camilo ponce enriquez          11551
# 241580  2021-08-23     azuay  camilo ponce enriquez          11551
# 247629  2021-08-23     azuay  camilo ponce enriquez          11551
# 258977  2021-08-26  orellana               aguarico         220254
# 283710  2021-08-29     azuay  camilo ponce enriquez          11551
# 284223  2021-08-29     azuay  camilo ponce enriquez          11551
#
#                   Parroquia               Servicio  \
# 85324   el carmen de pijili      gestion sanitaria
# 87044   el carmen de pijili   transito y movilidad
# 100177  el carmen de pijili      gestion sanitaria
# 119225             tiputini      gestion sanitaria
# 125696  el carmen de pijili      gestion sanitaria
# 144637  el carmen de pijili  gestion de siniestros
# 175709  el carmen de pijili      gestion sanitaria
# 222088  el carmen de pijili  gestion de siniestros
# 241580  el carmen de pijili    seguridad ciudadana
# 247629  el carmen de pijili    seguridad ciudadana
# 258977             tiputini    seguridad ciudadana
# 283710  el carmen de pijili    seguridad ciudadana
# 284223  el carmen de pijili    seguridad ciudadana
#
#                                             Subtipo prov_norm  \
# 85324                         alergias / anafilaxis     azuay
# 87044                          denuncias / campanas     azuay
# 100177                        transporte secundario     azuay
# 119225                        transporte secundario  orellana
# 125696                                      alcohol     azuay
# 144637                  abrir viviendas / vehiculos     azuay
# 175709                           mal estado general     azuay
# 222088                                      rescate     azuay
# 241580  patrullaje policial en el sector solicitado     azuay
# 247629                            ruidos molestosos     azuay
# 258977                           presencia policial  orellana
# 283710  patrullaje policial en el sector solicitado     azuay
# 284223  patrullaje policial en el sector solicitado     azuay
#
#                   canton_norm            parr_norm  DPA_PARROQ
# 85324   camilo ponce enriquez  el carmen de pijili         NaN
# 87044   camilo ponce enriquez  el carmen de pijili         NaN
# 100177  camilo ponce enriquez  el carmen de pijili         NaN
# 119225               aguarico             tiputini         NaN
# 125696  camilo ponce enriquez  el carmen de pijili         NaN
# 144637  camilo ponce enriquez  el carmen de pijili         NaN
# 175709  camilo ponce enriquez  el carmen de pijili         NaN
# 222088  camilo ponce enriquez  el carmen de pijili         NaN
# 241580  camilo ponce enriquez  el carmen de pijili         NaN
# 247629  camilo ponce enriquez  el carmen de pijili         NaN
# 258977               aguarico             tiputini         NaN
# 283710  camilo ponce enriquez  el carmen de pijili         NaN
# 284223  camilo ponce enriquez  el carmen de pijili         NaN
# Fecha                       2021-08-05
# provincia                        azuay
# Canton           camilo ponce enriquez
# Cod_Parroquia                    11551
# Parroquia          el carmen de pijili
# Servicio             gestion sanitaria
# Subtipo          alergias / anafilaxis
# prov_norm                        azuay
# canton_norm      camilo ponce enriquez
# parr_norm          el carmen de pijili
# DPA_PARROQ                         NaN
# Name: 85324, dtype: object
# Fecha                       2021-08-04
# provincia                        azuay
# Canton           camilo ponce enriquez
# Cod_Parroquia                    11551
# Parroquia          el carmen de pijili
# Servicio          transito y movilidad
# Subtipo           denuncias / campanas
# prov_norm                        azuay
# canton_norm      camilo ponce enriquez
# parr_norm          el carmen de pijili
# DPA_PARROQ                         NaN
# Name: 87044, dtype: object
# Fecha                       2021-08-11
# provincia                        azuay
# Canton           camilo ponce enriquez
# Cod_Parroquia                    11551
# Parroquia          el carmen de pijili
# Servicio             gestion sanitaria
# Subtipo          transporte secundario
# prov_norm                        azuay
# canton_norm      camilo ponce enriquez
# parr_norm          el carmen de pijili
# DPA_PARROQ                         NaN
# Name: 100177, dtype: object
# Fecha                       2021-08-13
# provincia                     orellana
# Canton                        aguarico
# Cod_Parroquia                   220254
# Parroquia                     tiputini
# Servicio             gestion sanitaria
# Subtipo          transporte secundario
# prov_norm                     orellana
# canton_norm                   aguarico
# parr_norm                     tiputini
# DPA_PARROQ                         NaN
# Name: 119225, dtype: object
# Fecha                       2021-08-13
# provincia                        azuay
# Canton           camilo ponce enriquez
# Cod_Parroquia                    11551
# Parroquia          el carmen de pijili
# Servicio             gestion sanitaria
# Subtipo                        alcohol
# prov_norm                        azuay
# canton_norm      camilo ponce enriquez
# parr_norm          el carmen de pijili
# DPA_PARROQ                         NaN
# Name: 125696, dtype: object
# Fecha                             2021-08-06
# provincia                              azuay
# Canton                 camilo ponce enriquez
# Cod_Parroquia                          11551
# Parroquia                el carmen de pijili
# Servicio               gestion de siniestros
# Subtipo          abrir viviendas / vehiculos
# prov_norm                              azuay
# canton_norm            camilo ponce enriquez
# parr_norm                el carmen de pijili
# DPA_PARROQ                               NaN
# Name: 144637, dtype: object
# Fecha                       2021-08-20
# provincia                        azuay
# Canton           camilo ponce enriquez
# Cod_Parroquia                    11551
# Parroquia          el carmen de pijili
# Servicio             gestion sanitaria
# Subtipo             mal estado general
# prov_norm                        azuay
# canton_norm      camilo ponce enriquez
# parr_norm          el carmen de pijili
# DPA_PARROQ                         NaN
# Name: 175709, dtype: object
# Fecha                       2021-08-17
# provincia                        azuay
# Canton           camilo ponce enriquez
# Cod_Parroquia                    11551
# Parroquia          el carmen de pijili
# Servicio         gestion de siniestros
# Subtipo                        rescate
# prov_norm                        azuay
# canton_norm      camilo ponce enriquez
# parr_norm          el carmen de pijili
# DPA_PARROQ                         NaN
# Name: 222088, dtype: object
# Fecha                                             2021-08-23
# provincia                                              azuay
# Canton                                 camilo ponce enriquez
# Cod_Parroquia                                          11551
# Parroquia                                el carmen de pijili
# Servicio                                 seguridad ciudadana
# Subtipo          patrullaje policial en el sector solicitado
# prov_norm                                              azuay
# canton_norm                            camilo ponce enriquez
# parr_norm                                el carmen de pijili
# DPA_PARROQ                                               NaN
# Name: 241580, dtype: object
# Fecha                       2021-08-23
# provincia                        azuay
# Canton           camilo ponce enriquez
# Cod_Parroquia                    11551
# Parroquia          el carmen de pijili
# Servicio           seguridad ciudadana
# Subtipo              ruidos molestosos
# prov_norm                        azuay
# canton_norm      camilo ponce enriquez
# parr_norm          el carmen de pijili
# DPA_PARROQ                         NaN
# Name: 247629, dtype: object
# Fecha                     2021-08-26
# provincia                   orellana
# Canton                      aguarico
# Cod_Parroquia                 220254
# Parroquia                   tiputini
# Servicio         seguridad ciudadana
# Subtipo           presencia policial
# prov_norm                   orellana
# canton_norm                 aguarico
# parr_norm                   tiputini
# DPA_PARROQ                       NaN
# Name: 258977, dtype: object
# Fecha                                             2021-08-29
# provincia                                              azuay
# Canton                                 camilo ponce enriquez
# Cod_Parroquia                                          11551
# Parroquia                                el carmen de pijili
# Servicio                                 seguridad ciudadana
# Subtipo          patrullaje policial en el sector solicitado
# prov_norm                                              azuay
# canton_norm                            camilo ponce enriquez
# parr_norm                                el carmen de pijili
# DPA_PARROQ                                               NaN
# Name: 283710, dtype: object
# Fecha                                             2021-08-29
# provincia                                              azuay
# Canton                                 camilo ponce enriquez
# Cod_Parroquia                                          11551
# Parroquia                                el carmen de pijili
# Servicio                                 seguridad ciudadana
# Subtipo          patrullaje policial en el sector solicitado
# prov_norm                                              azuay
# canton_norm                            camilo ponce enriquez
# parr_norm                                el carmen de pijili
# DPA_PARROQ                                               NaN
# Name: 284223, dtype: object

# %% [markdown]
# # Procesamiento de todos los años

# %%
# ============================================================
# PROCESAMIENTO MULTI-AÑO DE DATOS DE EMERGENCIAS (2022-2025)
# NAVEGACIÓN CON RUTAS RELATIVAS DESDE DataHUB
# ============================================================

import pandas as pd
import sys
import os
import glob
from pathlib import Path

# ============================================================
# DETECTAR Y CONFIGURAR DIRECTORIOS
# ============================================================

# Obtener directorio actual (debería ser DataHUB/2021 donde está el notebook)
DIR_ACTUAL = Path.cwd()

# Navegar al directorio padre (DataHUB)
DIR_DATAHUB = DIR_ACTUAL.parent

print("=" * 80)
print("CONFIGURACIÓN DE DIRECTORIOS")
print("=" * 80)
print(f"📁 Directorio actual (notebook): {DIR_ACTUAL}")
print(f"📁 Directorio DataHUB (padre): {DIR_DATAHUB}")

# Cambiar al directorio DataHUB como base
os.chdir(str(DIR_DATAHUB))
print(f"✅ Directorio de trabajo cambiado a: {Path.cwd()}")
print("=" * 80 + "\n")

# Agregar directorio 2021 al path para importar funciones
sys.path.insert(0, str(DIR_DATAHUB / '2021'))

# Importar funciones de procesamiento
from procesar_todos_emergencias import (
    norm_nombre,
    norm_provincia,
    load_emergencias,
    clean_emergencias,
    load_inec_codificacion,
    mapear_parroquias_inec,
    reporte_geocodificacion,
    pipeline_georreferenciacion
)

# ============================================================
# CONFIGURACIÓN
# ============================================================

# Años a procesar (2021 ya está procesado)
ANIOS = ['2022', '2023', '2024', '2025']

# ============================================================
# FUNCIÓN PRINCIPAL DE PROCESAMIENTO MULTI-AÑO
# ============================================================

def procesar_multianio():
    """
    Procesa todos los archivos de emergencias en los directorios 2022-2025.
    Usa rutas relativas desde DataHUB para navegar entre directorios.
    """
    
    # Verificar que estamos en DataHUB
    dir_base = Path.cwd()
    print(f"📍 Directorio base: {dir_base.name} ({dir_base})\n")
    
    # Estadísticas consolidadas
    estadisticas_totales = []
    
    # Procesar cada año
    for año in ANIOS:
        print("\n" + "=" * 80)
        print(f"PROCESANDO AÑO: {año}")
        print("=" * 80)
        
        # Navegar al directorio del año usando ruta relativa
        dir_año = Path(año)  # Ruta relativa desde DataHUB
        
        # Verificar que el directorio existe
        if not dir_año.exists():
            print(f"⚠️  Directorio no encontrado: {dir_año}")
            print(f"   Ruta buscada: {dir_año.absolute()}")
            print(f"   Saltando año {año}...\n")
            continue
        
        # Construir ruta al archivo de codificación INEC usando ruta relativa
        inec_path = dir_año / f'CODIFICACIÓN_{año}.xlsx'
        
        # Cargar codificación INEC específica del año
        print(f"📂 Cargando codificación INEC desde: {inec_path}")
        
        try:
            dataI = pd.read_excel(str(inec_path), header=0, skiprows=1)
            dataI = dataI.dropna(axis=1, how="any")
            print(f"✅ Codificación INEC {año} cargada: {dataI.shape[0]} parroquias\n")
        except FileNotFoundError:
            print(f"❌ ERROR: No se encontró {inec_path}")
            print(f"   Ruta completa: {inec_path.absolute()}")
            print(f"   Saltando año {año}...\n")
            continue
        except Exception as e:
            print(f"❌ ERROR al cargar INEC {año}: {str(e)}")
            print(f"   Saltando año {año}...\n")
            continue
        
        # Cambiar al directorio del año
        os.chdir(str(dir_año))
        print(f"📁 Navegado a: {año}/ (ruta completa: {Path.cwd()})")
        
        # Buscar archivos de emergencias usando ruta relativa
        archivos_emergencias = glob.glob("emergencias_*.csv")
        
        # Filtrar archivos ya georreferenciados
        archivos_sin_procesar = [
            f for f in archivos_emergencias 
            if not f.endswith('_georreferenciado.csv')
        ]
        
        if not archivos_sin_procesar:
            print(f"ℹ️  No se encontraron archivos sin procesar en {año}/")
            # Volver a DataHUB
            os.chdir(str(dir_base))
            continue
        
        print(f"📊 Archivos encontrados en {año}/: {len(archivos_sin_procesar)}")
        for archivo in archivos_sin_procesar:
            print(f"   - {archivo}")
        print()
        
        # Procesar cada archivo
        archivos_exitosos = 0
        archivos_fallidos = 0
        
        for path_emerg in archivos_sin_procesar:
            try:
                # Ejecutar pipeline de georreferenciación
                df_geo = pipeline_georreferenciacion(path_emerg, dataI)
                
                # Crear nombre del archivo de salida
                nombre_base = os.path.splitext(path_emerg)[0]
                output_path = f"{nombre_base}_georreferenciado.csv"
                
                # Guardar resultado en el mismo directorio (ruta relativa)
                df_geo.to_csv(output_path, index=False, encoding='utf-8')
                print(f"✅ Guardado: {año}/{output_path}\n")
                
                # Guardar estadísticas
                total = len(df_geo)
                con_codigo = df_geo['DPA_PARROQ'].notna().sum()
                estadisticas_totales.append({
                    'año': año,
                    'archivo': path_emerg,
                    'total_registros': total,
                    'georreferenciados': con_codigo,
                    'sin_georreferenciar': total - con_codigo,
                    'porcentaje_exito': (con_codigo / total * 100) if total > 0 else 0
                })
                
                archivos_exitosos += 1
                
            except Exception as e:
                print(f"❌ ERROR al procesar {path_emerg}: {str(e)}\n")
                archivos_fallidos += 1
                continue
        
        print(f"{'=' * 80}")
        print(f"RESUMEN AÑO {año}:")
        print(f"  ✅ Archivos procesados exitosamente: {archivos_exitosos}")
        print(f"  ❌ Archivos con errores: {archivos_fallidos}")
        print(f"{'=' * 80}")
        
        # Volver al directorio DataHUB (ruta relativa)
        os.chdir(str(dir_base))
        print(f"🔙 Volviendo a: DataHUB/ ({Path.cwd()})\n")
    
    # Mostrar estadísticas consolidadas
    if estadisticas_totales:
        print("\n" + "=" * 80)
        print("ESTADÍSTICAS CONSOLIDADAS - TODOS LOS AÑOS")
        print("=" * 80)
        
        df_stats = pd.DataFrame(estadisticas_totales)
        
        # Resumen por año
        print("\n📊 RESUMEN POR AÑO:")
        resumen_año = df_stats.groupby('año').agg({
            'total_registros': 'sum',
            'georreferenciados': 'sum',
            'sin_georreferenciar': 'sum'
        }).reset_index()
        
        resumen_año['% éxito'] = (
            resumen_año['georreferenciados'] / resumen_año['total_registros'] * 100
        ).round(2)
        
        print(resumen_año.to_string(index=False))
        
        # Resumen total
        print("\n📊 RESUMEN TOTAL:")
        total_general = df_stats['total_registros'].sum()
        geo_general = df_stats['georreferenciados'].sum()
        sin_geo_general = df_stats['sin_georreferenciar'].sum()
        
        print(f"  Total de registros procesados: {total_general:,}")
        print(f"  Registros georreferenciados: {geo_general:,} ({geo_general/total_general*100:.2f}%)")
        print(f"  Registros sin georreferenciar: {sin_geo_general:,} ({sin_geo_general/total_general*100:.2f}%)")
        
        # Tabla detallada por archivo
        print("\n📋 DETALLE POR ARCHIVO:")
        df_stats_display = df_stats.copy()
        df_stats_display['porcentaje_exito'] = df_stats_display['porcentaje_exito'].round(2)
        print(df_stats_display.to_string(index=False))
        
    print("\n" + "=" * 80)
    print("✅ PROCESAMIENTO MULTI-AÑO COMPLETADO")
    print("=" * 80)


# ============================================================
# EJECUTAR PROCESAMIENTO
# ============================================================

# Ejecutar la función principal
procesar_multianio()
# Out:
# ================================================================================
# CONFIGURACIÓN DE DIRECTORIOS
# ================================================================================
# 📁 Directorio actual (notebook): c:\
# 📁 Directorio DataHUB (padre): c:\
# ✅ Directorio de trabajo cambiado a: c:\
# ================================================================================
#
# 📍 Directorio base:  (c:\)
#
#
# ================================================================================
# PROCESANDO AÑO: 2022
# ================================================================================
# ⚠️  Directorio no encontrado: 2022
#    Ruta buscada: c:\2022
#    Saltando año 2022...
#
#
# ================================================================================
# PROCESANDO AÑO: 2023
# ================================================================================
# ⚠️  Directorio no encontrado: 2023
#    Ruta buscada: c:\2023
#    Saltando año 2023...
#
#
# ================================================================================
# PROCESANDO AÑO: 2024
# ================================================================================
# ⚠️  Directorio no encontrado: 2024
#    Ruta buscada: c:\2024
#    Saltando año 2024...
#
#
# ================================================================================
# PROCESANDO AÑO: 2025
# ================================================================================
# ⚠️  Directorio no encontrado: 2025
#    Ruta buscada: c:\2025
#    Saltando año 2025...
#
#
# ================================================================================
# ✅ PROCESAMIENTO MULTI-AÑO COMPLETADO
# ================================================================================

# %% [markdown]
# #  Todos los tipos de patrones

# %%
# ============================================================
# PROCESAMIENTO MULTI-AÑO DE DATOS DE EMERGENCIAS (2022-2025)
# NAVEGACIÓN CON RUTAS RELATIVAS DESDE DataHUB
# ============================================================

import pandas as pd
import sys
import os
import glob
from pathlib import Path

# ============================================================
# DETECTAR Y CONFIGURAR DIRECTORIOS
# ============================================================

# Obtener directorio actual (debería ser DataHUB/2021 donde está el notebook)
# ============================================================
# DETECTAR Y CONFIGURAR DIRECTORIOS
# ============================================================

# Usar ruta fija al directorio DataHUB
DIR_DATAHUB = Path(r'C:\Users\JPbau\OneDrive\Documents\8vo\DataHUB')

# Obtener directorio actual para referencia
DIR_ACTUAL = Path.cwd()

print("=" * 80)
print("CONFIGURACIÓN DE DIRECTORIOS")
print("=" * 80)
print(f"📁 Directorio actual (notebook): {DIR_ACTUAL}")
print(f"📁 Directorio DataHUB (fijo): {DIR_DATAHUB}")

# Verificar que el directorio DataHUB existe
if not DIR_DATAHUB.exists():
    print(f"❌ ERROR: El directorio DataHUB no existe: {DIR_DATAHUB}")
    raise FileNotFoundError(f"No se encontró el directorio: {DIR_DATAHUB}")

# Cambiar al directorio DataHUB como base
os.chdir(str(DIR_DATAHUB))
print(f"✅ Directorio de trabajo cambiado a: {Path.cwd()}")
print("=" * 80 + "\n")

# Agregar directorio 2021 al path para importar funciones
sys.path.insert(0, str(DIR_DATAHUB / '2021'))

# Importar funciones de procesamiento
from procesar_todos_emergencias import (
    norm_nombre,
    norm_provincia,
    load_emergencias,
    clean_emergencias,
    load_inec_codificacion,
    mapear_parroquias_inec,
    reporte_geocodificacion,
    pipeline_georreferenciacion
)

# ============================================================
# CONFIGURACIÓN
# ============================================================

# Años a procesar (2021 ya está procesado)
AÑOS = ['2022', '2023', '2024', '2025']

# Patrones de archivos a buscar
PATRONES_ARCHIVOS = ['emergencias_*.csv', 'incidentes_*.csv']

# ============================================================
# FUNCIÓN PRINCIPAL DE PROCESAMIENTO MULTI-AÑO
# ============================================================

def procesar_multianio():
    """
    Procesa todos los archivos de emergencias e incidentes en los directorios 2022-2025.
    Busca archivos con patrones: emergencias_*.csv e incidentes_*.csv
    Usa rutas relativas desde DataHUB para navegar entre directorios.
    """
    
    # Verificar que estamos en DataHUB
    dir_base = Path.cwd()
    print(f"📍 Directorio base: {dir_base.name} ({dir_base})\n")
    
    # Estadísticas consolidadas
    estadisticas_totales = []
    
    # Procesar cada año
    for año in AÑOS:
        print("\n" + "=" * 80)
        print(f"PROCESANDO AÑO: {año}")
        print("=" * 80)
        
        # Navegar al directorio del año usando ruta relativa
        dir_año = Path(año)  # Ruta relativa desde DataHUB
        
        # Verificar que el directorio existe
        if not dir_año.exists():
            print(f"⚠️  Directorio no encontrado: {dir_año}")
            print(f"   Ruta buscada: {dir_año.absolute()}")
            print(f"   Saltando año {año}...\n")
            continue
        
        # Construir ruta al archivo de codificación INEC usando ruta relativa
        inec_path = dir_año / f'CODIFICACIÓN_{año}.xlsx'
        
        # Cargar codificación INEC específica del año
        print(f"📂 Cargando codificación INEC desde: {inec_path}")
        
        try:
            dataI = pd.read_excel(str(inec_path), header=0, skiprows=1)
            dataI = dataI.dropna(axis=1, how="any")
            print(f"✅ Codificación INEC {año} cargada: {dataI.shape[0]} parroquias\n")
        except FileNotFoundError:
            print(f"❌ ERROR: No se encontró {inec_path}")
            print(f"   Ruta completa: {inec_path.absolute()}")
            print(f"   Saltando año {año}...\n")
            continue
        except Exception as e:
            print(f"❌ ERROR al cargar INEC {año}: {str(e)}")
            print(f"   Saltando año {año}...\n")
            continue
        
        # Cambiar al directorio del año
        os.chdir(str(dir_año))
        print(f"📁 Navegado a: {año}/ (ruta completa: {Path.cwd()})")
        
        # Buscar archivos con múltiples patrones
        print(f"\n🔍 Buscando archivos con patrones: {', '.join(PATRONES_ARCHIVOS)}")
        archivos_encontrados = []
        
        for patron in PATRONES_ARCHIVOS:
            archivos = glob.glob(patron)
            if archivos:
                print(f"   - Patrón '{patron}': {len(archivos)} archivo(s)")
                archivos_encontrados.extend(archivos)
        
        # Filtrar archivos ya georreferenciados
        archivos_sin_procesar = [
            f for f in archivos_encontrados 
            if not f.endswith('_georreferenciado.csv')
        ]
        
        # Eliminar duplicados (por si acaso)
        archivos_sin_procesar = list(set(archivos_sin_procesar))
        
        if not archivos_sin_procesar:
            print(f"ℹ️  No se encontraron archivos sin procesar en {año}/")
            # Volver a DataHUB
            os.chdir(str(dir_base))
            continue
        
        print(f"\n📊 Total de archivos a procesar en {año}/: {len(archivos_sin_procesar)}")
        for archivo in sorted(archivos_sin_procesar):
            print(f"   - {archivo}")
        print()
        
        # Procesar cada archivo
        archivos_exitosos = 0
        archivos_fallidos = 0
        
        for path_emerg in archivos_sin_procesar:
            try:
                # Ejecutar pipeline de georreferenciación
                df_geo = pipeline_georreferenciacion(path_emerg, dataI)
                
                # Crear nombre del archivo de salida
                nombre_base = os.path.splitext(path_emerg)[0]
                output_path = f"{nombre_base}_georreferenciado.csv"
                
                # Guardar resultado en el mismo directorio (ruta relativa)
                df_geo.to_csv(output_path, index=False, encoding='utf-8')
                print(f"✅ Guardado: {año}/{output_path}\n")
                
                # Guardar estadísticas
                total = len(df_geo)
                con_codigo = df_geo['DPA_PARROQ'].notna().sum()
                estadisticas_totales.append({
                    'año': año,
                    'archivo': path_emerg,
                    'total_registros': total,
                    'georreferenciados': con_codigo,
                    'sin_georreferenciar': total - con_codigo,
                    'porcentaje_exito': (con_codigo / total * 100) if total > 0 else 0
                })
                
                archivos_exitosos += 1
                
            except Exception as e:
                print(f"❌ ERROR al procesar {path_emerg}: {str(e)}\n")
                archivos_fallidos += 1
                continue
        
        print(f"{'=' * 80}")
        print(f"RESUMEN AÑO {año}:")
        print(f"  ✅ Archivos procesados exitosamente: {archivos_exitosos}")
        print(f"  ❌ Archivos con errores: {archivos_fallidos}")
        print(f"{'=' * 80}")
        
        # Volver al directorio DataHUB (ruta relativa)
        os.chdir(str(dir_base))
        print(f"🔙 Volviendo a: DataHUB/ ({Path.cwd()})\n")
    
    # Mostrar estadísticas consolidadas
    if estadisticas_totales:
        print("\n" + "=" * 80)
        print("ESTADÍSTICAS CONSOLIDADAS - TODOS LOS AÑOS")
        print("=" * 80)
        
        df_stats = pd.DataFrame(estadisticas_totales)
        
        # Resumen por año
        print("\n📊 RESUMEN POR AÑO:")
        resumen_año = df_stats.groupby('año').agg({
            'total_registros': 'sum',
            'georreferenciados': 'sum',
            'sin_georreferenciar': 'sum'
        }).reset_index()
        
        resumen_año['% éxito'] = (
            resumen_año['georreferenciados'] / resumen_año['total_registros'] * 100
        ).round(2)
        
        print(resumen_año.to_string(index=False))
        
        # Resumen total
        print("\n📊 RESUMEN TOTAL:")
        total_general = df_stats['total_registros'].sum()
        geo_general = df_stats['georreferenciados'].sum()
        sin_geo_general = df_stats['sin_georreferenciar'].sum()
        
        print(f"  Total de registros procesados: {total_general:,}")
        print(f"  Registros georreferenciados: {geo_general:,} ({geo_general/total_general*100:.2f}%)")
        print(f"  Registros sin georreferenciar: {sin_geo_general:,} ({sin_geo_general/total_general*100:.2f}%)")
        
        # Tabla detallada por archivo
        print("\n📋 DETALLE POR ARCHIVO:")
        df_stats_display = df_stats.copy()
        df_stats_display['porcentaje_exito'] = df_stats_display['porcentaje_exito'].round(2)
        print(df_stats_display.to_string(index=False))
        
    print("\n" + "=" * 80)
    print("✅ PROCESAMIENTO MULTI-AÑO COMPLETADO")
    print("=" * 80)


# ============================================================
# EJECUTAR PROCESAMIENTO
# ============================================================

# Ejecutar la función principal
procesar_multianio()
# Out:
# ================================================================================
# CONFIGURACIÓN DE DIRECTORIOS
# ================================================================================
# 📁 Directorio actual (notebook): c:\
# 📁 Directorio DataHUB (fijo): C:\Users\JPbau\OneDrive\Documents\8vo\DataHUB
# ✅ Directorio de trabajo cambiado a: C:\Users\JPbau\OneDrive\Documents\8vo\DataHUB
# ================================================================================
#
# 📍 Directorio base: DataHUB (C:\Users\JPbau\OneDrive\Documents\8vo\DataHUB)
#
#
# ================================================================================
# PROCESANDO AÑO: 2022
# ================================================================================
# 📂 Cargando codificación INEC desde: 2022\CODIFICACIÓN_2022.xlsx
# ✅ Codificación INEC 2022 cargada: 1042 parroquias
#
# 📁 Navegado a: 2022/ (ruta completa: C:\Users\JPbau\OneDrive\Documents\8vo\DataHUB\2022)
#
# 🔍 Buscando archivos con patrones: emergencias_*.csv, incidentes_*.csv
#    - Patrón 'emergencias_*.csv': 12 archivo(s)
#
# 📊 Total de archivos a procesar en 2022/: 12
#    - emergencias_abril_2022.csv
#    - emergencias_agosto_2022.csv
#    - emergencias_diciembre_2022.csv
#    - emergencias_enero_2022.csv
#    - emergencias_febrero_2022.csv
#    - emergencias_julio_2022.csv
#    - emergencias_junio_2022.csv
#    - emergencias_marzo_2022.csv
#    - emergencias_mayo_2022.csv
#    - emergencias_noviembre_2022.csv
#    - emergencias_octubre_2022.csv
#    - emergencias_septiembre_2022.csv
#
#
# ============================================================
# Procesando: emergencias_octubre_2022.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 97
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 306659
# Con código INEC (DPA_PARROQ): 306647 (100.00%)
# Sin código INEC: 12 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 43536   orellana               aguarico             tiputini
# 138662     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2022/emergencias_octubre_2022_georreferenciado.csv
#
#
# ============================================================
# Procesando: emergencias_agosto_2022.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 102
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 296358
# Con código INEC (DPA_PARROQ): 296351 (100.00%)
# Sin código INEC: 7 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 43155   orellana               aguarico             tiputini
# 101856     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2022/emergencias_agosto_2022_georreferenciado.csv
#
#
# ============================================================
# Procesando: emergencias_noviembre_2022.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 89
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 287205
# Con código INEC (DPA_PARROQ): 287195 (100.00%)
# Sin código INEC: 10 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 11610   orellana               aguarico             tiputini
# 126693     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2022/emergencias_noviembre_2022_georreferenciado.csv
#
#
# ============================================================
# Procesando: emergencias_abril_2022.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 93
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 311646
# Con código INEC (DPA_PARROQ): 311633 (100.00%)
# Sin código INEC: 13 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 204     orellana               aguarico             tiputini
# 291078     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2022/emergencias_abril_2022_georreferenciado.csv
#
#
# ============================================================
# Procesando: emergencias_mayo_2022.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 109
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 318690
# Con código INEC (DPA_PARROQ): 318686 (100.00%)
# Sin código INEC: 4 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 37252   orellana               aguarico             tiputini
# 140578     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2022/emergencias_mayo_2022_georreferenciado.csv
#
#
# ============================================================
# Procesando: emergencias_marzo_2022.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 104
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 312697
# Con código INEC (DPA_PARROQ): 312692 (100.00%)
# Sin código INEC: 5 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 137340     azuay  camilo ponce enriquez  el carmen de pijili
# 172930  orellana               aguarico             tiputini
# ✅ Guardado: 2022/emergencias_marzo_2022_georreferenciado.csv
#
#
# ============================================================
# Procesando: emergencias_julio_2022.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 102
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 309235
# Con código INEC (DPA_PARROQ): 309222 (100.00%)
# Sin código INEC: 13 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 43448   orellana               aguarico             tiputini
# 131952     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2022/emergencias_julio_2022_georreferenciado.csv
#
#
# ============================================================
# Procesando: emergencias_enero_2022.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 83
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 304492
# Con código INEC (DPA_PARROQ): 304484 (100.00%)
# Sin código INEC: 8 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 12245   orellana               aguarico             tiputini
# 116825     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2022/emergencias_enero_2022_georreferenciado.csv
#
#
# ============================================================
# Procesando: emergencias_junio_2022.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 104
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 291698
# Con código INEC (DPA_PARROQ): 291692 (100.00%)
# Sin código INEC: 6 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 116002     azuay  camilo ponce enriquez  el carmen de pijili
# 174958  orellana               aguarico             tiputini
# ✅ Guardado: 2022/emergencias_junio_2022_georreferenciado.csv
#
#
# ============================================================
# Procesando: emergencias_septiembre_2022.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 95
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 294045
# Con código INEC (DPA_PARROQ): 294035 (100.00%)
# Sin código INEC: 10 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 19316   orellana               aguarico             tiputini
# 132463     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2022/emergencias_septiembre_2022_georreferenciado.csv
#
#
# ============================================================
# Procesando: emergencias_diciembre_2022.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 78
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 302289
# Con código INEC (DPA_PARROQ): 302277 (100.00%)
# Sin código INEC: 12 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 54441   orellana               aguarico             tiputini
# 134907     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2022/emergencias_diciembre_2022_georreferenciado.csv
#
#
# ============================================================
# Procesando: emergencias_febrero_2022.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 76
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 293958
# Con código INEC (DPA_PARROQ): 293951 (100.00%)
# Sin código INEC: 7 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 99411      azuay  camilo ponce enriquez  el carmen de pijili
# 230899  orellana               aguarico             tiputini
# ✅ Guardado: 2022/emergencias_febrero_2022_georreferenciado.csv
#
# ================================================================================
# RESUMEN AÑO 2022:
#   ✅ Archivos procesados exitosamente: 12
#   ❌ Archivos con errores: 0
# ================================================================================
# 🔙 Volviendo a: DataHUB/ (C:\Users\JPbau\OneDrive\Documents\8vo\DataHUB)
#
#
# ================================================================================
# PROCESANDO AÑO: 2023
# ================================================================================
# 📂 Cargando codificación INEC desde: 2023\CODIFICACIÓN_2023.xlsx
# ✅ Codificación INEC 2023 cargada: 1043 parroquias
#
# 📁 Navegado a: 2023/ (ruta completa: C:\Users\JPbau\OneDrive\Documents\8vo\DataHUB\2023)
#
# 🔍 Buscando archivos con patrones: emergencias_*.csv, incidentes_*.csv
#    - Patrón 'emergencias_*.csv': 12 archivo(s)
#
# 📊 Total de archivos a procesar en 2023/: 12
#    - emergencias_abril_2023.csv
#    - emergencias_agosto_2023.csv
#    - emergencias_diciembre_2023.csv
#    - emergencias_enero_2023.csv
#    - emergencias_febrero_2023.csv
#    - emergencias_julio_2023.csv
#    - emergencias_junio_2023.csv
#    - emergencias_marzo_2023.csv
#    - emergencias_mayo_2023.csv
#    - emergencias_noviembre_2023.csv
#    - emergencias_octubre_2023.csv
#    - emergencias_septiembre_2023.csv
#
#
# ============================================================
# Procesando: emergencias_febrero_2023.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 80
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 270533
# Con código INEC (DPA_PARROQ): 270523 (100.00%)
# Sin código INEC: 10 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 34916   orellana               aguarico             tiputini
# 113753     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2023/emergencias_febrero_2023_georreferenciado.csv
#
#
# ============================================================
# Procesando: emergencias_marzo_2023.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 66
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 289406
# Con código INEC (DPA_PARROQ): 289403 (100.00%)
# Sin código INEC: 3 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 132429     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2023/emergencias_marzo_2023_georreferenciado.csv
#
#
# ============================================================
# Procesando: emergencias_mayo_2023.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 80
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 291284
# Con código INEC (DPA_PARROQ): 291274 (100.00%)
# Sin código INEC: 10 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 38162      azuay  camilo ponce enriquez  el carmen de pijili
# 225994  orellana               aguarico             tiputini
# ✅ Guardado: 2023/emergencias_mayo_2023_georreferenciado.csv
#
#
# ============================================================
# Procesando: emergencias_julio_2023.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 76
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 295308
# Con código INEC (DPA_PARROQ): 295301 (100.00%)
# Sin código INEC: 7 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 32764   orellana               aguarico             tiputini
# 152184     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2023/emergencias_julio_2023_georreferenciado.csv
#
#
# ============================================================
# Procesando: emergencias_abril_2023.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 80
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 289331
# Con código INEC (DPA_PARROQ): 289324 (100.00%)
# Sin código INEC: 7 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 15260   orellana               aguarico             tiputini
# 220287     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2023/emergencias_abril_2023_georreferenciado.csv
#
#
# ============================================================
# Procesando: emergencias_enero_2023.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 73
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 286362
# Con código INEC (DPA_PARROQ): 286349 (100.00%)
# Sin código INEC: 13 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 2548    orellana               aguarico             tiputini
# 123478     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2023/emergencias_enero_2023_georreferenciado.csv
#
#
# ============================================================
# Procesando: emergencias_agosto_2023.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 81
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 284284
# Con código INEC (DPA_PARROQ): 284282 (100.00%)
# Sin código INEC: 2 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#       provincia                 Canton            Parroquia
# 12120  orellana               aguarico             tiputini
# 99525     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2023/emergencias_agosto_2023_georreferenciado.csv
#
#
# ============================================================
# Procesando: emergencias_diciembre_2023.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 92
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 299559
# Con código INEC (DPA_PARROQ): 299547 (100.00%)
# Sin código INEC: 12 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 5875    orellana               aguarico             tiputini
# 146906     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2023/emergencias_diciembre_2023_georreferenciado.csv
#
#
# ============================================================
# Procesando: emergencias_junio_2023.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 79
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 290166
# Con código INEC (DPA_PARROQ): 290158 (100.00%)
# Sin código INEC: 8 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#       provincia                 Canton            Parroquia
# 4222   orellana               aguarico             tiputini
# 40831     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2023/emergencias_junio_2023_georreferenciado.csv
#
#
# ============================================================
# Procesando: emergencias_octubre_2023.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 83
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 288964
# Con código INEC (DPA_PARROQ): 288955 (100.00%)
# Sin código INEC: 9 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 15464   orellana               aguarico             tiputini
# 124554     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2023/emergencias_octubre_2023_georreferenciado.csv
#
#
# ============================================================
# Procesando: emergencias_septiembre_2023.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 74
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 287072
# Con código INEC (DPA_PARROQ): 287062 (100.00%)
# Sin código INEC: 10 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#       provincia                 Canton            Parroquia
# 38227     azuay  camilo ponce enriquez  el carmen de pijili
# 83248  orellana               aguarico             tiputini
# ✅ Guardado: 2023/emergencias_septiembre_2023_georreferenciado.csv
#
#
# ============================================================
# Procesando: emergencias_noviembre_2023.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 101
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 273855
# Con código INEC (DPA_PARROQ): 273853 (100.00%)
# Sin código INEC: 2 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 193638     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2023/emergencias_noviembre_2023_georreferenciado.csv
#
# ================================================================================
# RESUMEN AÑO 2023:
#   ✅ Archivos procesados exitosamente: 12
#   ❌ Archivos con errores: 0
# ================================================================================
# 🔙 Volviendo a: DataHUB/ (C:\Users\JPbau\OneDrive\Documents\8vo\DataHUB)
#
#
# ================================================================================
# PROCESANDO AÑO: 2024
# ================================================================================
# 📂 Cargando codificación INEC desde: 2024\CODIFICACIÓN_2024.xlsx
# ✅ Codificación INEC 2024 cargada: 1047 parroquias
#
# 📁 Navegado a: 2024/ (ruta completa: C:\Users\JPbau\OneDrive\Documents\8vo\DataHUB\2024)
#
# 🔍 Buscando archivos con patrones: emergencias_*.csv, incidentes_*.csv
#    - Patrón 'incidentes_*.csv': 12 archivo(s)
#
# 📊 Total de archivos a procesar en 2024/: 12
#    - incidentes_abril_2024.csv
#    - incidentes_agosto_2024.csv
#    - incidentes_diciembre2024.csv
#    - incidentes_enero_2024.csv
#    - incidentes_febrero_2024.csv
#    - incidentes_julio_2024.csv
#    - incidentes_junio_2024.csv
#    - incidentes_marzo_2024.csv
#    - incidentes_mayo_2024.csv
#    - incidentes_noviembre2024.csv
#    - incidentes_octubre2024.csv
#    - incidentes_septiembre2024.csv
#
#
# ============================================================
# Procesando: incidentes_septiembre2024.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 67
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 279880
# Con código INEC (DPA_PARROQ): 279865 (99.99%)
# Sin código INEC: 15 (0.01%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 120127  orellana               aguarico             tiputini
# 213243     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2024/incidentes_septiembre2024_georreferenciado.csv
#
#
# ============================================================
# Procesando: incidentes_enero_2024.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 51
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 208143
# Con código INEC (DPA_PARROQ): 208141 (100.00%)
# Sin código INEC: 2 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 42384   orellana               aguarico             tiputini
# 113657     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2024/incidentes_enero_2024_georreferenciado.csv
#
#
# ============================================================
# Procesando: incidentes_abril_2024.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 92
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 271900
# Con código INEC (DPA_PARROQ): 271896 (100.00%)
# Sin código INEC: 4 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 29333   orellana               aguarico             tiputini
# 108648     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2024/incidentes_abril_2024_georreferenciado.csv
#
#
# ============================================================
# Procesando: incidentes_mayo_2024.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 63
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 278041
# Con código INEC (DPA_PARROQ): 278031 (100.00%)
# Sin código INEC: 10 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 20070   orellana               aguarico             tiputini
# 127381     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2024/incidentes_mayo_2024_georreferenciado.csv
#
#
# ============================================================
# Procesando: incidentes_noviembre2024.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 61
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 279528
# Con código INEC (DPA_PARROQ): 279515 (100.00%)
# Sin código INEC: 13 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 103587     azuay  camilo ponce enriquez  el carmen de pijili
# 239741  orellana               aguarico             tiputini
# ✅ Guardado: 2024/incidentes_noviembre2024_georreferenciado.csv
#
#
# ============================================================
# Procesando: incidentes_marzo_2024.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 116
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 291103
# Con código INEC (DPA_PARROQ): 291091 (100.00%)
# Sin código INEC: 12 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#       provincia                 Canton            Parroquia
# 17586  orellana               aguarico             tiputini
# 67308     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2024/incidentes_marzo_2024_georreferenciado.csv
#
#
# ============================================================
# Procesando: incidentes_febrero_2024.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 88
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 276756
# Con código INEC (DPA_PARROQ): 276751 (100.00%)
# Sin código INEC: 5 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 47936   orellana               aguarico             tiputini
# 128265     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2024/incidentes_febrero_2024_georreferenciado.csv
#
#
# ============================================================
# Procesando: incidentes_diciembre2024.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 72
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 297251
# Con código INEC (DPA_PARROQ): 297234 (99.99%)
# Sin código INEC: 17 (0.01%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 131226  orellana               aguarico             tiputini
# 225078     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2024/incidentes_diciembre2024_georreferenciado.csv
#
#
# ============================================================
# Procesando: incidentes_octubre2024.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 71
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 294423
# Con código INEC (DPA_PARROQ): 294418 (100.00%)
# Sin código INEC: 5 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia    Canton Parroquia
# 237389  orellana  aguarico  tiputini
# ✅ Guardado: 2024/incidentes_octubre2024_georreferenciado.csv
#
#
# ============================================================
# Procesando: incidentes_julio_2024.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 75
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 268214
# Con código INEC (DPA_PARROQ): 268199 (99.99%)
# Sin código INEC: 15 (0.01%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#               provincia                 Canton  \
# 86038          orellana               aguarico
# 249903            azuay  camilo ponce enriquez
# 265379  morona santiago                 morona
# 265393  morona santiago                 morona
# 266023            azuay                 cuenca
#
#                                             Parroquia
# 86038                                        tiputini
# 249903                            el carmen de pijili
# 265379  macas, cabecera cantonal y capital provincial
# 265393                              sevilla don bosco
# 266023                                         cuenca
# ✅ Guardado: 2024/incidentes_julio_2024_georreferenciado.csv
#
#
# ============================================================
# Procesando: incidentes_junio_2024.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 74
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 277003
# Con código INEC (DPA_PARROQ): 276994 (100.00%)
# Sin código INEC: 9 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 12871   orellana               aguarico             tiputini
# 113660     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2024/incidentes_junio_2024_georreferenciado.csv
#
#
# ============================================================
# Procesando: incidentes_agosto_2024.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 70
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 269501
# Con código INEC (DPA_PARROQ): 269487 (99.99%)
# Sin código INEC: 14 (0.01%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#               provincia                 Canton                 Parroquia
# 1247              azuay  camilo ponce enriquez       el carmen de pijili
# 23501   morona santiago                  sucua  sucua, cabecera cantonal
# 199537         orellana               aguarico                  tiputini
# ✅ Guardado: 2024/incidentes_agosto_2024_georreferenciado.csv
#
# ================================================================================
# RESUMEN AÑO 2024:
#   ✅ Archivos procesados exitosamente: 12
#   ❌ Archivos con errores: 0
# ================================================================================
# 🔙 Volviendo a: DataHUB/ (C:\Users\JPbau\OneDrive\Documents\8vo\DataHUB)
#
#
# ================================================================================
# PROCESANDO AÑO: 2025
# ================================================================================
# 📂 Cargando codificación INEC desde: 2025\CODIFICACIÓN_2025.xlsx
# ✅ Codificación INEC 2025 cargada: 1049 parroquias
#
# 📁 Navegado a: 2025/ (ruta completa: C:\Users\JPbau\OneDrive\Documents\8vo\DataHUB\2025)
#
# 🔍 Buscando archivos con patrones: emergencias_*.csv, incidentes_*.csv
#    - Patrón 'incidentes_*.csv': 8 archivo(s)
#
# 📊 Total de archivos a procesar en 2025/: 8
#    - incidentes_abril_2025.csv
#    - incidentes_agosto_2025.csv
#    - incidentes_enero_2025.csv
#    - incidentes_febrero_2025.csv
#    - incidentes_julio_2025.csv
#    - incidentes_junio_2025.csv
#    - incidentes_marzo_2025.csv
#    - incidentes_mayo_2025.csv
#
#
# ============================================================
# Procesando: incidentes_agosto_2025.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 111
# 3) Cargando codificación INEC...
# ❌ ERROR al procesar incidentes_agosto_2025.csv: "['DPA_DESPRO', 'DPA_CANTON', 'DPA_DESCAN', 'DPA_PARROQ', 'DPA_DESPAR'] not in index"
#
#
# ============================================================
# Procesando: incidentes_marzo_2025.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 112
# 3) Cargando codificación INEC...
# ❌ ERROR al procesar incidentes_marzo_2025.csv: "['DPA_DESPRO', 'DPA_CANTON', 'DPA_DESCAN', 'DPA_PARROQ', 'DPA_DESPAR'] not in index"
#
#
# ============================================================
# Procesando: incidentes_junio_2025.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 98
# 3) Cargando codificación INEC...
# ❌ ERROR al procesar incidentes_junio_2025.csv: "['DPA_DESPRO', 'DPA_CANTON', 'DPA_DESCAN', 'DPA_PARROQ', 'DPA_DESPAR'] not in index"
#
#
# ============================================================
# Procesando: incidentes_enero_2025.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 75
# 3) Cargando codificación INEC...
# ❌ ERROR al procesar incidentes_enero_2025.csv: "['DPA_DESPRO', 'DPA_CANTON', 'DPA_DESCAN', 'DPA_PARROQ', 'DPA_DESPAR'] not in index"
#
#
# ============================================================
# Procesando: incidentes_febrero_2025.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 65
# 3) Cargando codificación INEC...
# ❌ ERROR al procesar incidentes_febrero_2025.csv: "['DPA_DESPRO', 'DPA_CANTON', 'DPA_DESCAN', 'DPA_PARROQ', 'DPA_DESPAR'] not in index"
#
#
# ============================================================
# Procesando: incidentes_abril_2025.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 113
# 3) Cargando codificación INEC...
# ❌ ERROR al procesar incidentes_abril_2025.csv: "['DPA_DESPRO', 'DPA_CANTON', 'DPA_DESCAN', 'DPA_PARROQ', 'DPA_DESPAR'] not in index"
#
#
# ============================================================
# Procesando: incidentes_julio_2025.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 116
# 3) Cargando codificación INEC...
# ❌ ERROR al procesar incidentes_julio_2025.csv: "['DPA_DESPRO', 'DPA_CANTON', 'DPA_DESCAN', 'DPA_PARROQ', 'DPA_DESPAR'] not in index"
#
#
# ============================================================
# Procesando: incidentes_mayo_2025.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 116
# 3) Cargando codificación INEC...
# ❌ ERROR al procesar incidentes_mayo_2025.csv: "['DPA_DESPRO', 'DPA_CANTON', 'DPA_DESCAN', 'DPA_PARROQ', 'DPA_DESPAR'] not in index"
#
# ================================================================================
# RESUMEN AÑO 2025:
#   ✅ Archivos procesados exitosamente: 0
#   ❌ Archivos con errores: 8
# ================================================================================
# 🔙 Volviendo a: DataHUB/ (C:\Users\JPbau\OneDrive\Documents\8vo\DataHUB)
#
#
# ================================================================================
# ESTADÍSTICAS CONSOLIDADAS - TODOS LOS AÑOS
# ================================================================================
#
# 📊 RESUMEN POR AÑO:
#  año  total_registros  georreferenciados  sin_georreferenciar  % éxito
# 2022          3628972            3628865                  107    100.0
# 2023          3446124            3446031                   93    100.0
# 2024          3291743            3291622                  121    100.0
#
# 📊 RESUMEN TOTAL:
#   Total de registros procesados: 10,366,839
#   Registros georreferenciados: 10,366,518 (100.00%)
#   Registros sin georreferenciar: 321 (0.00%)
#
# 📋 DETALLE POR ARCHIVO:
#  año                         archivo  total_registros  georreferenciados  sin_georreferenciar  porcentaje_exito
# 2022    emergencias_octubre_2022.csv           306659             306647                   12            100.00
# 2022     emergencias_agosto_2022.csv           296358             296351                    7            100.00
# 2022  emergencias_noviembre_2022.csv           287205             287195                   10            100.00
# 2022      emergencias_abril_2022.csv           311646             311633                   13            100.00
# 2022       emergencias_mayo_2022.csv           318690             318686                    4            100.00
# 2022      emergencias_marzo_2022.csv           312697             312692                    5            100.00
# 2022      emergencias_julio_2022.csv           309235             309222                   13            100.00
# 2022      emergencias_enero_2022.csv           304492             304484                    8            100.00
# 2022      emergencias_junio_2022.csv           291698             291692                    6            100.00
# 2022 emergencias_septiembre_2022.csv           294045             294035                   10            100.00
# 2022  emergencias_diciembre_2022.csv           302289             302277                   12            100.00
# 2022    emergencias_febrero_2022.csv           293958             293951                    7            100.00
# 2023    emergencias_febrero_2023.csv           270533             270523                   10            100.00
# 2023      emergencias_marzo_2023.csv           289406             289403                    3            100.00
# 2023       emergencias_mayo_2023.csv           291284             291274                   10            100.00
# 2023      emergencias_julio_2023.csv           295308             295301                    7            100.00
# 2023      emergencias_abril_2023.csv           289331             289324                    7            100.00
# 2023      emergencias_enero_2023.csv           286362             286349                   13            100.00
# 2023     emergencias_agosto_2023.csv           284284             284282                    2            100.00
# 2023  emergencias_diciembre_2023.csv           299559             299547                   12            100.00
# 2023      emergencias_junio_2023.csv           290166             290158                    8            100.00
# 2023    emergencias_octubre_2023.csv           288964             288955                    9            100.00
# 2023 emergencias_septiembre_2023.csv           287072             287062                   10            100.00
# 2023  emergencias_noviembre_2023.csv           273855             273853                    2            100.00
# 2024   incidentes_septiembre2024.csv           279880             279865                   15             99.99
# 2024       incidentes_enero_2024.csv           208143             208141                    2            100.00
# 2024       incidentes_abril_2024.csv           271900             271896                    4            100.00
# 2024        incidentes_mayo_2024.csv           278041             278031                   10            100.00
# 2024    incidentes_noviembre2024.csv           279528             279515                   13            100.00
# 2024       incidentes_marzo_2024.csv           291103             291091                   12            100.00
# 2024     incidentes_febrero_2024.csv           276756             276751                    5            100.00
# 2024    incidentes_diciembre2024.csv           297251             297234                   17             99.99
# 2024      incidentes_octubre2024.csv           294423             294418                    5            100.00
# 2024       incidentes_julio_2024.csv           268214             268199                   15             99.99
# 2024       incidentes_junio_2024.csv           277003             276994                    9            100.00
# 2024      incidentes_agosto_2024.csv           269501             269487                   14             99.99
#
# ================================================================================
# ✅ PROCESAMIENTO MULTI-AÑO COMPLETADO
# ================================================================================

# %%
# Ejecuta esto en una celda para ver qué columnas tiene CODIFICACIÓN_2025.xlsx
import pandas as pd
ruta_2025 = r'C:\Users\JPbau\OneDrive\Documents\8vo\DataHUB\2025\CODIFICACIÓN_2025.xlsx'
df_2025 = pd.read_excel(ruta_2025, header=0, skiprows=1)
print("Columnas en CODIFICACIÓN_2025.xlsx:")
print(df_2025.columns.tolist())
# Out:
# Columnas en CODIFICACIÓN_2025.xlsx:
# ['Unnamed: 0', 'DPA_PROVIN', 'DPA_DESPRO', 'DPA_CANTON', 'DPA_DESCAN', 'DPA_PARROQ', 'DPA_DESPAR']

# %% [markdown]
# # Ultimo intento

# %%
# PROCESAMIENTO MULTI-AÑO DE DATOS DE EMERGENCIAS (2022-2025)
# NAVEGACIÓN CON RUTAS RELATIVAS DESDE DataHUB
# ============================================================

import pandas as pd
import sys
import os
import glob
from pathlib import Path

# ============================================================
# DETECTAR Y CONFIGURAR DIRECTORIOS
# ============================================================

# Usar ruta fija al directorio DataHUB
DIR_DATAHUB = Path(r'C:\Users\JPbau\OneDrive\Documents\8vo\DataHUB')

# Obtener directorio actual para referencia
DIR_ACTUAL = Path.cwd()

print("=" * 80)
print("CONFIGURACIÓN DE DIRECTORIOS")
print("=" * 80)
print(f"📁 Directorio actual (notebook): {DIR_ACTUAL}")
print(f"📁 Directorio DataHUB (fijo): {DIR_DATAHUB}")

# Verificar que el directorio DataHUB existe
if not DIR_DATAHUB.exists():
    print(f"❌ ERROR: El directorio DataHUB no existe: {DIR_DATAHUB}")
    raise FileNotFoundError(f"No se encontró el directorio: {DIR_DATAHUB}")

# Cambiar al directorio DataHUB como base
os.chdir(str(DIR_DATAHUB))
print(f"✅ Directorio de trabajo cambiado a: {Path.cwd()}")
print("=" * 80 + "\n")

# Agregar directorio 2021 al path para importar funciones
sys.path.insert(0, str(DIR_DATAHUB / '2021'))

from procesar_todos_emergencias import (
    norm_nombre,
    norm_provincia,
    load_emergencias,
    clean_emergencias,
    mapear_parroquias_inec,
    reporte_geocodificacion,
    pipeline_georreferenciacion
)

# ============================================================
# CONFIGURACIÓN
# ============================================================

AÑOS = ['2022', '2023', '2024', '2025']
PATRONES_ARCHIVOS = ['emergencias_*.csv', 'incidentes_*.csv']

# ============================================================
# FUNCIÓN PRINCIPAL DE PROCESAMIENTO MULTI-AÑO
# ============================================================

def procesar_multianio():
    """
    Procesa todos los archivos de emergencias e incidentes en los directorios 2022-2025.
    Busca archivos con patrones: emergencias_*.csv e incidentes_*.csv
    Usa rutas relativas desde DataHUB para navegar entre directorios.
    """
    
    dir_base = Path.cwd()
    print(f"📍 Directorio base: {dir_base.name} ({dir_base})\n")
    
    estadisticas_totales = []
    
    for año in AÑOS:
        print("\n" + "=" * 80)
        print(f"PROCESANDO AÑO: {año}")
        print("=" * 80)
        
        dir_año = Path(año)
        
        if not dir_año.exists():
            print(f"⚠️  Directorio no encontrado: {dir_año}")
            print(f"   Ruta buscada: {dir_año.absolute()}")
            print(f"   Saltando año {año}...\n")
            continue
        
        inec_path = dir_año / f'CODIFICACIÓN_{año}.xlsx'
        
        print(f"📂 Cargando codificación INEC desde: {inec_path}")
        
        try:
            # Cargar archivo Excel
            dataI = pd.read_excel(str(inec_path), header=0, skiprows=1)
            
            # Eliminar columna Unnamed: 0 si existe
            if 'Unnamed: 0' in dataI.columns:
                dataI = dataI.drop(columns=['Unnamed: 0'])
            
            # Verificar columnas necesarias
            cols_necesarias = ['DPA_PROVIN', 'DPA_DESPRO', 'DPA_CANTON', 
                             'DPA_DESCAN', 'DPA_PARROQ', 'DPA_DESPAR']
            
            cols_faltantes = [col for col in cols_necesarias if col not in dataI.columns]
            if cols_faltantes:
                print(f"   ❌ Columnas faltantes: {cols_faltantes}")
                print(f"   📋 Columnas disponibles: {dataI.columns.tolist()}")
                raise ValueError(f"Faltan columnas en CODIFICACIÓN_{año}.xlsx")
            
            # Seleccionar solo columnas necesarias
            dataI = dataI[cols_necesarias].copy()
            
            # Normalizar nombres
            dataI['prov_norm']   = dataI['DPA_DESPRO'].apply(norm_nombre)
            dataI['canton_norm'] = dataI['DPA_DESCAN'].apply(norm_nombre)
            dataI['parr_norm']   = dataI['DPA_DESPAR'].apply(norm_nombre)
            
            print(f"✅ Codificación INEC {año} cargada: {dataI.shape[0]} parroquias\n")
            
        except FileNotFoundError:
            print(f"❌ ERROR: No se encontró {inec_path}")
            print(f"   Ruta completa: {inec_path.absolute()}")
            print(f"   Saltando año {año}...\n")
            continue
        except Exception as e:
            print(f"❌ ERROR al cargar INEC {año}: {str(e)}")
            print(f"   Saltando año {año}...\n")
            continue
        
        os.chdir(str(dir_año))
        print(f"📁 Navegado a: {año}/ (ruta completa: {Path.cwd()})")
        
        print(f"\n🔍 Buscando archivos con patrones: {', '.join(PATRONES_ARCHIVOS)}")
        archivos_encontrados = []
        
        for patron in PATRONES_ARCHIVOS:
            archivos = glob.glob(patron)
            if archivos:
                print(f"   - Patrón '{patron}': {len(archivos)} archivo(s)")
                archivos_encontrados.extend(archivos)
        
        archivos_sin_procesar = [
            f for f in archivos_encontrados 
            if not f.endswith('_georreferenciado.csv')
        ]
        archivos_sin_procesar = list(set(archivos_sin_procesar))
        
        if not archivos_sin_procesar:
            print(f"ℹ️  No se encontraron archivos sin procesar en {año}/")
            os.chdir(str(dir_base))
            continue
        
        print(f"\n📊 Total de archivos a procesar en {año}/: {len(archivos_sin_procesar)}")
        for archivo in sorted(archivos_sin_procesar):
            print(f"   - {archivo}")
        print()
        
        archivos_exitosos = 0
        archivos_fallidos = 0
        
        for path_emerg in archivos_sin_procesar:
            try:
                df_geo = pipeline_georreferenciacion(path_emerg, dataI)
                
                nombre_base = os.path.splitext(path_emerg)[0]
                output_path = f"{nombre_base}_georreferenciado.csv"
                
                df_geo.to_csv(output_path, index=False, encoding='utf-8')
                print(f"✅ Guardado: {año}/{output_path}\n")
                
                total = len(df_geo)
                con_codigo = df_geo['DPA_PARROQ'].notna().sum()
                estadisticas_totales.append({
                    'año': año,
                    'archivo': path_emerg,
                    'total_registros': total,
                    'georreferenciados': con_codigo,
                    'sin_georreferenciar': total - con_codigo,
                    'porcentaje_exito': (con_codigo / total * 100) if total > 0 else 0
                })
                
                archivos_exitosos += 1
                
            except Exception as e:
                print(f"❌ ERROR al procesar {path_emerg}: {str(e)}\n")
                archivos_fallidos += 1
                continue
        
        print(f"{'=' * 80}")
        print(f"RESUMEN AÑO {año}:")
        print(f"  ✅ Archivos procesados exitosamente: {archivos_exitosos}")
        print(f"  ❌ Archivos con errores: {archivos_fallidos}")
        print(f"{'=' * 80}")
        
        os.chdir(str(dir_base))
        print(f"🔙 Volviendo a: DataHUB/ ({Path.cwd()})\n")
    
    if estadisticas_totales:
        print("\n" + "=" * 80)
        print("ESTADÍSTICAS CONSOLIDADAS - TODOS LOS AÑOS")
        print("=" * 80)
        
        df_stats = pd.DataFrame(estadisticas_totales)
        
        print("\n📊 RESUMEN POR AÑO:")
        resumen_año = df_stats.groupby('año').agg({
            'total_registros': 'sum',
            'georreferenciados': 'sum',
            'sin_georreferenciar': 'sum'
        }).reset_index()
        
        resumen_año['% éxito'] = (
            resumen_año['georreferenciados'] / resumen_año['total_registros'] * 100
        ).round(2)
        
        print(resumen_año.to_string(index=False))
        
        print("\n📊 RESUMEN TOTAL:")
        total_general = df_stats['total_registros'].sum()
        geo_general = df_stats['georreferenciados'].sum()
        sin_geo_general = df_stats['sin_georreferenciar'].sum()
        
        print(f"  Total de registros procesados: {total_general:,}")
        print(f"  Registros georreferenciados: {geo_general:,} ({geo_general/total_general*100:.2f}%)")
        print(f"  Registros sin georreferenciar: {sin_geo_general:,} ({sin_geo_general/total_general*100:.2f}%)")
        
        print("\n📋 DETALLE POR ARCHIVO:")
        df_stats_display = df_stats.copy()
        df_stats_display['porcentaje_exito'] = df_stats_display['porcentaje_exito'].round(2)
        print(df_stats_display.to_string(index=False))
        
    print("\n" + "=" * 80)
    print("✅ PROCESAMIENTO MULTI-AÑO COMPLETADO")
    print("=" * 80)


# ============================================================
# EJECUTAR PROCESAMIENTO
# ============================================================

procesar_multianio()
# Out:
# ================================================================================
# CONFIGURACIÓN DE DIRECTORIOS
# ================================================================================
# 📁 Directorio actual (notebook): C:\Users\JPbau\OneDrive\Documents\8vo\DataHUB
# 📁 Directorio DataHUB (fijo): C:\Users\JPbau\OneDrive\Documents\8vo\DataHUB
# ✅ Directorio de trabajo cambiado a: C:\Users\JPbau\OneDrive\Documents\8vo\DataHUB
# ================================================================================
#
# 📍 Directorio base: DataHUB (C:\Users\JPbau\OneDrive\Documents\8vo\DataHUB)
#
#
# ================================================================================
# PROCESANDO AÑO: 2022
# ================================================================================
# 📂 Cargando codificación INEC desde: 2022\CODIFICACIÓN_2022.xlsx
# ✅ Codificación INEC 2022 cargada: 1042 parroquias
#
# 📁 Navegado a: 2022/ (ruta completa: C:\Users\JPbau\OneDrive\Documents\8vo\DataHUB\2022)
#
# 🔍 Buscando archivos con patrones: emergencias_*.csv, incidentes_*.csv
#    - Patrón 'emergencias_*.csv': 12 archivo(s)
#
# 📊 Total de archivos a procesar en 2022/: 12
#    - emergencias_abril_2022.csv
#    - emergencias_agosto_2022.csv
#    - emergencias_diciembre_2022.csv
#    - emergencias_enero_2022.csv
#    - emergencias_febrero_2022.csv
#    - emergencias_julio_2022.csv
#    - emergencias_junio_2022.csv
#    - emergencias_marzo_2022.csv
#    - emergencias_mayo_2022.csv
#    - emergencias_noviembre_2022.csv
#    - emergencias_octubre_2022.csv
#    - emergencias_septiembre_2022.csv
#
#
# ============================================================
# Procesando: emergencias_octubre_2022.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 97
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 306659
# Con código INEC (DPA_PARROQ): 306647 (100.00%)
# Sin código INEC: 12 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 43536   orellana               aguarico             tiputini
# 138662     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2022/emergencias_octubre_2022_georreferenciado.csv
#
#
# ============================================================
# Procesando: emergencias_agosto_2022.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 102
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 296358
# Con código INEC (DPA_PARROQ): 296351 (100.00%)
# Sin código INEC: 7 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 43155   orellana               aguarico             tiputini
# 101856     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2022/emergencias_agosto_2022_georreferenciado.csv
#
#
# ============================================================
# Procesando: emergencias_noviembre_2022.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 89
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 287205
# Con código INEC (DPA_PARROQ): 287195 (100.00%)
# Sin código INEC: 10 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 11610   orellana               aguarico             tiputini
# 126693     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2022/emergencias_noviembre_2022_georreferenciado.csv
#
#
# ============================================================
# Procesando: emergencias_abril_2022.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 93
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 311646
# Con código INEC (DPA_PARROQ): 311633 (100.00%)
# Sin código INEC: 13 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 204     orellana               aguarico             tiputini
# 291078     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2022/emergencias_abril_2022_georreferenciado.csv
#
#
# ============================================================
# Procesando: emergencias_mayo_2022.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 109
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 318690
# Con código INEC (DPA_PARROQ): 318686 (100.00%)
# Sin código INEC: 4 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 37252   orellana               aguarico             tiputini
# 140578     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2022/emergencias_mayo_2022_georreferenciado.csv
#
#
# ============================================================
# Procesando: emergencias_marzo_2022.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 104
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 312697
# Con código INEC (DPA_PARROQ): 312692 (100.00%)
# Sin código INEC: 5 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 137340     azuay  camilo ponce enriquez  el carmen de pijili
# 172930  orellana               aguarico             tiputini
# ✅ Guardado: 2022/emergencias_marzo_2022_georreferenciado.csv
#
#
# ============================================================
# Procesando: emergencias_julio_2022.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 102
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 309235
# Con código INEC (DPA_PARROQ): 309222 (100.00%)
# Sin código INEC: 13 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 43448   orellana               aguarico             tiputini
# 131952     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2022/emergencias_julio_2022_georreferenciado.csv
#
#
# ============================================================
# Procesando: emergencias_enero_2022.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 83
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 304492
# Con código INEC (DPA_PARROQ): 304484 (100.00%)
# Sin código INEC: 8 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 12245   orellana               aguarico             tiputini
# 116825     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2022/emergencias_enero_2022_georreferenciado.csv
#
#
# ============================================================
# Procesando: emergencias_junio_2022.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 104
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 291698
# Con código INEC (DPA_PARROQ): 291692 (100.00%)
# Sin código INEC: 6 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 116002     azuay  camilo ponce enriquez  el carmen de pijili
# 174958  orellana               aguarico             tiputini
# ✅ Guardado: 2022/emergencias_junio_2022_georreferenciado.csv
#
#
# ============================================================
# Procesando: emergencias_septiembre_2022.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 95
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 294045
# Con código INEC (DPA_PARROQ): 294035 (100.00%)
# Sin código INEC: 10 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 19316   orellana               aguarico             tiputini
# 132463     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2022/emergencias_septiembre_2022_georreferenciado.csv
#
#
# ============================================================
# Procesando: emergencias_diciembre_2022.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 78
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 302289
# Con código INEC (DPA_PARROQ): 302277 (100.00%)
# Sin código INEC: 12 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 54441   orellana               aguarico             tiputini
# 134907     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2022/emergencias_diciembre_2022_georreferenciado.csv
#
#
# ============================================================
# Procesando: emergencias_febrero_2022.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 76
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 293958
# Con código INEC (DPA_PARROQ): 293951 (100.00%)
# Sin código INEC: 7 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 99411      azuay  camilo ponce enriquez  el carmen de pijili
# 230899  orellana               aguarico             tiputini
# ✅ Guardado: 2022/emergencias_febrero_2022_georreferenciado.csv
#
# ================================================================================
# RESUMEN AÑO 2022:
#   ✅ Archivos procesados exitosamente: 12
#   ❌ Archivos con errores: 0
# ================================================================================
# 🔙 Volviendo a: DataHUB/ (C:\Users\JPbau\OneDrive\Documents\8vo\DataHUB)
#
#
# ================================================================================
# PROCESANDO AÑO: 2023
# ================================================================================
# 📂 Cargando codificación INEC desde: 2023\CODIFICACIÓN_2023.xlsx
# ✅ Codificación INEC 2023 cargada: 1043 parroquias
#
# 📁 Navegado a: 2023/ (ruta completa: C:\Users\JPbau\OneDrive\Documents\8vo\DataHUB\2023)
#
# 🔍 Buscando archivos con patrones: emergencias_*.csv, incidentes_*.csv
#    - Patrón 'emergencias_*.csv': 12 archivo(s)
#
# 📊 Total de archivos a procesar en 2023/: 12
#    - emergencias_abril_2023.csv
#    - emergencias_agosto_2023.csv
#    - emergencias_diciembre_2023.csv
#    - emergencias_enero_2023.csv
#    - emergencias_febrero_2023.csv
#    - emergencias_julio_2023.csv
#    - emergencias_junio_2023.csv
#    - emergencias_marzo_2023.csv
#    - emergencias_mayo_2023.csv
#    - emergencias_noviembre_2023.csv
#    - emergencias_octubre_2023.csv
#    - emergencias_septiembre_2023.csv
#
#
# ============================================================
# Procesando: emergencias_febrero_2023.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 80
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 270533
# Con código INEC (DPA_PARROQ): 270523 (100.00%)
# Sin código INEC: 10 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 34916   orellana               aguarico             tiputini
# 113753     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2023/emergencias_febrero_2023_georreferenciado.csv
#
#
# ============================================================
# Procesando: emergencias_marzo_2023.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 66
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 289406
# Con código INEC (DPA_PARROQ): 289403 (100.00%)
# Sin código INEC: 3 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 132429     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2023/emergencias_marzo_2023_georreferenciado.csv
#
#
# ============================================================
# Procesando: emergencias_mayo_2023.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 80
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 291284
# Con código INEC (DPA_PARROQ): 291274 (100.00%)
# Sin código INEC: 10 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 38162      azuay  camilo ponce enriquez  el carmen de pijili
# 225994  orellana               aguarico             tiputini
# ✅ Guardado: 2023/emergencias_mayo_2023_georreferenciado.csv
#
#
# ============================================================
# Procesando: emergencias_julio_2023.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 76
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 295308
# Con código INEC (DPA_PARROQ): 295301 (100.00%)
# Sin código INEC: 7 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 32764   orellana               aguarico             tiputini
# 152184     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2023/emergencias_julio_2023_georreferenciado.csv
#
#
# ============================================================
# Procesando: emergencias_abril_2023.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 80
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 289331
# Con código INEC (DPA_PARROQ): 289324 (100.00%)
# Sin código INEC: 7 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 15260   orellana               aguarico             tiputini
# 220287     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2023/emergencias_abril_2023_georreferenciado.csv
#
#
# ============================================================
# Procesando: emergencias_enero_2023.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 73
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 286362
# Con código INEC (DPA_PARROQ): 286349 (100.00%)
# Sin código INEC: 13 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 2548    orellana               aguarico             tiputini
# 123478     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2023/emergencias_enero_2023_georreferenciado.csv
#
#
# ============================================================
# Procesando: emergencias_agosto_2023.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 81
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 284284
# Con código INEC (DPA_PARROQ): 284282 (100.00%)
# Sin código INEC: 2 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#       provincia                 Canton            Parroquia
# 12120  orellana               aguarico             tiputini
# 99525     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2023/emergencias_agosto_2023_georreferenciado.csv
#
#
# ============================================================
# Procesando: emergencias_diciembre_2023.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 92
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 299559
# Con código INEC (DPA_PARROQ): 299547 (100.00%)
# Sin código INEC: 12 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 5875    orellana               aguarico             tiputini
# 146906     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2023/emergencias_diciembre_2023_georreferenciado.csv
#
#
# ============================================================
# Procesando: emergencias_junio_2023.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 79
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 290166
# Con código INEC (DPA_PARROQ): 290158 (100.00%)
# Sin código INEC: 8 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#       provincia                 Canton            Parroquia
# 4222   orellana               aguarico             tiputini
# 40831     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2023/emergencias_junio_2023_georreferenciado.csv
#
#
# ============================================================
# Procesando: emergencias_octubre_2023.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 83
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 288964
# Con código INEC (DPA_PARROQ): 288955 (100.00%)
# Sin código INEC: 9 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 15464   orellana               aguarico             tiputini
# 124554     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2023/emergencias_octubre_2023_georreferenciado.csv
#
#
# ============================================================
# Procesando: emergencias_septiembre_2023.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 74
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 287072
# Con código INEC (DPA_PARROQ): 287062 (100.00%)
# Sin código INEC: 10 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#       provincia                 Canton            Parroquia
# 38227     azuay  camilo ponce enriquez  el carmen de pijili
# 83248  orellana               aguarico             tiputini
# ✅ Guardado: 2023/emergencias_septiembre_2023_georreferenciado.csv
#
#
# ============================================================
# Procesando: emergencias_noviembre_2023.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 101
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 273855
# Con código INEC (DPA_PARROQ): 273853 (100.00%)
# Sin código INEC: 2 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 193638     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2023/emergencias_noviembre_2023_georreferenciado.csv
#
# ================================================================================
# RESUMEN AÑO 2023:
#   ✅ Archivos procesados exitosamente: 12
#   ❌ Archivos con errores: 0
# ================================================================================
# 🔙 Volviendo a: DataHUB/ (C:\Users\JPbau\OneDrive\Documents\8vo\DataHUB)
#
#
# ================================================================================
# PROCESANDO AÑO: 2024
# ================================================================================
# 📂 Cargando codificación INEC desde: 2024\CODIFICACIÓN_2024.xlsx
# ✅ Codificación INEC 2024 cargada: 1047 parroquias
#
# 📁 Navegado a: 2024/ (ruta completa: C:\Users\JPbau\OneDrive\Documents\8vo\DataHUB\2024)
#
# 🔍 Buscando archivos con patrones: emergencias_*.csv, incidentes_*.csv
#    - Patrón 'incidentes_*.csv': 12 archivo(s)
#
# 📊 Total de archivos a procesar en 2024/: 12
#    - incidentes_abril_2024.csv
#    - incidentes_agosto_2024.csv
#    - incidentes_diciembre2024.csv
#    - incidentes_enero_2024.csv
#    - incidentes_febrero_2024.csv
#    - incidentes_julio_2024.csv
#    - incidentes_junio_2024.csv
#    - incidentes_marzo_2024.csv
#    - incidentes_mayo_2024.csv
#    - incidentes_noviembre2024.csv
#    - incidentes_octubre2024.csv
#    - incidentes_septiembre2024.csv
#
#
# ============================================================
# Procesando: incidentes_septiembre2024.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 67
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 279880
# Con código INEC (DPA_PARROQ): 279865 (99.99%)
# Sin código INEC: 15 (0.01%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 120127  orellana               aguarico             tiputini
# 213243     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2024/incidentes_septiembre2024_georreferenciado.csv
#
#
# ============================================================
# Procesando: incidentes_enero_2024.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 51
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 208143
# Con código INEC (DPA_PARROQ): 208141 (100.00%)
# Sin código INEC: 2 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 42384   orellana               aguarico             tiputini
# 113657     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2024/incidentes_enero_2024_georreferenciado.csv
#
#
# ============================================================
# Procesando: incidentes_abril_2024.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 92
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 271900
# Con código INEC (DPA_PARROQ): 271896 (100.00%)
# Sin código INEC: 4 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 29333   orellana               aguarico             tiputini
# 108648     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2024/incidentes_abril_2024_georreferenciado.csv
#
#
# ============================================================
# Procesando: incidentes_mayo_2024.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 63
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 278041
# Con código INEC (DPA_PARROQ): 278031 (100.00%)
# Sin código INEC: 10 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 20070   orellana               aguarico             tiputini
# 127381     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2024/incidentes_mayo_2024_georreferenciado.csv
#
#
# ============================================================
# Procesando: incidentes_noviembre2024.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 61
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 279528
# Con código INEC (DPA_PARROQ): 279515 (100.00%)
# Sin código INEC: 13 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 103587     azuay  camilo ponce enriquez  el carmen de pijili
# 239741  orellana               aguarico             tiputini
# ✅ Guardado: 2024/incidentes_noviembre2024_georreferenciado.csv
#
#
# ============================================================
# Procesando: incidentes_marzo_2024.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 116
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 291103
# Con código INEC (DPA_PARROQ): 291091 (100.00%)
# Sin código INEC: 12 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#       provincia                 Canton            Parroquia
# 17586  orellana               aguarico             tiputini
# 67308     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2024/incidentes_marzo_2024_georreferenciado.csv
#
#
# ============================================================
# Procesando: incidentes_febrero_2024.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 88
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 276756
# Con código INEC (DPA_PARROQ): 276751 (100.00%)
# Sin código INEC: 5 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 47936   orellana               aguarico             tiputini
# 128265     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2024/incidentes_febrero_2024_georreferenciado.csv
#
#
# ============================================================
# Procesando: incidentes_diciembre2024.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 72
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 297251
# Con código INEC (DPA_PARROQ): 297234 (99.99%)
# Sin código INEC: 17 (0.01%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 131226  orellana               aguarico             tiputini
# 225078     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2024/incidentes_diciembre2024_georreferenciado.csv
#
#
# ============================================================
# Procesando: incidentes_octubre2024.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 71
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 294423
# Con código INEC (DPA_PARROQ): 294418 (100.00%)
# Sin código INEC: 5 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia    Canton Parroquia
# 237389  orellana  aguarico  tiputini
# ✅ Guardado: 2024/incidentes_octubre2024_georreferenciado.csv
#
#
# ============================================================
# Procesando: incidentes_julio_2024.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 75
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 268214
# Con código INEC (DPA_PARROQ): 268199 (99.99%)
# Sin código INEC: 15 (0.01%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#               provincia                 Canton  \
# 86038          orellana               aguarico
# 249903            azuay  camilo ponce enriquez
# 265379  morona santiago                 morona
# 265393  morona santiago                 morona
# 266023            azuay                 cuenca
#
#                                             Parroquia
# 86038                                        tiputini
# 249903                            el carmen de pijili
# 265379  macas, cabecera cantonal y capital provincial
# 265393                              sevilla don bosco
# 266023                                         cuenca
# ✅ Guardado: 2024/incidentes_julio_2024_georreferenciado.csv
#
#
# ============================================================
# Procesando: incidentes_junio_2024.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 74
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 277003
# Con código INEC (DPA_PARROQ): 276994 (100.00%)
# Sin código INEC: 9 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 12871   orellana               aguarico             tiputini
# 113660     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2024/incidentes_junio_2024_georreferenciado.csv
#
#
# ============================================================
# Procesando: incidentes_agosto_2024.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 70
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 269501
# Con código INEC (DPA_PARROQ): 269487 (99.99%)
# Sin código INEC: 14 (0.01%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#               provincia                 Canton                 Parroquia
# 1247              azuay  camilo ponce enriquez       el carmen de pijili
# 23501   morona santiago                  sucua  sucua, cabecera cantonal
# 199537         orellana               aguarico                  tiputini
# ✅ Guardado: 2024/incidentes_agosto_2024_georreferenciado.csv
#
# ================================================================================
# RESUMEN AÑO 2024:
#   ✅ Archivos procesados exitosamente: 12
#   ❌ Archivos con errores: 0
# ================================================================================
# 🔙 Volviendo a: DataHUB/ (C:\Users\JPbau\OneDrive\Documents\8vo\DataHUB)
#
#
# ================================================================================
# PROCESANDO AÑO: 2025
# ================================================================================
# 📂 Cargando codificación INEC desde: 2025\CODIFICACIÓN_2025.xlsx
# ✅ Codificación INEC 2025 cargada: 1049 parroquias
#
# 📁 Navegado a: 2025/ (ruta completa: C:\Users\JPbau\OneDrive\Documents\8vo\DataHUB\2025)
#
# 🔍 Buscando archivos con patrones: emergencias_*.csv, incidentes_*.csv
#    - Patrón 'incidentes_*.csv': 8 archivo(s)
#
# 📊 Total de archivos a procesar en 2025/: 8
#    - incidentes_abril_2025.csv
#    - incidentes_agosto_2025.csv
#    - incidentes_enero_2025.csv
#    - incidentes_febrero_2025.csv
#    - incidentes_julio_2025.csv
#    - incidentes_junio_2025.csv
#    - incidentes_marzo_2025.csv
#    - incidentes_mayo_2025.csv
#
#
# ============================================================
# Procesando: incidentes_agosto_2025.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 111
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 275331
# Con código INEC (DPA_PARROQ): 275322 (100.00%)
# Sin código INEC: 9 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#       provincia                 Canton            Parroquia
# 528    orellana               aguarico             tiputini
# 88785     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2025/incidentes_agosto_2025_georreferenciado.csv
#
#
# ============================================================
# Procesando: incidentes_marzo_2025.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 112
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 277048
# Con código INEC (DPA_PARROQ): 277043 (100.00%)
# Sin código INEC: 5 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#       provincia                 Canton            Parroquia
# 45270     azuay  camilo ponce enriquez  el carmen de pijili
# 98703  orellana               aguarico             tiputini
# ✅ Guardado: 2025/incidentes_marzo_2025_georreferenciado.csv
#
#
# ============================================================
# Procesando: incidentes_junio_2025.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 98
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 271077
# Con código INEC (DPA_PARROQ): 271065 (100.00%)
# Sin código INEC: 12 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 124519     azuay  camilo ponce enriquez  el carmen de pijili
# 215284  orellana               aguarico             tiputini
# ✅ Guardado: 2025/incidentes_junio_2025_georreferenciado.csv
#
#
# ============================================================
# Procesando: incidentes_enero_2025.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 75
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 267715
# Con código INEC (DPA_PARROQ): 267496 (99.92%)
# Sin código INEC: 219 (0.08%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#               provincia                 Canton            Parroquia
# 50531   morona santiago                 morona    sevilla don bosco
# 80875             azuay  camilo ponce enriquez  el carmen de pijili
# 106144         orellana               aguarico             tiputini
# ✅ Guardado: 2025/incidentes_enero_2025_georreferenciado.csv
#
#
# ============================================================
# Procesando: incidentes_febrero_2025.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 65
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 244604
# Con código INEC (DPA_PARROQ): 244515 (99.96%)
# Sin código INEC: 89 (0.04%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#               provincia                 Canton            Parroquia
# 366               azuay  camilo ponce enriquez  el carmen de pijili
# 25780   morona santiago                 morona    sevilla don bosco
# 127274         orellana               aguarico             tiputini
# ✅ Guardado: 2025/incidentes_febrero_2025_georreferenciado.csv
#
#
# ============================================================
# Procesando: incidentes_abril_2025.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 113
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 263353
# Con código INEC (DPA_PARROQ): 263337 (99.99%)
# Sin código INEC: 16 (0.01%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 87108      azuay  camilo ponce enriquez  el carmen de pijili
# 118100  orellana               aguarico             tiputini
# ✅ Guardado: 2025/incidentes_abril_2025_georreferenciado.csv
#
#
# ============================================================
# Procesando: incidentes_julio_2025.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 116
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 268003
# Con código INEC (DPA_PARROQ): 267990 (100.00%)
# Sin código INEC: 13 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#       provincia                 Canton            Parroquia
# 72301  orellana               aguarico             tiputini
# 96531     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2025/incidentes_julio_2025_georreferenciado.csv
#
#
# ============================================================
# Procesando: incidentes_mayo_2025.csv
# ============================================================
# 1) Cargando emergencias...
# 2) Limpiando emergencias...
# [clean_emergencias] Filas eliminadas por provincia None: 116
# 3) Cargando codificación INEC...
# 4) Mapeando parroquias a INEC...
# 5) Reporte de georreferenciación:
# === REPORTE GEOREFERENCIACIÓN ===
# Filas totales: 277852
# Con código INEC (DPA_PARROQ): 277844 (100.00%)
# Sin código INEC: 8 (0.00%)
#
# Ejemplos de parroquias SIN match (provincia / cantón / parroquia):
#        provincia                 Canton            Parroquia
# 53653   orellana               aguarico             tiputini
# 126214     azuay  camilo ponce enriquez  el carmen de pijili
# ✅ Guardado: 2025/incidentes_mayo_2025_georreferenciado.csv
#
# ================================================================================
# RESUMEN AÑO 2025:
#   ✅ Archivos procesados exitosamente: 8
#   ❌ Archivos con errores: 0
# ================================================================================
# 🔙 Volviendo a: DataHUB/ (C:\Users\JPbau\OneDrive\Documents\8vo\DataHUB)
#
#
# ================================================================================
# ESTADÍSTICAS CONSOLIDADAS - TODOS LOS AÑOS
# ================================================================================
#
# 📊 RESUMEN POR AÑO:
#  año  total_registros  georreferenciados  sin_georreferenciar  % éxito
# 2022          3628972            3628865                  107   100.00
# 2023          3446124            3446031                   93   100.00
# 2024          3291743            3291622                  121   100.00
# 2025          2144983            2144612                  371    99.98
#
# 📊 RESUMEN TOTAL:
#   Total de registros procesados: 12,511,822
#   Registros georreferenciados: 12,511,130 (99.99%)
#   Registros sin georreferenciar: 692 (0.01%)
#
# 📋 DETALLE POR ARCHIVO:
#  año                         archivo  total_registros  georreferenciados  sin_georreferenciar  porcentaje_exito
# 2022    emergencias_octubre_2022.csv           306659             306647                   12            100.00
# 2022     emergencias_agosto_2022.csv           296358             296351                    7            100.00
# 2022  emergencias_noviembre_2022.csv           287205             287195                   10            100.00
# 2022      emergencias_abril_2022.csv           311646             311633                   13            100.00
# 2022       emergencias_mayo_2022.csv           318690             318686                    4            100.00
# 2022      emergencias_marzo_2022.csv           312697             312692                    5            100.00
# 2022      emergencias_julio_2022.csv           309235             309222                   13            100.00
# 2022      emergencias_enero_2022.csv           304492             304484                    8            100.00
# 2022      emergencias_junio_2022.csv           291698             291692                    6            100.00
# 2022 emergencias_septiembre_2022.csv           294045             294035                   10            100.00
# 2022  emergencias_diciembre_2022.csv           302289             302277                   12            100.00
# 2022    emergencias_febrero_2022.csv           293958             293951                    7            100.00
# 2023    emergencias_febrero_2023.csv           270533             270523                   10            100.00
# 2023      emergencias_marzo_2023.csv           289406             289403                    3            100.00
# 2023       emergencias_mayo_2023.csv           291284             291274                   10            100.00
# 2023      emergencias_julio_2023.csv           295308             295301                    7            100.00
# 2023      emergencias_abril_2023.csv           289331             289324                    7            100.00
# 2023      emergencias_enero_2023.csv           286362             286349                   13            100.00
# 2023     emergencias_agosto_2023.csv           284284             284282                    2            100.00
# 2023  emergencias_diciembre_2023.csv           299559             299547                   12            100.00
# 2023      emergencias_junio_2023.csv           290166             290158                    8            100.00
# 2023    emergencias_octubre_2023.csv           288964             288955                    9            100.00
# 2023 emergencias_septiembre_2023.csv           287072             287062                   10            100.00
# 2023  emergencias_noviembre_2023.csv           273855             273853                    2            100.00
# 2024   incidentes_septiembre2024.csv           279880             279865                   15             99.99
# 2024       incidentes_enero_2024.csv           208143             208141                    2            100.00
# 2024       incidentes_abril_2024.csv           271900             271896                    4            100.00
# 2024        incidentes_mayo_2024.csv           278041             278031                   10            100.00
# 2024    incidentes_noviembre2024.csv           279528             279515                   13            100.00
# 2024       incidentes_marzo_2024.csv           291103             291091                   12            100.00
# 2024     incidentes_febrero_2024.csv           276756             276751                    5            100.00
# 2024    incidentes_diciembre2024.csv           297251             297234                   17             99.99
# 2024      incidentes_octubre2024.csv           294423             294418                    5            100.00
# 2024       incidentes_julio_2024.csv           268214             268199                   15             99.99
# 2024       incidentes_junio_2024.csv           277003             276994                    9            100.00
# 2024      incidentes_agosto_2024.csv           269501             269487                   14             99.99
# 2025      incidentes_agosto_2025.csv           275331             275322                    9            100.00
# 2025       incidentes_marzo_2025.csv           277048             277043                    5            100.00
# 2025       incidentes_junio_2025.csv           271077             271065                   12            100.00
# 2025       incidentes_enero_2025.csv           267715             267496                  219             99.92
# 2025     incidentes_febrero_2025.csv           244604             244515                   89             99.96
# 2025       incidentes_abril_2025.csv           263353             263337                   16             99.99
# 2025       incidentes_julio_2025.csv           268003             267990                   13            100.00
# 2025        incidentes_mayo_2025.csv           277852             277844                    8            100.00
#
# ================================================================================
# ✅ PROCESAMIENTO MULTI-AÑO COMPLETADO
# ================================================================================

# %%
# Deseo unir todos los archivos emergencias georeferenciadas en un solo archivo de todos los anios
from unir_georreferenciados import unir_archivos_georreferenciados

# ============================================================
# UNIR ARCHIVOS GEORREFERENCIADOS POR AÑO
# ============================================================

import pandas as pd
import glob
import os
from pathlib import Path

# ============================================================
# CONFIGURACIÓN
# ============================================================

# Ruta fija al directorio DataHUB
DIR_DATAHUB = Path(r'C:\Users\JPbau\OneDrive\Documents\8vo\DataHUB')

# Años a procesar
AÑOS = ['2022', '2023', '2024', '2025']

# Patrones de archivos georreferenciados a buscar
PATRONES = ['emergencias_*_georreferenciado.csv', 'incidentes_*_georreferenciado.csv']

# ============================================================
# FUNCIÓN PARA UNIR ARCHIVOS DE UN AÑO
# ============================================================

def unir_archivos_por_año(año: str, dir_año: Path):
    """
    Une todos los archivos georreferenciados de un año específico en un solo archivo.
    
    Args:
        año: Año a procesar (ej: '2022')
        dir_año: Path al directorio del año
    """
    print("\n" + "=" * 80)
    print(f"UNIENDO ARCHIVOS GEORREFERENCIADOS - AÑO {año}")
    print("=" * 80)
    
    # Cambiar al directorio del año
    os.chdir(str(dir_año))
    
    # Buscar archivos georreferenciados con múltiples patrones
    archivos = []
    for patron in PATRONES:
        archivos.extend(glob.glob(patron))
    
    # Eliminar duplicados
    archivos = list(set(archivos))
    
    if not archivos:
        print(f"⚠️  No se encontraron archivos georreferenciados en {año}/")
        return None
    
    print(f"\n✅ Se encontraron {len(archivos)} archivos:")
    for archivo in sorted(archivos):
        tamano_mb = os.path.getsize(archivo) / (1024 * 1024)
        print(f"   - {archivo} ({tamano_mb:.2f} MB)")
    
    # Leer y concatenar todos los archivos
    print(f"\n📥 Cargando archivos...")
    dataframes = []
    
    for i, archivo in enumerate(sorted(archivos), 1):
        print(f"   [{i}/{len(archivos)}] {archivo}...", end=" ")
        try:
            df = pd.read_csv(archivo, encoding='utf-8')
            
            # Agregar columna con el nombre del archivo de origen
            df['archivo_origen'] = os.path.basename(archivo)
            
            dataframes.append(df)
            print(f"✅ {len(df):,} filas")
        except Exception as e:
            print(f"❌ Error: {str(e)}")
            continue
    
    if not dataframes:
        print(f"❌ No se pudo cargar ningún archivo")
        return None
    
    # Concatenar todos los dataframes
    print(f"\n🔗 Concatenando {len(dataframes)} archivos...")
    df_completo = pd.concat(dataframes, ignore_index=True)
    
    print(f"   ✅ Total de filas: {len(df_completo):,}")
    print(f"   ✅ Total de columnas: {len(df_completo.columns)}")
    
    # Mostrar estadísticas
    print(f"\n📊 ESTADÍSTICAS:")
    con_codigo = df_completo['DPA_PARROQ'].notna().sum()
    sin_codigo = df_completo['DPA_PARROQ'].isna().sum()
    print(f"   - Con código INEC: {con_codigo:,} ({con_codigo/len(df_completo)*100:.2f}%)")
    print(f"   - Sin código INEC: {sin_codigo:,} ({sin_codigo/len(df_completo)*100:.2f}%)")
    
    if 'Fecha' in df_completo.columns:
        df_completo['Fecha'] = pd.to_datetime(df_completo['Fecha'], errors='coerce')
        fecha_min = df_completo['Fecha'].min()
        fecha_max = df_completo['Fecha'].max()
        if pd.notna(fecha_min) and pd.notna(fecha_max):
            print(f"   - Rango de fechas: {fecha_min.date()} a {fecha_max.date()}")
    
    # Guardar archivo unificado
    output_file = f"eventos_{año}_completo_georreferenciado.csv"
    print(f"\n💾 Guardando archivo unificado: {output_file}")
    df_completo.to_csv(output_file, index=False, encoding='utf-8')
    
    tamano_final_mb = os.path.getsize(output_file) / (1024 * 1024)
    print(f"   ✅ Guardado exitosamente ({tamano_final_mb:.2f} MB)")
    
    # Reporte por archivo de origen
    print(f"\n📋 DISTRIBUCIÓN POR ARCHIVO:")
    conteo_origen = df_completo['archivo_origen'].value_counts().sort_index()
    for archivo, cantidad in conteo_origen.items():
        print(f"   - {archivo}: {cantidad:,} filas")
    
    print(f"\n{'=' * 80}")
    print(f"✅ AÑO {año} COMPLETADO")
    print(f"{'=' * 80}")
    
    return df_completo


# ============================================================
# FUNCIÓN PRINCIPAL - UNIR TODOS LOS AÑOS
# ============================================================

def unir_todos_los_años():
    """
    Une archivos georreferenciados para todos los años (2022-2025).
    """
    # Guardar directorio original
    dir_original = Path.cwd()
    
    print("\n" + "=" * 80)
    print("UNIFICACIÓN MULTI-AÑO DE ARCHIVOS GEORREFERENCIADOS")
    print("=" * 80)
    print(f"📁 Directorio DataHUB: {DIR_DATAHUB}\n")
    
    # Verificar que DataHUB existe
    if not DIR_DATAHUB.exists():
        print(f"❌ ERROR: No se encontró el directorio DataHUB: {DIR_DATAHUB}")
        return
    
    # Resumen de resultados
    resumen = []
    
    # Procesar cada año
    for año in AÑOS:
        dir_año = DIR_DATAHUB / año
        
        if not dir_año.exists():
            print(f"\n⚠️  Directorio no encontrado: {año}/")
            continue
        
        try:
            # Unir archivos del año
            df_año = unir_archivos_por_año(año, dir_año)
            
            if df_año is not None:
                resumen.append({
                    'año': año,
                    'total_registros': len(df_año),
                    'georreferenciados': df_año['DPA_PARROQ'].notna().sum(),
                    'sin_georreferenciar': df_año['DPA_PARROQ'].isna().sum(),
                    'archivos_unidos': len(df_año['archivo_origen'].unique()),
                    'archivo_salida': f"eventos_{año}_completo_georreferenciado.csv"
                })
        
        except Exception as e:
            print(f"\n❌ ERROR al procesar año {año}: {str(e)}")
            continue
        
        # Volver al directorio original
        os.chdir(str(dir_original))
    
    # Mostrar resumen final
    if resumen:
        print("\n\n" + "=" * 80)
        print("RESUMEN FINAL - TODOS LOS AÑOS")
        print("=" * 80)
        
        df_resumen = pd.DataFrame(resumen)
        
        # Calcular porcentaje de éxito
        df_resumen['% éxito'] = (
            df_resumen['georreferenciados'] / df_resumen['total_registros'] * 100
        ).round(2)
        
        print("\n📊 ESTADÍSTICAS POR AÑO:")
        print(df_resumen[['año', 'total_registros', 'georreferenciados', 
                          'sin_georreferenciar', '% éxito', 'archivos_unidos']].to_string(index=False))
        
        # Totales generales
        print("\n📊 TOTALES GENERALES:")
        total_registros = df_resumen['total_registros'].sum()
        total_georreferenciados = df_resumen['georreferenciados'].sum()
        total_sin_georreferenciar = df_resumen['sin_georreferenciar'].sum()
        
        print(f"   Total de registros: {total_registros:,}")
        print(f"   Georreferenciados: {total_georreferenciados:,} ({total_georreferenciados/total_registros*100:.2f}%)")
        print(f"   Sin georreferenciar: {total_sin_georreferenciar:,} ({total_sin_georreferenciar/total_registros*100:.2f}%)")
        
        # Archivos generados
        print("\n📁 ARCHIVOS GENERADOS:")
        for idx, row in df_resumen.iterrows():
            print(f"   - {row['año']}/{row['archivo_salida']}")
        
    print("\n" + "=" * 80)
    print("✅ PROCESO COMPLETADO")
    print("=" * 80)


# ============================================================
# EJECUTAR
# ============================================================

unir_todos_los_años()
# Out:
# ================================================================================
# UNIFICACIÓN MULTI-AÑO DE ARCHIVOS GEORREFERENCIADOS
# ================================================================================
# 📁 Directorio DataHUB: C:\Users\JPbau\OneDrive\Documents\8vo\DataHUB
#
#
# ================================================================================
# UNIENDO ARCHIVOS GEORREFERENCIADOS - AÑO 2022
# ================================================================================
#
# ✅ Se encontraron 12 archivos:
#    - emergencias_abril_2022_georreferenciado.csv (57.54 MB)
#    - emergencias_agosto_2022_georreferenciado.csv (54.66 MB)
#    - emergencias_diciembre_2022_georreferenciado.csv (55.77 MB)
#    - emergencias_enero_2022_georreferenciado.csv (55.94 MB)
#    - emergencias_febrero_2022_georreferenciado.csv (54.16 MB)
#    - emergencias_julio_2022_georreferenciado.csv (57.07 MB)
#    - emergencias_junio_2022_georreferenciado.csv (54.03 MB)
#    - emergencias_marzo_2022_georreferenciado.csv (57.74 MB)
#    - emergencias_mayo_2022_georreferenciado.csv (59.16 MB)
#    - emergencias_noviembre_2022_georreferenciado.csv (53.06 MB)
#    - emergencias_octubre_2022_georreferenciado.csv (56.46 MB)
#    - emergencias_septiembre_2022_georreferenciado.csv (54.23 MB)
#
# 📥 Cargando archivos...
#    [1/12] emergencias_abril_2022_georreferenciado.csv... ✅ 311,646 filas
#    [2/12] emergencias_agosto_2022_georreferenciado.csv... ✅ 296,358 filas
#    [3/12] emergencias_diciembre_2022_georreferenciado.csv... ✅ 302,289 filas
#    [4/12] emergencias_enero_2022_georreferenciado.csv... ✅ 304,492 filas
#    [5/12] emergencias_febrero_2022_georreferenciado.csv... ✅ 293,958 filas
#    [6/12] emergencias_julio_2022_georreferenciado.csv... ✅ 309,235 filas
#    [7/12] emergencias_junio_2022_georreferenciado.csv... ✅ 291,698 filas
#    [8/12] emergencias_marzo_2022_georreferenciado.csv... ✅ 312,697 filas
#    [9/12] emergencias_mayo_2022_georreferenciado.csv... ✅ 318,690 filas
#    [10/12] emergencias_noviembre_2022_georreferenciado.csv... ✅ 287,205 filas
#    [11/12] emergencias_octubre_2022_georreferenciado.csv... ✅ 306,659 filas
#    [12/12] emergencias_septiembre_2022_georreferenciado.csv... ✅ 294,045 filas
#
# 🔗 Concatenando 12 archivos...
#    ✅ Total de filas: 3,628,972
#    ✅ Total de columnas: 12
#
# 📊 ESTADÍSTICAS:
#    - Con código INEC: 3,628,865 (100.00%)
#    - Sin código INEC: 107 (0.00%)
#    - Rango de fechas: 2022-01-01 a 2022-12-31
#
# 💾 Guardando archivo unificado: eventos_2022_completo_georreferenciado.csv
#    ✅ Guardado exitosamente (830.65 MB)
#
# 📋 DISTRIBUCIÓN POR ARCHIVO:
#    - emergencias_abril_2022_georreferenciado.csv: 311,646 filas
#    - emergencias_agosto_2022_georreferenciado.csv: 296,358 filas
#    - emergencias_diciembre_2022_georreferenciado.csv: 302,289 filas
#    - emergencias_enero_2022_georreferenciado.csv: 304,492 filas
#    - emergencias_febrero_2022_georreferenciado.csv: 293,958 filas
#    - emergencias_julio_2022_georreferenciado.csv: 309,235 filas
#    - emergencias_junio_2022_georreferenciado.csv: 291,698 filas
#    - emergencias_marzo_2022_georreferenciado.csv: 312,697 filas
#    - emergencias_mayo_2022_georreferenciado.csv: 318,690 filas
#    - emergencias_noviembre_2022_georreferenciado.csv: 287,205 filas
#    - emergencias_octubre_2022_georreferenciado.csv: 306,659 filas
#    - emergencias_septiembre_2022_georreferenciado.csv: 294,045 filas
#
# ================================================================================
# ✅ AÑO 2022 COMPLETADO
# ================================================================================
#
# ================================================================================
# UNIENDO ARCHIVOS GEORREFERENCIADOS - AÑO 2023
# ================================================================================
#
# ✅ Se encontraron 12 archivos:
#    - emergencias_abril_2023_georreferenciado.csv (53.45 MB)
#    - emergencias_agosto_2023_georreferenciado.csv (52.36 MB)
#    - emergencias_diciembre_2023_georreferenciado.csv (55.16 MB)
#    - emergencias_enero_2023_georreferenciado.csv (52.80 MB)
#    - emergencias_febrero_2023_georreferenciado.csv (47.22 MB)
#    - emergencias_julio_2023_georreferenciado.csv (54.36 MB)
#    - emergencias_junio_2023_georreferenciado.csv (53.57 MB)
#    - emergencias_marzo_2023_georreferenciado.csv (53.49 MB)
#    - emergencias_mayo_2023_georreferenciado.csv (53.90 MB)
#    - emergencias_noviembre_2023_georreferenciado.csv (50.31 MB)
#    - emergencias_octubre_2023_georreferenciado.csv (53.05 MB)
#    - emergencias_septiembre_2023_georreferenciado.csv (52.66 MB)
#
# 📥 Cargando archivos...
#    [1/12] emergencias_abril_2023_georreferenciado.csv... ✅ 289,331 filas
#    [2/12] emergencias_agosto_2023_georreferenciado.csv... ✅ 284,284 filas
#    [3/12] emergencias_diciembre_2023_georreferenciado.csv... ✅ 299,559 filas
#    [4/12] emergencias_enero_2023_georreferenciado.csv... ✅ 286,362 filas
#    [5/12] emergencias_febrero_2023_georreferenciado.csv... ✅ 270,533 filas
#    [6/12] emergencias_julio_2023_georreferenciado.csv... ✅ 295,308 filas
#    [7/12] emergencias_junio_2023_georreferenciado.csv... ✅ 290,166 filas
#    [8/12] emergencias_marzo_2023_georreferenciado.csv... ✅ 289,406 filas
#    [9/12] emergencias_mayo_2023_georreferenciado.csv... ✅ 291,284 filas
#    [10/12] emergencias_noviembre_2023_georreferenciado.csv... ✅ 273,855 filas
#    [11/12] emergencias_octubre_2023_georreferenciado.csv... ✅ 288,964 filas
#    [12/12] emergencias_septiembre_2023_georreferenciado.csv... ✅ 287,072 filas
#
# 🔗 Concatenando 12 archivos...
#    ✅ Total de filas: 3,446,124
#    ✅ Total de columnas: 12
#
# 📊 ESTADÍSTICAS:
#    - Con código INEC: 3,446,031 (100.00%)
#    - Sin código INEC: 93 (0.00%)
#    - Rango de fechas: 2023-01-01 a 2023-12-31
#
# 💾 Guardando archivo unificado: eventos_2023_completo_georreferenciado.csv
#    ✅ Guardado exitosamente (785.30 MB)
#
# 📋 DISTRIBUCIÓN POR ARCHIVO:
#    - emergencias_abril_2023_georreferenciado.csv: 289,331 filas
#    - emergencias_agosto_2023_georreferenciado.csv: 284,284 filas
#    - emergencias_diciembre_2023_georreferenciado.csv: 299,559 filas
#    - emergencias_enero_2023_georreferenciado.csv: 286,362 filas
#    - emergencias_febrero_2023_georreferenciado.csv: 270,533 filas
#    - emergencias_julio_2023_georreferenciado.csv: 295,308 filas
#    - emergencias_junio_2023_georreferenciado.csv: 290,166 filas
#    - emergencias_marzo_2023_georreferenciado.csv: 289,406 filas
#    - emergencias_mayo_2023_georreferenciado.csv: 291,284 filas
#    - emergencias_noviembre_2023_georreferenciado.csv: 273,855 filas
#    - emergencias_octubre_2023_georreferenciado.csv: 288,964 filas
#    - emergencias_septiembre_2023_georreferenciado.csv: 287,072 filas
#
# ================================================================================
# ✅ AÑO 2023 COMPLETADO
# ================================================================================
#
# ================================================================================
# UNIENDO ARCHIVOS GEORREFERENCIADOS - AÑO 2024
# ================================================================================
#
# ✅ Se encontraron 12 archivos:
#    - incidentes_abril_2024_georreferenciado.csv (49.98 MB)
#    - incidentes_agosto_2024_georreferenciado.csv (49.38 MB)
#    - incidentes_diciembre2024_georreferenciado.csv (54.93 MB)
#    - incidentes_enero_2024_georreferenciado.csv (39.21 MB)
#    - incidentes_febrero_2024_georreferenciado.csv (50.94 MB)
#    - incidentes_julio_2024_georreferenciado.csv (49.42 MB)
#    - incidentes_junio_2024_georreferenciado.csv (50.93 MB)
#    - incidentes_marzo_2024_georreferenciado.csv (53.51 MB)
#    - incidentes_mayo_2024_georreferenciado.csv (51.17 MB)
#    - incidentes_noviembre2024_georreferenciado.csv (51.41 MB)
#    - incidentes_octubre2024_georreferenciado.csv (54.21 MB)
#    - incidentes_septiembre2024_georreferenciado.csv (51.27 MB)
#
# 📥 Cargando archivos...
#    [1/12] incidentes_abril_2024_georreferenciado.csv... ✅ 271,900 filas
#    [2/12] incidentes_agosto_2024_georreferenciado.csv...
# C:\Users\JPbau\AppData\Local\Temp\ipykernel_29028\3833260322.py:69: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(archivo, encoding='utf-8')
# ✅ 269,501 filas
#    [3/12] incidentes_diciembre2024_georreferenciado.csv... ✅ 297,251 filas
#    [4/12] incidentes_enero_2024_georreferenciado.csv... ✅ 208,143 filas
#    [5/12] incidentes_febrero_2024_georreferenciado.csv... ✅ 276,756 filas
#    [6/12] incidentes_julio_2024_georreferenciado.csv...
# C:\Users\JPbau\AppData\Local\Temp\ipykernel_29028\3833260322.py:69: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(archivo, encoding='utf-8')
# ✅ 268,214 filas
#    [7/12] incidentes_junio_2024_georreferenciado.csv... ✅ 277,003 filas
#    [8/12] incidentes_marzo_2024_georreferenciado.csv... ✅ 291,103 filas
#    [9/12] incidentes_mayo_2024_georreferenciado.csv... ✅ 278,041 filas
#    [10/12] incidentes_noviembre2024_georreferenciado.csv... ✅ 279,528 filas
#    [11/12] incidentes_octubre2024_georreferenciado.csv... ✅ 294,423 filas
#    [12/12] incidentes_septiembre2024_georreferenciado.csv... ✅ 279,880 filas
#
# 🔗 Concatenando 12 archivos...
#    ✅ Total de filas: 3,291,743
#    ✅ Total de columnas: 12
#
# 📊 ESTADÍSTICAS:
#    - Con código INEC: 3,291,622 (100.00%)
#    - Sin código INEC: 121 (0.00%)
#    - Rango de fechas: 2024-01-01 a 2024-12-31
#
# 💾 Guardando archivo unificado: eventos_2024_completo_georreferenciado.csv
#    ✅ Guardado exitosamente (748.36 MB)
#
# 📋 DISTRIBUCIÓN POR ARCHIVO:
#    - incidentes_abril_2024_georreferenciado.csv: 271,900 filas
#    - incidentes_agosto_2024_georreferenciado.csv: 269,501 filas
#    - incidentes_diciembre2024_georreferenciado.csv: 297,251 filas
#    - incidentes_enero_2024_georreferenciado.csv: 208,143 filas
#    - incidentes_febrero_2024_georreferenciado.csv: 276,756 filas
#    - incidentes_julio_2024_georreferenciado.csv: 268,214 filas
#    - incidentes_junio_2024_georreferenciado.csv: 277,003 filas
#    - incidentes_marzo_2024_georreferenciado.csv: 291,103 filas
#    - incidentes_mayo_2024_georreferenciado.csv: 278,041 filas
#    - incidentes_noviembre2024_georreferenciado.csv: 279,528 filas
#    - incidentes_octubre2024_georreferenciado.csv: 294,423 filas
#    - incidentes_septiembre2024_georreferenciado.csv: 279,880 filas
#
# ================================================================================
# ✅ AÑO 2024 COMPLETADO
# ================================================================================
#
# ================================================================================
# UNIENDO ARCHIVOS GEORREFERENCIADOS - AÑO 2025
# ================================================================================
#
# ✅ Se encontraron 8 archivos:
#    - incidentes_abril_2025_georreferenciado.csv (48.34 MB)
#    - incidentes_agosto_2025_georreferenciado.csv (50.50 MB)
#    - incidentes_enero_2025_georreferenciado.csv (49.42 MB)
#    - incidentes_febrero_2025_georreferenciado.csv (45.02 MB)
#    - incidentes_julio_2025_georreferenciado.csv (49.21 MB)
#    - incidentes_junio_2025_georreferenciado.csv (49.72 MB)
#    - incidentes_marzo_2025_georreferenciado.csv (50.68 MB)
#    - incidentes_mayo_2025_georreferenciado.csv (51.00 MB)
#
# 📥 Cargando archivos...
#    [1/8] incidentes_abril_2025_georreferenciado.csv... ✅ 263,353 filas
#    [2/8] incidentes_agosto_2025_georreferenciado.csv... ✅ 275,331 filas
#    [3/8] incidentes_enero_2025_georreferenciado.csv... ✅ 267,715 filas
#    [4/8] incidentes_febrero_2025_georreferenciado.csv... ✅ 244,604 filas
#    [5/8] incidentes_julio_2025_georreferenciado.csv... ✅ 268,003 filas
#    [6/8] incidentes_junio_2025_georreferenciado.csv... ✅ 271,077 filas
#    [7/8] incidentes_marzo_2025_georreferenciado.csv... ✅ 277,048 filas
#    [8/8] incidentes_mayo_2025_georreferenciado.csv... ✅ 277,852 filas
#
# 🔗 Concatenando 8 archivos...
#    ✅ Total de filas: 2,144,983
#    ✅ Total de columnas: 12
#
# 📊 ESTADÍSTICAS:
#    - Con código INEC: 2,144,612 (99.98%)
#    - Sin código INEC: 371 (0.02%)
#    - Rango de fechas: 2025-01-01 a 2025-08-31
#
# 💾 Guardando archivo unificado: eventos_2025_completo_georreferenciado.csv
#    ✅ Guardado exitosamente (484.57 MB)
#
# 📋 DISTRIBUCIÓN POR ARCHIVO:
#    - incidentes_abril_2025_georreferenciado.csv: 263,353 filas
#    - incidentes_agosto_2025_georreferenciado.csv: 275,331 filas
#    - incidentes_enero_2025_georreferenciado.csv: 267,715 filas
#    - incidentes_febrero_2025_georreferenciado.csv: 244,604 filas
#    - incidentes_julio_2025_georreferenciado.csv: 268,003 filas
#    - incidentes_junio_2025_georreferenciado.csv: 271,077 filas
#    - incidentes_marzo_2025_georreferenciado.csv: 277,048 filas
#    - incidentes_mayo_2025_georreferenciado.csv: 277,852 filas
#
# ================================================================================
# ✅ AÑO 2025 COMPLETADO
# ================================================================================
#
#
# ================================================================================
# RESUMEN FINAL - TODOS LOS AÑOS
# ================================================================================
#
# 📊 ESTADÍSTICAS POR AÑO:
#  año  total_registros  georreferenciados  sin_georreferenciar  % éxito  archivos_unidos
# 2022          3628972            3628865                  107   100.00               12
# 2023          3446124            3446031                   93   100.00               12
# 2024          3291743            3291622                  121   100.00               12
# 2025          2144983            2144612                  371    99.98                8
#
# 📊 TOTALES GENERALES:
#    Total de registros: 12,511,822
#    Georreferenciados: 12,511,130 (99.99%)
#    Sin georreferenciar: 692 (0.01%)
#
# 📁 ARCHIVOS GENERADOS:
#    - 2022/eventos_2022_completo_georreferenciado.csv
#    - 2023/eventos_2023_completo_georreferenciado.csv
#    - 2024/eventos_2024_completo_georreferenciado.csv
#    - 2025/eventos_2025_completo_georreferenciado.csv
#
# ================================================================================
# ✅ PROCESO COMPLETADO
# ================================================================================

# %% [markdown]
# ----------------------------------------

# %% [markdown]
# Limpieza de datos(eventos georeferenciados por anio) usando la librería de polars

# %%
#polars 
# %pip install polars
# Out:
# Collecting polars
#   Downloading polars-1.37.0-py3-none-any.whl.metadata (10 kB)
# Collecting polars-runtime-32==1.37.0 (from polars)
#   Downloading polars_runtime_32-1.37.0-cp310-abi3-win_amd64.whl.metadata (1.5 kB)
# Downloading polars-1.37.0-py3-none-any.whl (805 kB)
#    ---------------------------------------- 0.0/805.6 kB ? eta -:--:--
#    ------------- -------------------------- 262.1/805.6 kB ? eta -:--:--
#    ---------------------------------------- 805.6/805.6 kB 2.9 MB/s eta 0:00:00
# Downloading polars_runtime_32-1.37.0-cp310-abi3-win_amd64.whl (45.0 MB)
#    ---------------------------------------- 0.0/45.0 MB ? eta -:--:--
#    ---------------------------------------- 0.5/45.0 MB 2.8 MB/s eta 0:00:16
#     --------------------------------------- 1.0/45.0 MB 2.5 MB/s eta 0:00:18
#    - -------------------------------------- 1.6/45.0 MB 2.7 MB/s eta 0:00:17
#    -- ------------------------------------- 2.4/45.0 MB 2.9 MB/s eta 0:00:15
#    -- ------------------------------------- 2.9/45.0 MB 2.8 MB/s eta 0:00:15
#    --- ------------------------------------ 3.4/45.0 MB 3.0 MB/s eta 0:00:15
#    --- ------------------------------------ 4.2/45.0 MB 2.9 MB/s eta 0:00:15
#    ---- ----------------------------------- 4.7/45.0 MB 2.9 MB/s eta 0:00:14
#    ---- ----------------------------------- 5.2/45.0 MB 2.8 MB/s eta 0:00:15
#    ---- ----------------------------------- 5.5/45.0 MB 2.7 MB/s eta 0:00:15
#    ----- ---------------------------------- 6.0/45.0 MB 2.7 MB/s eta 0:00:15
#    ----- ---------------------------------- 6.6/45.0 MB 2.7 MB/s eta 0:00:15
#    ------ --------------------------------- 7.1/45.0 MB 2.7 MB/s eta 0:00:15
#    ------ --------------------------------- 7.6/45.0 MB 2.6 MB/s eta 0:00:15
#    ------ --------------------------------- 7.9/45.0 MB 2.5 MB/s eta 0:00:15
#    ------- -------------------------------- 8.1/45.0 MB 2.4 MB/s eta 0:00:16
#    ------- -------------------------------- 8.4/45.0 MB 2.4 MB/s eta 0:00:16
#    ------- -------------------------------- 8.7/45.0 MB 2.3 MB/s eta 0:00:16
#    ------- -------------------------------- 8.9/45.0 MB 2.3 MB/s eta 0:00:16
#    ------- -------------------------------- 8.9/45.0 MB 2.3 MB/s eta 0:00:16
#    -------- ------------------------------- 9.2/45.0 MB 2.1 MB/s eta 0:00:18
#    -------- ------------------------------- 9.2/45.0 MB 2.1 MB/s eta 0:00:18
#    -------- ------------------------------- 9.4/45.0 MB 2.0 MB/s eta 0:00:19
#    -------- ------------------------------- 10.0/45.0 MB 2.0 MB/s eta 0:00:18
#    -------- ------------------------------- 10.0/45.0 MB 2.0 MB/s eta 0:00:18
#    --------- ------------------------------ 10.2/45.0 MB 1.9 MB/s eta 0:00:19
#    --------- ------------------------------ 10.5/45.0 MB 1.9 MB/s eta 0:00:19
#    --------- ------------------------------ 10.7/45.0 MB 1.9 MB/s eta 0:00:19
#    --------- ------------------------------ 11.0/45.0 MB 1.8 MB/s eta 0:00:19
#    ---------- ----------------------------- 11.3/45.0 MB 1.8 MB/s eta 0:00:19
#    ---------- ----------------------------- 11.3/45.0 MB 1.8 MB/s eta 0:00:19
#    ---------- ----------------------------- 11.5/45.0 MB 1.7 MB/s eta 0:00:20
#    ---------- ----------------------------- 11.8/45.0 MB 1.7 MB/s eta 0:00:20
#    ---------- ----------------------------- 12.3/45.0 MB 1.7 MB/s eta 0:00:20
#    ---------- ----------------------------- 12.3/45.0 MB 1.7 MB/s eta 0:00:20
#    ---------- ----------------------------- 12.3/45.0 MB 1.7 MB/s eta 0:00:20
#    ----------- ---------------------------- 12.6/45.0 MB 1.6 MB/s eta 0:00:20
#    ----------- ---------------------------- 12.8/45.0 MB 1.6 MB/s eta 0:00:20
#    ----------- ---------------------------- 13.1/45.0 MB 1.6 MB/s eta 0:00:20
#    ------------ --------------------------- 13.6/45.0 MB 1.6 MB/s eta 0:00:20
#    ------------ --------------------------- 13.9/45.0 MB 1.6 MB/s eta 0:00:20
#    ------------ --------------------------- 14.2/45.0 MB 1.6 MB/s eta 0:00:20
#    ------------ --------------------------- 14.2/45.0 MB 1.6 MB/s eta 0:00:20
#    ------------ --------------------------- 14.4/45.0 MB 1.6 MB/s eta 0:00:20
#    ------------- -------------------------- 14.7/45.0 MB 1.5 MB/s eta 0:00:20
#    ------------- -------------------------- 14.9/45.0 MB 1.5 MB/s eta 0:00:20
#    ------------- -------------------------- 15.2/45.0 MB 1.5 MB/s eta 0:00:20
#    ------------- -------------------------- 15.5/45.0 MB 1.5 MB/s eta 0:00:20
#    -------------- ------------------------- 16.0/45.0 MB 1.6 MB/s eta 0:00:19
#    -------------- ------------------------- 16.3/45.0 MB 1.5 MB/s eta 0:00:19
#    -------------- ------------------------- 16.8/45.0 MB 1.6 MB/s eta 0:00:19
#    --------------- ------------------------ 17.0/45.0 MB 1.6 MB/s eta 0:00:18
#    --------------- ------------------------ 17.6/45.0 MB 1.6 MB/s eta 0:00:18
#    --------------- ------------------------ 17.8/45.0 MB 1.6 MB/s eta 0:00:18
#    ---------------- ----------------------- 18.4/45.0 MB 1.6 MB/s eta 0:00:17
#    ---------------- ----------------------- 18.6/45.0 MB 1.6 MB/s eta 0:00:17
#    ----------------- ---------------------- 19.1/45.0 MB 1.6 MB/s eta 0:00:17
#    ----------------- ---------------------- 19.4/45.0 MB 1.6 MB/s eta 0:00:17
#    ----------------- ---------------------- 19.9/45.0 MB 1.6 MB/s eta 0:00:16
#    ----------------- ---------------------- 20.2/45.0 MB 1.6 MB/s eta 0:00:16
#    ------------------ --------------------- 20.7/45.0 MB 1.6 MB/s eta 0:00:16
#    ------------------ --------------------- 21.2/45.0 MB 1.6 MB/s eta 0:00:15
#    ------------------- -------------------- 21.5/45.0 MB 1.6 MB/s eta 0:00:15
#    ------------------- -------------------- 21.8/45.0 MB 1.6 MB/s eta 0:00:15
#    ------------------- -------------------- 22.0/45.0 MB 1.6 MB/s eta 0:00:15
#    -------------------- ------------------- 22.5/45.0 MB 1.6 MB/s eta 0:00:14
#    -------------------- ------------------- 22.5/45.0 MB 1.6 MB/s eta 0:00:14
#    -------------------- ------------------- 23.1/45.0 MB 1.6 MB/s eta 0:00:14
#    -------------------- ------------------- 23.3/45.0 MB 1.6 MB/s eta 0:00:14
#    -------------------- ------------------- 23.3/45.0 MB 1.6 MB/s eta 0:00:14
#    --------------------- ------------------ 23.9/45.0 MB 1.6 MB/s eta 0:00:14
#    --------------------- ------------------ 24.1/45.0 MB 1.6 MB/s eta 0:00:14
#    --------------------- ------------------ 24.4/45.0 MB 1.6 MB/s eta 0:00:13
#    --------------------- ------------------ 24.6/45.0 MB 1.6 MB/s eta 0:00:13
#    ---------------------- ----------------- 24.9/45.0 MB 1.6 MB/s eta 0:00:13
#    ---------------------- ----------------- 25.4/45.0 MB 1.6 MB/s eta 0:00:13
#    ---------------------- ----------------- 25.7/45.0 MB 1.6 MB/s eta 0:00:13
#    ----------------------- ---------------- 26.0/45.0 MB 1.6 MB/s eta 0:00:13
#    ----------------------- ---------------- 26.2/45.0 MB 1.6 MB/s eta 0:00:12
#    ----------------------- ---------------- 26.5/45.0 MB 1.6 MB/s eta 0:00:12
#    ----------------------- ---------------- 26.7/45.0 MB 1.6 MB/s eta 0:00:12
#    ----------------------- ---------------- 26.7/45.0 MB 1.6 MB/s eta 0:00:12
#    ----------------------- ---------------- 27.0/45.0 MB 1.6 MB/s eta 0:00:12
#    ------------------------ --------------- 27.5/45.0 MB 1.6 MB/s eta 0:00:12
#    ------------------------ --------------- 27.8/45.0 MB 1.6 MB/s eta 0:00:12
#    ------------------------ --------------- 28.0/45.0 MB 1.6 MB/s eta 0:00:11
#    ------------------------- -------------- 28.3/45.0 MB 1.6 MB/s eta 0:00:11
#    ------------------------- -------------- 28.6/45.0 MB 1.5 MB/s eta 0:00:11
#    ------------------------- -------------- 28.8/45.0 MB 1.5 MB/s eta 0:00:11
#    -------------------------- ------------- 29.4/45.0 MB 1.6 MB/s eta 0:00:11
#    -------------------------- ------------- 29.6/45.0 MB 1.6 MB/s eta 0:00:10
#    -------------------------- ------------- 29.9/45.0 MB 1.5 MB/s eta 0:00:10
#    -------------------------- ------------- 30.1/45.0 MB 1.5 MB/s eta 0:00:10
#    --------------------------- ------------ 30.4/45.0 MB 1.5 MB/s eta 0:00:10
#    --------------------------- ------------ 30.9/45.0 MB 1.5 MB/s eta 0:00:10
#    --------------------------- ------------ 31.2/45.0 MB 1.5 MB/s eta 0:00:09
#    --------------------------- ------------ 31.5/45.0 MB 1.5 MB/s eta 0:00:09
#    ---------------------------- ----------- 31.7/45.0 MB 1.5 MB/s eta 0:00:09
#    ---------------------------- ----------- 31.7/45.0 MB 1.5 MB/s eta 0:00:09
#    ---------------------------- ----------- 32.0/45.0 MB 1.5 MB/s eta 0:00:09
#    ---------------------------- ----------- 32.0/45.0 MB 1.5 MB/s eta 0:00:09
#    ---------------------------- ----------- 32.2/45.0 MB 1.5 MB/s eta 0:00:09
#    ---------------------------- ----------- 32.5/45.0 MB 1.5 MB/s eta 0:00:09
#    ----------------------------- ---------- 32.8/45.0 MB 1.5 MB/s eta 0:00:09
#    ----------------------------- ---------- 32.8/45.0 MB 1.5 MB/s eta 0:00:09
#    ----------------------------- ---------- 33.0/45.0 MB 1.5 MB/s eta 0:00:09
#    ----------------------------- ---------- 33.6/45.0 MB 1.5 MB/s eta 0:00:08
#    ------------------------------ --------- 33.8/45.0 MB 1.5 MB/s eta 0:00:08
#    ------------------------------ --------- 34.1/45.0 MB 1.5 MB/s eta 0:00:08
#    ------------------------------ --------- 34.6/45.0 MB 1.5 MB/s eta 0:00:07
#    ------------------------------- -------- 35.1/45.0 MB 1.5 MB/s eta 0:00:07
#    ------------------------------- -------- 35.7/45.0 MB 1.5 MB/s eta 0:00:07
#    ------------------------------- -------- 35.9/45.0 MB 1.5 MB/s eta 0:00:07
#    -------------------------------- ------- 36.4/45.0 MB 1.5 MB/s eta 0:00:06
#    -------------------------------- ------- 36.7/45.0 MB 1.5 MB/s eta 0:00:06
#    -------------------------------- ------- 37.0/45.0 MB 1.5 MB/s eta 0:00:06
#    --------------------------------- ------ 37.5/45.0 MB 1.5 MB/s eta 0:00:05
#    --------------------------------- ------ 37.7/45.0 MB 1.5 MB/s eta 0:00:05
#    --------------------------------- ------ 38.0/45.0 MB 1.5 MB/s eta 0:00:05
#    ---------------------------------- ----- 38.3/45.0 MB 1.5 MB/s eta 0:00:05
#    ---------------------------------- ----- 38.5/45.0 MB 1.5 MB/s eta 0:00:05
#    ---------------------------------- ----- 38.5/45.0 MB 1.5 MB/s eta 0:00:05
#    ---------------------------------- ----- 38.5/45.0 MB 1.5 MB/s eta 0:00:05
#    ---------------------------------- ----- 38.5/45.0 MB 1.5 MB/s eta 0:00:05
#    ---------------------------------- ----- 38.8/45.0 MB 1.5 MB/s eta 0:00:05
#    ---------------------------------- ----- 38.8/45.0 MB 1.5 MB/s eta 0:00:05
#    ---------------------------------- ----- 39.1/45.0 MB 1.5 MB/s eta 0:00:05
#    ---------------------------------- ----- 39.1/45.0 MB 1.5 MB/s eta 0:00:05
#    ---------------------------------- ----- 39.3/45.0 MB 1.5 MB/s eta 0:00:04
#    ---------------------------------- ----- 39.3/45.0 MB 1.5 MB/s eta 0:00:04
#    ----------------------------------- ---- 39.6/45.0 MB 1.4 MB/s eta 0:00:04
#    ----------------------------------- ---- 39.8/45.0 MB 1.4 MB/s eta 0:00:04
#    ----------------------------------- ---- 40.1/45.0 MB 1.4 MB/s eta 0:00:04
#    ----------------------------------- ---- 40.1/45.0 MB 1.4 MB/s eta 0:00:04
#    ----------------------------------- ---- 40.4/45.0 MB 1.4 MB/s eta 0:00:04
#    ----------------------------------- ---- 40.4/45.0 MB 1.4 MB/s eta 0:00:04
#    ----------------------------------- ---- 40.4/45.0 MB 1.4 MB/s eta 0:00:04
#    ----------------------------------- ---- 40.4/45.0 MB 1.4 MB/s eta 0:00:04
#    ------------------------------------ --- 40.6/45.0 MB 1.4 MB/s eta 0:00:04
#    ------------------------------------ --- 40.6/45.0 MB 1.4 MB/s eta 0:00:04
#    ------------------------------------ --- 40.9/45.0 MB 1.4 MB/s eta 0:00:03
#    ------------------------------------ --- 41.2/45.0 MB 1.4 MB/s eta 0:00:03
#    ------------------------------------ --- 41.4/45.0 MB 1.4 MB/s eta 0:00:03
#    ------------------------------------ --- 41.4/45.0 MB 1.4 MB/s eta 0:00:03
#    ------------------------------------- -- 41.7/45.0 MB 1.4 MB/s eta 0:00:03
#    ------------------------------------- -- 41.7/45.0 MB 1.4 MB/s eta 0:00:03
#    ------------------------------------- -- 41.7/45.0 MB 1.4 MB/s eta 0:00:03
#    ------------------------------------- -- 42.2/45.0 MB 1.3 MB/s eta 0:00:03
#    ------------------------------------- -- 42.2/45.0 MB 1.3 MB/s eta 0:00:03
#    ------------------------------------- -- 42.5/45.0 MB 1.3 MB/s eta 0:00:02
#    ------------------------------------- -- 42.7/45.0 MB 1.3 MB/s eta 0:00:02
#    -------------------------------------- - 43.0/45.0 MB 1.3 MB/s eta 0:00:02
#    -------------------------------------- - 43.3/45.0 MB 1.2 MB/s eta 0:00:02
#    -------------------------------------- - 43.8/45.0 MB 1.2 MB/s eta 0:00:02
#    ---------------------------------------  44.0/45.0 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  44.3/45.0 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  44.8/45.0 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  44.8/45.0 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  44.8/45.0 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 45.0/45.0 MB 1.2 MB/s eta 0:00:00
# Installing collected packages: polars-runtime-32, polars
# Successfully installed polars-1.37.0 polars-runtime-32-1.37.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pathlib import Path  
import pandas as pd

# %%
import polars as pl
import glob
import os

def concatenar_archivos_georreferenciados():
    """
    Concatena todos los archivos georreferenciados de eventos y emergencias
    de los años 2021-2025 usando Polars, manejando errores de parsing y 
    diferencias en columnas.
    """
    print("="*80)
    print("CONCATENANDO ARCHIVOS GEORREFERENCIADOS CON POLARS")
    print("="*80)
    
    # Buscar archivos en todos los años
    patrones = [
        "emergencias_*_completo_georreferenciado.csv",
        "eventos_*_completo_georreferenciado.csv",
        "../2022/emergencias_*_completo_georreferenciado.csv",
        "../2022/eventos_*_completo_georreferenciado.csv",
        "../2023/emergencias_*_completo_georreferenciado.csv",
        "../2023/eventos_*_completo_georreferenciado.csv",
        "../2024/emergencias_*_completo_georreferenciado.csv",
        "../2024/eventos_*_completo_georreferenciado.csv",
        "../2025/emergencias_*_completo_georreferenciado.csv",
        "../2025/eventos_*_completo_georreferenciado.csv",
    ]
    
    archivos = []
    for patron in patrones:
        archivos.extend(glob.glob(patron))
    
    if not archivos:
        print("\n❌ No se encontraron archivos georreferenciados")
        return None
    
    print(f"\n✅ Se encontraron {len(archivos)} archivos:")
    for archivo in sorted(archivos):
        tamano_mb = os.path.getsize(archivo) / (1024 * 1024)
        print(f"  • {archivo} ({tamano_mb:.2f} MB)")
    
    # Leer archivos con Polars
    dataframes = []
    columnas_comunes = None
    
    for i, archivo in enumerate(sorted(archivos), 1):
        print(f"\n[{i}/{len(archivos)}] Procesando {os.path.basename(archivo)}...")
        
        try:
            # Leer con columnas como strings para evitar errores de parsing
            df_temp = pl.read_csv(
                archivo,
                encoding='utf-8',
                infer_schema_length=0,  # Leer todo como string primero
                ignore_errors=True
            )
            
            print(f"  ✓ Leído: {df_temp.shape[0]:,} filas, {df_temp.shape[1]} columnas")
            
            # Identificar columnas comunes
            if columnas_comunes is None:
                columnas_comunes = set(df_temp.columns)
            else:
                columnas_comunes = columnas_comunes.intersection(set(df_temp.columns))
            
            # Convertir columnas numéricas con manejo de errores
            for col in df_temp.columns:
                if col in ['Cod_Provincia', 'Cod_Canton', 'Cod_Parroquia']:
                    # Limpiar valores tipo "000nan" y convertir
                    df_temp = df_temp.with_columns(
                        pl.when(pl.col(col).str.contains("nan"))
                        .then(None)
                        .otherwise(pl.col(col))
                        .cast(pl.Int64, strict=False)
                        .alias(col)
                    )
            
            # Agregar columna de origen
            df_temp = df_temp.with_columns(
                pl.lit(os.path.basename(archivo)).alias("archivo_origen")
            )
            
            dataframes.append(df_temp)
            print(f"  ✓ Procesado correctamente")
            
        except Exception as e:
            print(f"  ❌ Error al leer {archivo}: {e}")
            continue
    
    if not dataframes:
        print("\n❌ No se pudieron leer archivos")
        return None
    
    print(f"\n{'='*80}")
    print(f"CONCATENANDO {len(dataframes)} DATAFRAMES")
    print(f"{'='*80}")
    
    # Asegurar que todos tengan las mismas columnas base
    print(f"\n📋 Columnas comunes encontradas: {len(columnas_comunes)}")
    
    # Seleccionar solo columnas comunes + archivo_origen de cada dataframe
    dataframes_normalizados = []
    for df in dataframes:
        cols_seleccionar = [col for col in df.columns if col in columnas_comunes or col == "archivo_origen"]
        df_normalizado = df.select(cols_seleccionar)
        dataframes_normalizados.append(df_normalizado)
    
    # Concatenar usando vertical_relaxed para mayor flexibilidad
    try:
        df_final = pl.concat(dataframes_normalizados, how='vertical_relaxed')
        print(f"\n✅ DataFrame final creado con {df_final.shape[0]:,} filas y {df_final.shape[1]} columnas")
        print(f"\n📊 Columnas: {df_final.columns}")
        
        # Estadísticas
        print(f"\n{'='*80}")
        print("ESTADÍSTICAS")
        print(f"{'='*80}")
        
        if 'DPA_PARROQ' in df_final.columns:
            con_codigo = df_final.filter(pl.col('DPA_PARROQ').is_not_null()).shape[0]
            sin_codigo = df_final.filter(pl.col('DPA_PARROQ').is_null()).shape[0]
            print(f"  • Con código INEC: {con_codigo:,} ({con_codigo/df_final.shape[0]*100:.2f}%)")
            print(f"  • Sin código INEC: {sin_codigo:,} ({sin_codigo/df_final.shape[0]*100:.2f}%)")
        
        # Distribución por archivo
        print(f"\n{'='*80}")
        print("DISTRIBUCIÓN POR ARCHIVO")
        print(f"{'='*80}")
        
        dist_archivos = df_final.group_by("archivo_origen").agg(
            pl.count().alias("cantidad")
        ).sort("archivo_origen")
        
        print(dist_archivos)
        
        # Guardar archivo final
        output_file = "todos_georreferenciados_2021_2025.csv"
        print(f"\n💾 Guardando archivo: {output_file}")
        df_final.write_csv(output_file)
        
        tamano_final_mb = os.path.getsize(output_file) / (1024 * 1024)
        print(f"✅ Archivo guardado exitosamente ({tamano_final_mb:.2f} MB)")
        
        print(f"\n{'='*80}")
        print("✅ PROCESO COMPLETADO")
        print(f"{'='*80}")
        
        return df_final
        
    except Exception as e:
        print(f"\n❌ Error al concatenar: {e}")
        print(f"\n🔍 Información de debug:")
        for i, df in enumerate(dataframes_normalizados):
            print(f"  DataFrame {i+1}: {df.shape[0]} filas x {df.shape[1]} columnas")
            print(f"    Columnas: {df.columns}")
        return None

if __name__ == "__main__":
    df_unificado = concatenar_archivos_georreferenciados()
# Out:
# ================================================================================
# CONCATENANDO ARCHIVOS GEORREFERENCIADOS CON POLARS
# ================================================================================
#
# ✅ Se encontraron 5 archivos:
#   • ../2022\eventos_2022_completo_georreferenciado.csv (830.65 MB)
#   • ../2023\eventos_2023_completo_georreferenciado.csv (785.30 MB)
#   • ../2024\eventos_2024_completo_georreferenciado.csv (748.36 MB)
#   • ../2025\eventos_2025_completo_georreferenciado.csv (484.57 MB)
#   • emergencias_2021_completo_georreferenciado.csv (879.63 MB)
#
# [1/5] Procesando eventos_2022_completo_georreferenciado.csv...
#   ✓ Leído: 3,628,972 filas, 12 columnas
#   ✓ Procesado correctamente
#
# [2/5] Procesando eventos_2023_completo_georreferenciado.csv...
#   ✓ Leído: 3,446,124 filas, 12 columnas
#   ✓ Procesado correctamente
#
# [3/5] Procesando eventos_2024_completo_georreferenciado.csv...
#   ✓ Leído: 3,291,743 filas, 12 columnas
#   ✓ Procesado correctamente
#
# [4/5] Procesando eventos_2025_completo_georreferenciado.csv...
#   ✓ Leído: 2,144,983 filas, 12 columnas
#   ✓ Procesado correctamente
#
# [5/5] Procesando emergencias_2021_completo_georreferenciado.csv...
#   ✓ Leído: 3,805,108 filas, 13 columnas
#   ✓ Procesado correctamente
#
# ================================================================================
# CONCATENANDO 5 DATAFRAMES
# ================================================================================
#
# 📋 Columnas comunes encontradas: 12
#
# ✅ DataFrame final creado con 16,316,930 filas y 12 columnas
#
# 📊 Columnas: ['Fecha', 'provincia', 'Canton', 'Cod_Parroquia', 'Parroquia', 'Servicio', 'Subtipo', 'prov_norm', 'canton_norm', 'parr_norm', 'DPA_PARROQ', 'archivo_origen']
#
# ================================================================================
# ESTADÍSTICAS
# ================================================================================
#   • Con código INEC: 16,316,114 (99.99%)
#   • Sin código INEC: 816 (0.01%)
#
# ================================================================================
# DISTRIBUCIÓN POR ARCHIVO
# ================================================================================
# C:\Users\JPbau\AppData\Local\Temp\ipykernel_7000\3822312874.py:131: DeprecationWarning: `pl.count()` is deprecated. Please use `pl.len()` instead.
# (Deprecated in version 0.20.5)
#   pl.count().alias("cantidad")
# shape: (5, 2)
# ┌─────────────────────────────────┬──────────┐
# │ archivo_origen                  ┆ cantidad │
# │ ---                             ┆ ---      │
# │ str                             ┆ u32      │
# ╞═════════════════════════════════╪══════════╡
# │ emergencias_2021_completo_geor… ┆ 3805108  │
# │ eventos_2022_completo_georrefe… ┆ 3628972  │
# │ eventos_2023_completo_georrefe… ┆ 3446124  │
# │ eventos_2024_completo_georrefe… ┆ 3291743  │
# │ eventos_2025_completo_georrefe… ┆ 2144983  │
# └─────────────────────────────────┴──────────┘
#
# 💾 Guardando archivo: todos_georreferenciados_2021_2025.csv
# ✅ Archivo guardado exitosamente (3689.81 MB)
#
# ================================================================================
# ✅ PROCESO COMPLETADO
# ================================================================================

# %%
df_unificado.head()
# Out:
# shape: (5, 12)
# ┌────────────┬───────────┬────────┬────────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ Fecha      ┆ provincia ┆ Canton ┆ Cod_Parroq ┆ … ┆ canton_no ┆ parr_norm ┆ DPA_PARRO ┆ archivo_o │
# │ ---        ┆ ---       ┆ ---    ┆ uia        ┆   ┆ rm        ┆ ---       ┆ Q         ┆ rigen     │
# │ str        ┆ str       ┆ str    ┆ ---        ┆   ┆ ---       ┆ str       ┆ ---       ┆ ---       │
# │            ┆           ┆        ┆ i64        ┆   ┆ str       ┆           ┆ str       ┆ str       │
# ╞════════════╪═══════════╪════════╪════════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 2022-04-01 ┆ pichincha ┆ quito  ┆ 170150     ┆ … ┆ quito     ┆ quito     ┆ 170150.0  ┆ eventos_2 │
# │            ┆           ┆        ┆            ┆   ┆           ┆ distrito  ┆           ┆ 022_compl │
# │            ┆           ┆        ┆            ┆   ┆           ┆ metropoli ┆           ┆ eto_georr │
# │            ┆           ┆        ┆            ┆   ┆           ┆ tano, …   ┆           ┆ efe…      │
# │ 2022-04-01 ┆ pichincha ┆ quito  ┆ 170150     ┆ … ┆ quito     ┆ quito     ┆ 170150.0  ┆ eventos_2 │
# │            ┆           ┆        ┆            ┆   ┆           ┆ distrito  ┆           ┆ 022_compl │
# │            ┆           ┆        ┆            ┆   ┆           ┆ metropoli ┆           ┆ eto_georr │
# │            ┆           ┆        ┆            ┆   ┆           ┆ tano, …   ┆           ┆ efe…      │
# │ 2022-04-01 ┆ pichincha ┆ quito  ┆ 170150     ┆ … ┆ quito     ┆ quito     ┆ 170150.0  ┆ eventos_2 │
# │            ┆           ┆        ┆            ┆   ┆           ┆ distrito  ┆           ┆ 022_compl │
# │            ┆           ┆        ┆            ┆   ┆           ┆ metropoli ┆           ┆ eto_georr │
# │            ┆           ┆        ┆            ┆   ┆           ┆ tano, …   ┆           ┆ efe…      │
# │ 2022-04-01 ┆ pichincha ┆ quito  ┆ 170150     ┆ … ┆ quito     ┆ quito     ┆ 170150.0  ┆ eventos_2 │
# │            ┆           ┆        ┆            ┆   ┆           ┆ distrito  ┆           ┆ 022_compl │
# │            ┆           ┆        ┆            ┆   ┆           ┆ metropoli ┆           ┆ eto_georr │
# │            ┆           ┆        ┆            ┆   ┆           ┆ tano, …   ┆           ┆ efe…      │
# │ 2022-04-01 ┆ pichincha ┆ quito  ┆ 170176     ┆ … ┆ quito     ┆ pintag    ┆ 170176.0  ┆ eventos_2 │
# │            ┆           ┆        ┆            ┆   ┆           ┆           ┆           ┆ 022_compl │
# │            ┆           ┆        ┆            ┆   ┆           ┆           ┆           ┆ eto_georr │
# │            ┆           ┆        ┆            ┆   ┆           ┆           ┆           ┆ efe…      │
# └────────────┴───────────┴────────┴────────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
df_unificado.describe()
# Out:
# shape: (9, 13)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ statistic ┆ Fecha     ┆ provincia ┆ Canton    ┆ … ┆ canton_no ┆ parr_norm ┆ DPA_PARRO ┆ archivo_ │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ rm        ┆ ---       ┆ Q         ┆ origen   │
# │ str       ┆ str       ┆ str       ┆ str       ┆   ┆ ---       ┆ str       ┆ ---       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆ str       ┆           ┆ str       ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ count     ┆ 16316930  ┆ 16316930  ┆ 16316930  ┆ … ┆ 16316930  ┆ 16316930  ┆ 16316114  ┆ 16316930 │
# │ null_coun ┆ 0         ┆ 0         ┆ 0         ┆ … ┆ 0         ┆ 0         ┆ 816       ┆ 0        │
# │ t         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ mean      ┆ null      ┆ null      ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ std       ┆ null      ┆ null      ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ min       ┆ 2021-07-0 ┆ azuay     ┆ 24 de     ┆ … ┆ 24 de     ┆ 10 de     ┆ 100150.0  ┆ emergenc │
# │           ┆ 1         ┆           ┆ mayo      ┆   ┆ mayo      ┆ agosto    ┆           ┆ ias_2021 │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ _complet │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ o_geor…  │
# │ 25%       ┆ null      ┆ null      ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 50%       ┆ null      ┆ null      ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 75%       ┆ null      ┆ null      ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ max       ┆ 2025-08-3 ┆ zamora    ┆ zaruma    ┆ … ┆ zaruma    ┆ zurmi     ┆ 92850.0   ┆ eventos_ │
# │           ┆ 1         ┆ chinchipe ┆           ┆   ┆           ┆           ┆           ┆ 2025_com │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ pleto_ge │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ orrefe…  │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
type(df_unificado)
# Out:
# polars.dataframe.frame.DataFrame

# %%
df_copia = df_unificado.clone()

# %%
df_copia.head()
# Out:
# shape: (5, 12)
# ┌────────────┬───────────┬────────┬────────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ Fecha      ┆ provincia ┆ Canton ┆ Cod_Parroq ┆ … ┆ canton_no ┆ parr_norm ┆ DPA_PARRO ┆ archivo_o │
# │ ---        ┆ ---       ┆ ---    ┆ uia        ┆   ┆ rm        ┆ ---       ┆ Q         ┆ rigen     │
# │ str        ┆ str       ┆ str    ┆ ---        ┆   ┆ ---       ┆ str       ┆ ---       ┆ ---       │
# │            ┆           ┆        ┆ i64        ┆   ┆ str       ┆           ┆ str       ┆ str       │
# ╞════════════╪═══════════╪════════╪════════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 2022-04-01 ┆ pichincha ┆ quito  ┆ 170150     ┆ … ┆ quito     ┆ quito     ┆ 170150.0  ┆ eventos_2 │
# │            ┆           ┆        ┆            ┆   ┆           ┆ distrito  ┆           ┆ 022_compl │
# │            ┆           ┆        ┆            ┆   ┆           ┆ metropoli ┆           ┆ eto_georr │
# │            ┆           ┆        ┆            ┆   ┆           ┆ tano, …   ┆           ┆ efe…      │
# │ 2022-04-01 ┆ pichincha ┆ quito  ┆ 170150     ┆ … ┆ quito     ┆ quito     ┆ 170150.0  ┆ eventos_2 │
# │            ┆           ┆        ┆            ┆   ┆           ┆ distrito  ┆           ┆ 022_compl │
# │            ┆           ┆        ┆            ┆   ┆           ┆ metropoli ┆           ┆ eto_georr │
# │            ┆           ┆        ┆            ┆   ┆           ┆ tano, …   ┆           ┆ efe…      │
# │ 2022-04-01 ┆ pichincha ┆ quito  ┆ 170150     ┆ … ┆ quito     ┆ quito     ┆ 170150.0  ┆ eventos_2 │
# │            ┆           ┆        ┆            ┆   ┆           ┆ distrito  ┆           ┆ 022_compl │
# │            ┆           ┆        ┆            ┆   ┆           ┆ metropoli ┆           ┆ eto_georr │
# │            ┆           ┆        ┆            ┆   ┆           ┆ tano, …   ┆           ┆ efe…      │
# │ 2022-04-01 ┆ pichincha ┆ quito  ┆ 170150     ┆ … ┆ quito     ┆ quito     ┆ 170150.0  ┆ eventos_2 │
# │            ┆           ┆        ┆            ┆   ┆           ┆ distrito  ┆           ┆ 022_compl │
# │            ┆           ┆        ┆            ┆   ┆           ┆ metropoli ┆           ┆ eto_georr │
# │            ┆           ┆        ┆            ┆   ┆           ┆ tano, …   ┆           ┆ efe…      │
# │ 2022-04-01 ┆ pichincha ┆ quito  ┆ 170176     ┆ … ┆ quito     ┆ pintag    ┆ 170176.0  ┆ eventos_2 │
# │            ┆           ┆        ┆            ┆   ┆           ┆           ┆           ┆ 022_compl │
# │            ┆           ┆        ┆            ┆   ┆           ┆           ┆           ┆ eto_georr │
# │            ┆           ┆        ┆            ┆   ┆           ┆           ┆           ┆ efe…      │
# └────────────┴───────────┴────────┴────────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
df_copia.select(df_copia.filter(pl.col("DPA_PARROQ").is_null()))
# Out:
# shape: (816, 12)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ Fecha     ┆ provincia ┆ Canton    ┆ Cod_Parro ┆ … ┆ canton_no ┆ parr_norm ┆ DPA_PARRO ┆ archivo_ │
# │ ---       ┆ ---       ┆ ---       ┆ quia      ┆   ┆ rm        ┆ ---       ┆ Q         ┆ origen   │
# │ str       ┆ str       ┆ str       ┆ ---       ┆   ┆ ---       ┆ str       ┆ ---       ┆ ---      │
# │           ┆           ┆           ┆ i64       ┆   ┆ str       ┆           ┆ str       ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 2022-04-0 ┆ orellana  ┆ aguarico  ┆ 220254    ┆ … ┆ aguarico  ┆ tiputini  ┆ null      ┆ eventos_ │
# │ 1         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 2022_com │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ pleto_ge │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ orrefe…  │
# │ 2022-04-0 ┆ orellana  ┆ aguarico  ┆ 220254    ┆ … ┆ aguarico  ┆ tiputini  ┆ null      ┆ eventos_ │
# │ 1         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 2022_com │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ pleto_ge │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ orrefe…  │
# │ 2022-04-0 ┆ orellana  ┆ aguarico  ┆ 220254    ┆ … ┆ aguarico  ┆ tiputini  ┆ null      ┆ eventos_ │
# │ 3         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 2022_com │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ pleto_ge │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ orrefe…  │
# │ 2022-04-0 ┆ orellana  ┆ aguarico  ┆ 220254    ┆ … ┆ aguarico  ┆ tiputini  ┆ null      ┆ eventos_ │
# │ 3         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 2022_com │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ pleto_ge │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ orrefe…  │
# │ 2022-04-0 ┆ orellana  ┆ aguarico  ┆ 220254    ┆ … ┆ aguarico  ┆ tiputini  ┆ null      ┆ eventos_ │
# │ 3         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 2022_com │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ pleto_ge │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ orrefe…  │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ 2021-09-1 ┆ azuay     ┆ camilo    ┆ 11551     ┆ … ┆ camilo    ┆ el carmen ┆ null      ┆ emergenc │
# │ 6         ┆           ┆ ponce     ┆           ┆   ┆ ponce     ┆ de pijili ┆           ┆ ias_2021 │
# │           ┆           ┆ enriquez  ┆           ┆   ┆ enriquez  ┆           ┆           ┆ _complet │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ o_geor…  │
# │ 2021-09-2 ┆ azuay     ┆ camilo    ┆ 11551     ┆ … ┆ camilo    ┆ el carmen ┆ null      ┆ emergenc │
# │ 6         ┆           ┆ ponce     ┆           ┆   ┆ ponce     ┆ de pijili ┆           ┆ ias_2021 │
# │           ┆           ┆ enriquez  ┆           ┆   ┆ enriquez  ┆           ┆           ┆ _complet │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ o_geor…  │
# │ 2021-09-2 ┆ azuay     ┆ camilo    ┆ 11551     ┆ … ┆ camilo    ┆ el carmen ┆ null      ┆ emergenc │
# │ 9         ┆           ┆ ponce     ┆           ┆   ┆ ponce     ┆ de pijili ┆           ┆ ias_2021 │
# │           ┆           ┆ enriquez  ┆           ┆   ┆ enriquez  ┆           ┆           ┆ _complet │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ o_geor…  │
# │ 2021-09-1 ┆ orellana  ┆ aguarico  ┆ 220254    ┆ … ┆ aguarico  ┆ tiputini  ┆ null      ┆ emergenc │
# │ 1         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ ias_2021 │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ _complet │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ o_geor…  │
# │ 2021-09-2 ┆ orellana  ┆ aguarico  ┆ 220254    ┆ … ┆ aguarico  ┆ tiputini  ┆ null      ┆ emergenc │
# │ 0         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ ias_2021 │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ _complet │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ o_geor…  │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
df_copia = df_copia.drop_nulls(subset=['DPA_PARROQ'])

# %%
df_copia.head()
# Out:
# shape: (5, 12)
# ┌────────────┬───────────┬────────┬────────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ Fecha      ┆ provincia ┆ Canton ┆ Cod_Parroq ┆ … ┆ canton_no ┆ parr_norm ┆ DPA_PARRO ┆ archivo_o │
# │ ---        ┆ ---       ┆ ---    ┆ uia        ┆   ┆ rm        ┆ ---       ┆ Q         ┆ rigen     │
# │ str        ┆ str       ┆ str    ┆ ---        ┆   ┆ ---       ┆ str       ┆ ---       ┆ ---       │
# │            ┆           ┆        ┆ i64        ┆   ┆ str       ┆           ┆ str       ┆ str       │
# ╞════════════╪═══════════╪════════╪════════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 2022-04-01 ┆ pichincha ┆ quito  ┆ 170150     ┆ … ┆ quito     ┆ quito     ┆ 170150.0  ┆ eventos_2 │
# │            ┆           ┆        ┆            ┆   ┆           ┆ distrito  ┆           ┆ 022_compl │
# │            ┆           ┆        ┆            ┆   ┆           ┆ metropoli ┆           ┆ eto_georr │
# │            ┆           ┆        ┆            ┆   ┆           ┆ tano, …   ┆           ┆ efe…      │
# │ 2022-04-01 ┆ pichincha ┆ quito  ┆ 170150     ┆ … ┆ quito     ┆ quito     ┆ 170150.0  ┆ eventos_2 │
# │            ┆           ┆        ┆            ┆   ┆           ┆ distrito  ┆           ┆ 022_compl │
# │            ┆           ┆        ┆            ┆   ┆           ┆ metropoli ┆           ┆ eto_georr │
# │            ┆           ┆        ┆            ┆   ┆           ┆ tano, …   ┆           ┆ efe…      │
# │ 2022-04-01 ┆ pichincha ┆ quito  ┆ 170150     ┆ … ┆ quito     ┆ quito     ┆ 170150.0  ┆ eventos_2 │
# │            ┆           ┆        ┆            ┆   ┆           ┆ distrito  ┆           ┆ 022_compl │
# │            ┆           ┆        ┆            ┆   ┆           ┆ metropoli ┆           ┆ eto_georr │
# │            ┆           ┆        ┆            ┆   ┆           ┆ tano, …   ┆           ┆ efe…      │
# │ 2022-04-01 ┆ pichincha ┆ quito  ┆ 170150     ┆ … ┆ quito     ┆ quito     ┆ 170150.0  ┆ eventos_2 │
# │            ┆           ┆        ┆            ┆   ┆           ┆ distrito  ┆           ┆ 022_compl │
# │            ┆           ┆        ┆            ┆   ┆           ┆ metropoli ┆           ┆ eto_georr │
# │            ┆           ┆        ┆            ┆   ┆           ┆ tano, …   ┆           ┆ efe…      │
# │ 2022-04-01 ┆ pichincha ┆ quito  ┆ 170176     ┆ … ┆ quito     ┆ pintag    ┆ 170176.0  ┆ eventos_2 │
# │            ┆           ┆        ┆            ┆   ┆           ┆           ┆           ┆ 022_compl │
# │            ┆           ┆        ┆            ┆   ┆           ┆           ┆           ┆ eto_georr │
# │            ┆           ┆        ┆            ┆   ┆           ┆           ┆           ┆ efe…      │
# └────────────┴───────────┴────────┴────────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
df_unificado.shape
# Out:
# (16316930, 12)

# %%
df_copia.shape
# Out:
# (16316114, 12)

# %%
df_copia = df_copia.select(pl.exclude("prov_norm","canton_norm","parr_norm", "archivo_origen"))
# Out:
# shape: (5, 8)
# ┌────────────┬───────────┬────────┬────────────┬────────────┬────────────┬────────────┬────────────┐
# │ Fecha      ┆ provincia ┆ Canton ┆ Cod_Parroq ┆ Parroquia  ┆ Servicio   ┆ Subtipo    ┆ DPA_PARROQ │
# │ ---        ┆ ---       ┆ ---    ┆ uia        ┆ ---        ┆ ---        ┆ ---        ┆ ---        │
# │ str        ┆ str       ┆ str    ┆ ---        ┆ str        ┆ str        ┆ str        ┆ str        │
# │            ┆           ┆        ┆ i64        ┆            ┆            ┆            ┆            │
# ╞════════════╪═══════════╪════════╪════════════╪════════════╪════════════╪════════════╪════════════╡
# │ 2022-04-01 ┆ pichincha ┆ quito  ┆ 170150     ┆ quito      ┆ seguridad  ┆ presencia  ┆ 170150.0   │
# │            ┆           ┆        ┆            ┆ distrito   ┆ ciudadana  ┆ policial   ┆            │
# │            ┆           ┆        ┆            ┆ metropolit ┆            ┆            ┆            │
# │            ┆           ┆        ┆            ┆ ano, …     ┆            ┆            ┆            │
# │ 2022-04-01 ┆ pichincha ┆ quito  ┆ 170150     ┆ quito      ┆ seguridad  ┆ escandalo  ┆ 170150.0   │
# │            ┆           ┆        ┆            ┆ distrito   ┆ ciudadana  ┆ en espacio ┆            │
# │            ┆           ┆        ┆            ┆ metropolit ┆            ┆ publico    ┆            │
# │            ┆           ┆        ┆            ┆ ano, …     ┆            ┆            ┆            │
# │ 2022-04-01 ┆ pichincha ┆ quito  ┆ 170150     ┆ quito      ┆ servicios  ┆ apoyo inst ┆ 170150.0   │
# │            ┆           ┆        ┆            ┆ distrito   ┆ municipale ┆ itucional  ┆            │
# │            ┆           ┆        ┆            ┆ metropolit ┆ s          ┆            ┆            │
# │            ┆           ┆        ┆            ┆ ano, …     ┆            ┆            ┆            │
# │ 2022-04-01 ┆ pichincha ┆ quito  ┆ 170150     ┆ quito      ┆ seguridad  ┆ desapareci ┆ 170150.0   │
# │            ┆           ┆        ┆            ┆ distrito   ┆ ciudadana  ┆ do         ┆            │
# │            ┆           ┆        ┆            ┆ metropolit ┆            ┆            ┆            │
# │            ┆           ┆        ┆            ┆ ano, …     ┆            ┆            ┆            │
# │ 2022-04-01 ┆ pichincha ┆ quito  ┆ 170176     ┆ pintag     ┆ seguridad  ┆ patrullaje ┆ 170176.0   │
# │            ┆           ┆        ┆            ┆            ┆ ciudadana  ┆ policial   ┆            │
# │            ┆           ┆        ┆            ┆            ┆            ┆ en el      ┆            │
# │            ┆           ┆        ┆            ┆            ┆            ┆ sect…      ┆            │
# └────────────┴───────────┴────────┴────────────┴────────────┴────────────┴────────────┴────────────┘

# %%
df_copia
# Out:
# shape: (16_316_114, 8)
# ┌────────────┬───────────┬────────┬────────────┬────────────┬────────────┬────────────┬────────────┐
# │ Fecha      ┆ provincia ┆ Canton ┆ Cod_Parroq ┆ Parroquia  ┆ Servicio   ┆ Subtipo    ┆ DPA_PARROQ │
# │ ---        ┆ ---       ┆ ---    ┆ uia        ┆ ---        ┆ ---        ┆ ---        ┆ ---        │
# │ str        ┆ str       ┆ str    ┆ ---        ┆ str        ┆ str        ┆ str        ┆ str        │
# │            ┆           ┆        ┆ i64        ┆            ┆            ┆            ┆            │
# ╞════════════╪═══════════╪════════╪════════════╪════════════╪════════════╪════════════╪════════════╡
# │ 2022-04-01 ┆ pichincha ┆ quito  ┆ 170150     ┆ quito      ┆ seguridad  ┆ presencia  ┆ 170150.0   │
# │            ┆           ┆        ┆            ┆ distrito   ┆ ciudadana  ┆ policial   ┆            │
# │            ┆           ┆        ┆            ┆ metropolit ┆            ┆            ┆            │
# │            ┆           ┆        ┆            ┆ ano, …     ┆            ┆            ┆            │
# │ 2022-04-01 ┆ pichincha ┆ quito  ┆ 170150     ┆ quito      ┆ seguridad  ┆ escandalo  ┆ 170150.0   │
# │            ┆           ┆        ┆            ┆ distrito   ┆ ciudadana  ┆ en espacio ┆            │
# │            ┆           ┆        ┆            ┆ metropolit ┆            ┆ publico    ┆            │
# │            ┆           ┆        ┆            ┆ ano, …     ┆            ┆            ┆            │
# │ 2022-04-01 ┆ pichincha ┆ quito  ┆ 170150     ┆ quito      ┆ servicios  ┆ apoyo inst ┆ 170150.0   │
# │            ┆           ┆        ┆            ┆ distrito   ┆ municipale ┆ itucional  ┆            │
# │            ┆           ┆        ┆            ┆ metropolit ┆ s          ┆            ┆            │
# │            ┆           ┆        ┆            ┆ ano, …     ┆            ┆            ┆            │
# │ 2022-04-01 ┆ pichincha ┆ quito  ┆ 170150     ┆ quito      ┆ seguridad  ┆ desapareci ┆ 170150.0   │
# │            ┆           ┆        ┆            ┆ distrito   ┆ ciudadana  ┆ do         ┆            │
# │            ┆           ┆        ┆            ┆ metropolit ┆            ┆            ┆            │
# │            ┆           ┆        ┆            ┆ ano, …     ┆            ┆            ┆            │
# │ 2022-04-01 ┆ pichincha ┆ quito  ┆ 170176     ┆ pintag     ┆ seguridad  ┆ patrullaje ┆ 170176.0   │
# │            ┆           ┆        ┆            ┆            ┆ ciudadana  ┆ policial   ┆            │
# │            ┆           ┆        ┆            ┆            ┆            ┆ en el      ┆            │
# │            ┆           ┆        ┆            ┆            ┆            ┆ sect…      ┆            │
# │ …          ┆ …         ┆ …      ┆ …          ┆ …          ┆ …          ┆ …          ┆ …          │
# │ 2021-09-30 ┆ pichincha ┆ quito  ┆ 170150     ┆ quito      ┆ seguridad  ┆ robo       ┆ 170150.0   │
# │            ┆           ┆        ┆            ┆ distrito   ┆ ciudadana  ┆            ┆            │
# │            ┆           ┆        ┆            ┆ metropolit ┆            ┆            ┆            │
# │            ┆           ┆        ┆            ┆ ano, …     ┆            ┆            ┆            │
# │ 2021-09-30 ┆ pichincha ┆ quito  ┆ 170160     ┆ el quinche ┆ seguridad  ┆ violencia  ┆ 170160.0   │
# │            ┆           ┆        ┆            ┆            ┆ ciudadana  ┆ contra la  ┆            │
# │            ┆           ┆        ┆            ┆            ┆            ┆ mujer o    ┆            │
# │            ┆           ┆        ┆            ┆            ┆            ┆ mi…        ┆            │
# │ 2021-09-30 ┆ pichincha ┆ quito  ┆ 170150     ┆ quito      ┆ seguridad  ┆ presencia  ┆ 170150.0   │
# │            ┆           ┆        ┆            ┆ distrito   ┆ ciudadana  ┆ policial   ┆            │
# │            ┆           ┆        ┆            ┆ metropolit ┆            ┆            ┆            │
# │            ┆           ┆        ┆            ┆ ano, …     ┆            ┆            ┆            │
# │ 2021-09-30 ┆ napo      ┆ tena   ┆ 150150     ┆ tena,      ┆ seguridad  ┆ violencia  ┆ 150150.0   │
# │            ┆           ┆        ┆            ┆ cabecera   ┆ ciudadana  ┆ intrafamil ┆            │
# │            ┆           ┆        ┆            ┆ cantonal y ┆            ┆ iar        ┆            │
# │            ┆           ┆        ┆            ┆ capi…      ┆            ┆            ┆            │
# │ 2021-09-30 ┆ pichincha ┆ quito  ┆ 170150     ┆ quito      ┆ seguridad  ┆ patrullaje ┆ 170150.0   │
# │            ┆           ┆        ┆            ┆ distrito   ┆ ciudadana  ┆ policial   ┆            │
# │            ┆           ┆        ┆            ┆ metropolit ┆            ┆ en el      ┆            │
# │            ┆           ┆        ┆            ┆ ano, …     ┆            ┆ sect…      ┆            │
# └────────────┴───────────┴────────┴────────────┴────────────┴────────────┴────────────┴────────────┘

# %%
df_copia["DPA_PARROQ"]
# Out:
# shape: (16_316_114,)
# Series: 'DPA_PARROQ' [str]
# [
# 	"170150.0"
# 	"170150.0"
# 	"170150.0"
# 	"170150.0"
# 	"170176.0"
# 	…
# 	"170150.0"
# 	"170160.0"
# 	"170150.0"
# 	"150150.0"
# 	"170150.0"
# ]

# %%
# Verificar si TODOS los valores terminan en ".0"
todos_terminan_en_punto_cero = df_copia['DPA_PARROQ'].cast(pl.Utf8).str.ends_with('.0').all()
print(f"¿Todos terminan en .0?: {todos_terminan_en_punto_cero}")
# Out:
# ¿Todos terminan en .0?: True

# %%
print (df_copia.select('DPA_PARROQ').head())
df_copia = df_copia.with_columns(
    pl.col('DPA_PARROQ').cast(pl.Utf8).str.strip_suffix(".0").alias('DPA_PARROQ')

)
print (df_copia.select('DPA_PARROQ').head())
# Out:
# shape: (5, 1)
# ┌────────────┐
# │ DPA_PARROQ │
# │ ---        │
# │ str        │
# ╞════════════╡
# │ 170150.0   │
# │ 170150.0   │
# │ 170150.0   │
# │ 170150.0   │
# │ 170176.0   │
# └────────────┘
# shape: (5, 1)
# ┌────────────┐
# │ DPA_PARROQ │
# │ ---        │
# │ str        │
# ╞════════════╡
# │ 170150     │
# │ 170150     │
# │ 170150     │
# │ 170150     │
# │ 170176     │
# └────────────┘

# %%
df_copia
# Out:
# shape: (16_316_114, 8)
# ┌────────────┬───────────┬────────┬────────────┬────────────┬────────────┬────────────┬────────────┐
# │ Fecha      ┆ provincia ┆ Canton ┆ Cod_Parroq ┆ Parroquia  ┆ Servicio   ┆ Subtipo    ┆ DPA_PARROQ │
# │ ---        ┆ ---       ┆ ---    ┆ uia        ┆ ---        ┆ ---        ┆ ---        ┆ ---        │
# │ str        ┆ str       ┆ str    ┆ ---        ┆ str        ┆ str        ┆ str        ┆ str        │
# │            ┆           ┆        ┆ i64        ┆            ┆            ┆            ┆            │
# ╞════════════╪═══════════╪════════╪════════════╪════════════╪════════════╪════════════╪════════════╡
# │ 2022-04-01 ┆ pichincha ┆ quito  ┆ 170150     ┆ quito      ┆ seguridad  ┆ presencia  ┆ 170150     │
# │            ┆           ┆        ┆            ┆ distrito   ┆ ciudadana  ┆ policial   ┆            │
# │            ┆           ┆        ┆            ┆ metropolit ┆            ┆            ┆            │
# │            ┆           ┆        ┆            ┆ ano, …     ┆            ┆            ┆            │
# │ 2022-04-01 ┆ pichincha ┆ quito  ┆ 170150     ┆ quito      ┆ seguridad  ┆ escandalo  ┆ 170150     │
# │            ┆           ┆        ┆            ┆ distrito   ┆ ciudadana  ┆ en espacio ┆            │
# │            ┆           ┆        ┆            ┆ metropolit ┆            ┆ publico    ┆            │
# │            ┆           ┆        ┆            ┆ ano, …     ┆            ┆            ┆            │
# │ 2022-04-01 ┆ pichincha ┆ quito  ┆ 170150     ┆ quito      ┆ servicios  ┆ apoyo inst ┆ 170150     │
# │            ┆           ┆        ┆            ┆ distrito   ┆ municipale ┆ itucional  ┆            │
# │            ┆           ┆        ┆            ┆ metropolit ┆ s          ┆            ┆            │
# │            ┆           ┆        ┆            ┆ ano, …     ┆            ┆            ┆            │
# │ 2022-04-01 ┆ pichincha ┆ quito  ┆ 170150     ┆ quito      ┆ seguridad  ┆ desapareci ┆ 170150     │
# │            ┆           ┆        ┆            ┆ distrito   ┆ ciudadana  ┆ do         ┆            │
# │            ┆           ┆        ┆            ┆ metropolit ┆            ┆            ┆            │
# │            ┆           ┆        ┆            ┆ ano, …     ┆            ┆            ┆            │
# │ 2022-04-01 ┆ pichincha ┆ quito  ┆ 170176     ┆ pintag     ┆ seguridad  ┆ patrullaje ┆ 170176     │
# │            ┆           ┆        ┆            ┆            ┆ ciudadana  ┆ policial   ┆            │
# │            ┆           ┆        ┆            ┆            ┆            ┆ en el      ┆            │
# │            ┆           ┆        ┆            ┆            ┆            ┆ sect…      ┆            │
# │ …          ┆ …         ┆ …      ┆ …          ┆ …          ┆ …          ┆ …          ┆ …          │
# │ 2021-09-30 ┆ pichincha ┆ quito  ┆ 170150     ┆ quito      ┆ seguridad  ┆ robo       ┆ 170150     │
# │            ┆           ┆        ┆            ┆ distrito   ┆ ciudadana  ┆            ┆            │
# │            ┆           ┆        ┆            ┆ metropolit ┆            ┆            ┆            │
# │            ┆           ┆        ┆            ┆ ano, …     ┆            ┆            ┆            │
# │ 2021-09-30 ┆ pichincha ┆ quito  ┆ 170160     ┆ el quinche ┆ seguridad  ┆ violencia  ┆ 170160     │
# │            ┆           ┆        ┆            ┆            ┆ ciudadana  ┆ contra la  ┆            │
# │            ┆           ┆        ┆            ┆            ┆            ┆ mujer o    ┆            │
# │            ┆           ┆        ┆            ┆            ┆            ┆ mi…        ┆            │
# │ 2021-09-30 ┆ pichincha ┆ quito  ┆ 170150     ┆ quito      ┆ seguridad  ┆ presencia  ┆ 170150     │
# │            ┆           ┆        ┆            ┆ distrito   ┆ ciudadana  ┆ policial   ┆            │
# │            ┆           ┆        ┆            ┆ metropolit ┆            ┆            ┆            │
# │            ┆           ┆        ┆            ┆ ano, …     ┆            ┆            ┆            │
# │ 2021-09-30 ┆ napo      ┆ tena   ┆ 150150     ┆ tena,      ┆ seguridad  ┆ violencia  ┆ 150150     │
# │            ┆           ┆        ┆            ┆ cabecera   ┆ ciudadana  ┆ intrafamil ┆            │
# │            ┆           ┆        ┆            ┆ cantonal y ┆            ┆ iar        ┆            │
# │            ┆           ┆        ┆            ┆ capi…      ┆            ┆            ┆            │
# │ 2021-09-30 ┆ pichincha ┆ quito  ┆ 170150     ┆ quito      ┆ seguridad  ┆ patrullaje ┆ 170150     │
# │            ┆           ┆        ┆            ┆ distrito   ┆ ciudadana  ┆ policial   ┆            │
# │            ┆           ┆        ┆            ┆ metropolit ┆            ┆ en el      ┆            │
# │            ┆           ┆        ┆            ┆ ano, …     ┆            ┆ sect…      ┆            │
# └────────────┴───────────┴────────┴────────────┴────────────┴────────────┴────────────┴────────────┘

# %%
df_copia.write_csv("datos_limpios_2021_2025.csv")
